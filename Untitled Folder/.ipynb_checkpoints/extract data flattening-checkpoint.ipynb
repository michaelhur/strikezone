# %%
import glob
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import datetime
import requests
import urllib2
import re
import sys
import os

# %%
def get_soup(filepath):
    with open(filepath, 'r') as myfile:
        xml = myfile.read()
    soup = BeautifulSoup(xml, 'lxml-xml')
    return soup

# %%
server_url = 'http://gdx.mlb.com/components/game/mlb/'

# %%
def extract_field(document, tag, attr=None):
    result = document.find_all(tag)

    if len(result) == 0:
        return None

    if attr is not None:
        result = [r.get(attr).encode('ASCII', 'ignore') for r in result]
    else:
        result = [r.text.encode('ASCII', 'ignore') for r in result]
     
    if len(result) == 1:
        return result[0]
    else:
        return result

# %%
def extract_game_info(game_soup):
    game_dict = {}
    
    boxscore = game_soup.find('boxscore')
    umpires = game_soup.find('umpires')
    teams = game_soup.find_all('team')
    
    game_dict['game_type'] = boxscore['game_type']
    game_dict['venue_name'] = boxscore['venue_name']
    game_dict['venue_id'] = boxscore['venue_id']
    game_dict['game_id'] = boxscore['game_id']
    game_dict['date'] = boxscore['date']
    
    umpire_dict = {}
    for umpire in umpires:
        if umpire['position'] == 'HP':
            umpire_dict['id'] = umpire['id']
            umpire_dict['name'] = umpire['name']
            
            game_dict['umpire'] = umpire_dict
            break
    
    team_list = []
    
    for team in teams:
        team_list.append(team.attrs)
    
    game_dict['teams'] = team_list
    
    return game_dict

# %%
def extract_pitch_info(inning_soup):
    atbats = inning_soup.find_all('atbat')
    
    atbat_list = []
    
    for atbat in atbats:
        
        pitches = atbat.find_all('pitch')

        pitch_count = 0
        
        for pitch in pitches:
            
            pitch_count += 1
            try:
                pitch_dict = {}

                ## If any one of these attribute is missing, we omit the pitch data for it is no longer useful in plotting pitchfx data
                pitch_dict['isHome'] = 0 if atbat.parent.name == 'top' else 1
                pitch_dict['inning_count'] = atbat.parent.parent['num']

                pitch_dict['atbat_count'] = int(atbat['num'])
                pitch_dict['batter_height'] = atbat['b_height']
                pitch_dict['batter_id'] = atbat['batter']
                pitch_dict['pitcher_id'] = atbat['pitcher']
                pitch_dict['handedness'] = atbat['stand']
                pitch_dict['p_throws'] = atbat['p_throws']
 
                pitch_dict['pitch_count'] = pitch_count
                pitch_dict['des'] = pitch['des']
                pitch_dict['type'] = pitch['type']
                pitch_dict['px'] = float(pitch['px'])
                pitch_dict['pz'] = float(pitch['pz'])
                pitch_dict['sz_top'] = float(pitch['sz_top'])
                pitch_dict['sz_bottom'] = float(pitch['sz_bot'])

                atbat_list.append(pitch_dict)
            
            except:
                continue
        
        
        
    return atbat_list

# %%
def parse_game(gid_dir):
    
    gid_dir = gid_dir.rstrip('/') + "/"
    
    game_dir = gid_dir + "rawboxscore.xml"
    inning_dir = gid_dir + "inning_all.xml"
    
    game_soup = get_soup(game_dir)
    inning_soup = get_soup(inning_dir)
        
    game_dict = extract_game_info(game_soup)
    
    game_dict['pitches'] = extract_pitch_info(inning_soup)
    
    return game_dict

# %%
data_dir = './data'

# %%
def make_dir(designated_dir):
    if not os.path.exists(designated_dir):
        os.makedirs(designated_dir)

# %%
def download_page(url, download_dir):
    """
    Grab page at url and either return it as a string or save it to file
    """
    try:
        response = urllib2.urlopen(url)
        html = response.read()
    except Exception as err:
        print >>sys.stderr, "url: {0}\n\t{1}".format(url, str(err))

    filename = url.split('/')[-1]
    if not os.path.exists(download_dir + filename):
        print "Downloading %s" %(download_dir.strip('./data/') + "/" + filename)
        try:
            with open(download_dir + filename, 'w') as handle:
                handle.write(html)
        except:
            pass
    else:
        pass

# %%
def grab_page_with_pattern(url, pattern):
    
    """
    get_data() extracts pitch data from all the games played on the given date.
    we expect year, month and day to be a string, or integers, of the form "YYYY", "MM", "DD", respectively.
    By default, download_data() will download the entire 2017 season, will download, at least, at the season level.
    """
    
    response = urllib2.urlopen(url)
    link = response.read()
    soup = BeautifulSoup(link)
    
    if len(pattern) > 0:
        wanted_pattern = pattern[0]
        matched_patterns = []
        
        for ahref in soup.findAll('a'):
            for c in ahref.contents:
                c = str(c).strip()
                
                if re.match(wanted_pattern, c):                  
                    if len(pattern) == 2:
                        c = c.strip('/')
                        
                    if len(pattern) == 1:
                        c = "/" + c
                        make_dir(data_dir + c)
                
                    matched_patterns.append(c)
    
        for matched in matched_patterns:
            new_url = url + matched
            grab_page_with_pattern(new_url, pattern[1:])

    else:
        directory = data_dir + "/" + url.split('/')[-2] + "/"
        download_page(url + 'rawboxscore.xml', directory)
        download_page(url + 'inning/inning_all.xml', directory)

# %%
def download_data(year = 2017, month = "", day = ""):
    
    """
    get_data() extracts pitch data from all the games played on the given date.
    we expect year, month and day to be a string, or integers, of the form "YYYY", "MM", "DD", respectively.
    By default, download_data() will download the entire 2017 season, will download, at least, at the season level.
    """
    
    url = server_url
    
    year = str(year)
    month = str(month)
    day = str(day)
    
    year_pattern = "year_" + str(year)
    month_pattern = "month_" + str(month) if month is not None else "month_"
    day_pattern = "day_" + str(day) if day is not None else "day_"
    game_pattern  = "gid_"
    
    if month is "":
        url = server_url + year_pattern + "/"
        pattern = [month_pattern, day_pattern, game_pattern]
        
    elif day is "":
        url = server_url + year_pattern + "/" + month_pattern
        pattern = [day_pattern, game_pattern]

    else:
        url = server_url + year_pattern + "/" + month_pattern + "/" + day_pattern
        pattern = [game_pattern]
        
    print "Downloading data for %s %s %s" %(year, month, day)
   
    grab_page_with_pattern(url, pattern)

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
pitchfx_db2 = client.test_database
pitchfx_collection2 = pitchfx_db2.test_collection

# %%
data_dir = "./data/"
gid_dirs = glob.glob(data_dir + 'gid_*/')

# %%
pitchfx_collection2.delete_many({})

# %%
start_time = datetime.datetime.now()
print start_time

for d in gid_dirs:
    print d
    try:
        pitchfx_collection2.insert_one(parse_game(d))
    except:
        pass
    
end_time = datetime.datetime.now()
print 'Elapsed:', end_time - start_time
# Out:
# 2018-09-11 15:43:06.972714
# ./data/gid_2017_04_23_tormlb_anamlb_1/
# ./data/gid_2017_09_09_sdnmlb_arimlb_1/
# ./data/gid_2017_08_26_houmlb_anamlb_1/
# ./data/gid_2017_06_02_lanmlb_milmlb_1/
# ./data/gid_2017_04_24_sdnmlb_arimlb_1/
# ./data/gid_2017_08_13_sdnmlb_lanmlb_1/
# ./data/gid_2017_10_06_awcmlb_adtmlb_1/
# ./data/gid_2017_06_14_atlmlb_wasmlb_1/
# ./data/gid_2017_08_18_arimlb_minmlb_1/
# ./data/gid_2017_08_04_detmlb_balmlb_1/
# ./data/gid_2017_08_02_tbamlb_houmlb_1/
# ./data/gid_2017_05_03_milmlb_slnmlb_1/
# ./data/gid_2017_07_08_oakmlb_seamlb_1/
# ./data/gid_2017_07_01_sfnmlb_pitmlb_1/
# ./data/gid_2017_08_25_sdnmlb_miamlb_1/
# ./data/gid_2017_05_01_chamlb_kcamlb_1/
# ./data/gid_2017_05_17_wasmlb_pitmlb_1/
# ./data/gid_2017_04_25_houmlb_clemlb_1/
# ./data/gid_2017_09_19_texmlb_seamlb_1/
# ./data/gid_2017_08_29_miamlb_wasmlb_1/
# ./data/gid_2017_09_27_cinmlb_milmlb_1/
# ./data/gid_2017_06_28_colmlb_sfnmlb_1/
# ./data/gid_2017_09_10_tbamlb_bosmlb_1/
# ./data/gid_2017_05_03_texmlb_houmlb_1/
# ./data/gid_2017_06_11_colmlb_chnmlb_1/
# ./data/gid_2017_07_21_milmlb_phimlb_1/
# ./data/gid_2017_06_23_milmlb_atlmlb_1/
# ./data/gid_2017_10_06_arimlb_lanmlb_1/
# ./data/gid_2017_07_26_kcamlb_detmlb_1/
# ./data/gid_2017_07_30_sfnmlb_lanmlb_1/
# ./data/gid_2017_09_05_anamlb_oakmlb_1/
# ./data/gid_2017_05_28_chnmlb_lanmlb_1/
# ./data/gid_2017_05_13_balmlb_kcamlb_1/
# ./data/gid_2017_04_07_minmlb_chamlb_1/
# ./data/gid_2017_09_06_arimlb_lanmlb_1/
# ./data/gid_2017_08_22_miamlb_phimlb_2/
# ./data/gid_2017_07_23_oakmlb_nynmlb_1/
# ./data/gid_2017_06_11_phimlb_slnmlb_1/
# ./data/gid_2017_07_25_oakmlb_tormlb_1/
# ./data/gid_2017_05_11_lanmlb_colmlb_1/
# ./data/gid_2017_07_30_colmlb_wasmlb_1/
# ./data/gid_2017_05_31_arimlb_pitmlb_1/
# ./data/gid_2017_10_11_wasmlb_chnmlb_1/
# ./data/gid_2017_06_10_oakmlb_tbamlb_2/
# ./data/gid_2017_05_19_bosmlb_oakmlb_1/
# ./data/gid_2017_07_29_chnmlb_milmlb_1/
# ./data/gid_2017_07_21_miamlb_cinmlb_1/
# ./data/gid_2017_09_17_texmlb_anamlb_1/
# ./data/gid_2017_09_29_balmlb_tbamlb_1/
# ./data/gid_2017_10_10_ndomlb_nwcmlb_1/
# ./data/gid_2017_10_01_pitmlb_wasmlb_1/
# ./data/gid_2017_05_17_balmlb_detmlb_1/
# ./data/gid_2017_05_21_colmlb_cinmlb_1/
# ./data/gid_2017_08_10_kcamlb_slnmlb_1/
# ./data/gid_2017_06_09_texmlb_wasmlb_1/
# ./data/gid_2017_07_24_balmlb_tbamlb_1/
# ./data/gid_2017_07_02_clemlb_detmlb_1/
# ./data/gid_2017_08_19_anamlb_balmlb_1/
# ./data/gid_2017_04_13_texmlb_anamlb_1/
# ./data/gid_2017_08_17_cinmlb_chnmlb_1/
# ./data/gid_2017_08_09_phimlb_atlmlb_1/
# ./data/gid_2017_05_27_sdnmlb_wasmlb_1/
# ./data/gid_2017_04_13_milmlb_cinmlb_1/
# ./data/gid_2017_04_09_tormlb_tbamlb_1/
# ./data/gid_2017_09_08_nyamlb_texmlb_1/
# ./data/gid_2017_04_28_pitmlb_miamlb_1/
# ./data/gid_2017_09_23_nyamlb_tormlb_1/
# ./data/gid_2017_04_23_atlmlb_phimlb_1/
# ./data/gid_2017_07_04_pitmlb_phimlb_1/
# ./data/gid_2017_09_07_colmlb_lanmlb_1/
# ./data/gid_2017_08_19_miamlb_nynmlb_1/
# ./data/gid_2017_04_09_seamlb_anamlb_1/
# ./data/gid_2017_08_06_phimlb_colmlb_1/
# ./data/gid_2017_07_04_houmlb_atlmlb_1/
# ./data/gid_2017_07_04_sfnmlb_detmlb_1/
# ./data/gid_2017_09_09_sfnmlb_chamlb_1/
# ./data/gid_2017_07_29_colmlb_wasmlb_1/
# ./data/gid_2017_08_16_nyamlb_nynmlb_1/
# ./data/gid_2017_10_10_wasmlb_chnmlb_1/
# ./data/gid_2017_04_11_arimlb_sfnmlb_1/
# ./data/gid_2017_10_01_balmlb_tbamlb_1/
# ./data/gid_2017_05_04_nynmlb_atlmlb_1/
# ./data/gid_2017_04_08_lanmlb_colmlb_1/
# ./data/gid_2017_06_24_oakmlb_chamlb_1/
# ./data/gid_2017_07_07_chamlb_colmlb_1/
# ./data/gid_2017_05_04_texmlb_houmlb_1/
# ./data/gid_2017_07_22_texmlb_tbamlb_1/
# ./data/gid_2017_09_08_miamlb_atlmlb_1/
# ./data/gid_2017_08_30_tbamlb_kcamlb_1/
# ./data/gid_2017_09_08_phimlb_wasmlb_1/
# ./data/gid_2017_06_22_detmlb_seamlb_1/
# ./data/gid_2017_07_28_anamlb_tormlb_1/
# ./data/gid_2017_04_04_chnmlb_slnmlb_1/
# ./data/gid_2017_06_27_tbamlb_pitmlb_1/
# ./data/gid_2017_04_19_phimlb_nynmlb_1/
# ./data/gid_2017_04_07_clemlb_arimlb_1/
# ./data/gid_2017_09_25_sfnmlb_arimlb_1/
# ./data/gid_2017_09_17_bosmlb_tbamlb_1/
# ./data/gid_2017_06_23_anamlb_bosmlb_1/
# ./data/gid_2017_05_27_slnmlb_colmlb_1/
# ./data/gid_2017_08_30_sfnmlb_sdnmlb_1/
# ./data/gid_2017_09_26_cinmlb_milmlb_1/
# ./data/gid_2017_10_11_awcmlb_adomlb_1/
# ./data/gid_2017_08_31_nynmlb_cinmlb_1/
# ./data/gid_2017_08_24_sdnmlb_slnmlb_1/
# ./data/gid_2017_06_03_minmlb_anamlb_1/
# ./data/gid_2017_08_29_seamlb_balmlb_1/
# ./data/gid_2017_08_24_colmlb_kcamlb_1/
# ./data/gid_2017_10_06_adhmlb_clemlb_1/
# ./data/gid_2017_05_25_sdnmlb_nynmlb_1/
# ./data/gid_2017_07_17_detmlb_kcamlb_1/
# ./data/gid_2017_10_05_awcmlb_clemlb_1/
# ./data/gid_2017_06_20_cinmlb_tbamlb_1/
# ./data/gid_2017_05_31_milmlb_nynmlb_1/
# ./data/gid_2017_08_20_milmlb_colmlb_1/
# ./data/gid_2017_05_25_pitmlb_atlmlb_1/
# ./data/gid_2017_08_25_nynmlb_wasmlb_1/
# ./data/gid_2017_08_12_balmlb_oakmlb_1/
# ./data/gid_2017_05_07_lanmlb_sdnmlb_1/
# ./data/gid_2017_06_10_phimlb_slnmlb_1/
# ./data/gid_2017_06_16_clemlb_minmlb_1/
# ./data/gid_2017_09_28_houmlb_bosmlb_1/
# ./data/gid_2017_08_08_texmlb_nynmlb_1/
# ./data/gid_2017_09_02_slnmlb_sfnmlb_1/
# ./data/gid_2017_09_12_sdnmlb_minmlb_1/
# ./data/gid_2017_04_19_arimlb_sdnmlb_1/
# ./data/gid_2017_08_20_tormlb_chnmlb_1/
# ./data/gid_2017_08_16_slnmlb_bosmlb_1/
# ./data/gid_2017_08_07_chnmlb_sfnmlb_1/
# ./data/gid_2017_05_11_sdnmlb_texmlb_1/
# ./data/gid_2017_09_02_nynmlb_houmlb_2/
# ./data/gid_2017_08_25_detmlb_chamlb_1/
# ./data/gid_2017_09_05_clemlb_chamlb_1/
# ./data/gid_2017_06_30_lanmlb_sdnmlb_1/
# ./data/gid_2017_05_22_minmlb_balmlb_1/
# ./data/gid_2017_07_02_phimlb_nynmlb_1/
# ./data/gid_2017_10_10_ndtmlb_ndhmlb_1/
# ./data/gid_2017_08_09_minmlb_milmlb_1/
# ./data/gid_2017_08_29_slnmlb_milmlb_1/
# ./data/gid_2017_07_06_milmlb_chnmlb_1/
# ./data/gid_2017_07_29_pitmlb_sdnmlb_1/
# ./data/gid_2017_04_16_detmlb_clemlb_1/
# ./data/gid_2017_04_14_texmlb_seamlb_1/
# ./data/gid_2017_06_22_nynmlb_lanmlb_1/
# ./data/gid_2017_09_20_arimlb_sdnmlb_1/
# ./data/gid_2017_06_14_bosmlb_phimlb_1/
# ./data/gid_2017_04_20_slnmlb_milmlb_1/
# ./data/gid_2017_07_14_arimlb_atlmlb_1/
# ./data/gid_2017_04_25_lanmlb_sfnmlb_1/
# ./data/gid_2017_07_17_milmlb_pitmlb_1/
# ./data/gid_2017_07_14_wasmlb_cinmlb_1/
# ./data/gid_2017_10_14_nyamlb_houmlb_1/
# ./data/gid_2017_04_15_balmlb_tormlb_1/
# ./data/gid_2017_05_30_detmlb_kcamlb_1/
# ./data/gid_2017_06_13_texmlb_houmlb_1/
# ./data/gid_2017_07_30_balmlb_texmlb_1/
# ./data/gid_2017_08_09_texmlb_nynmlb_1/
# ./data/gid_2017_08_31_phimlb_miamlb_1/
# ./data/gid_2017_08_17_atlmlb_colmlb_1/
# ./data/gid_2017_04_05_atlmlb_nynmlb_1/
# ./data/gid_2017_09_06_clemlb_chamlb_1/
# ./data/gid_2017_08_19_phimlb_sfnmlb_1/
# ./data/gid_2017_10_16_ahsmlb_alsmlb_1/
# ./data/gid_2017_08_22_milmlb_sfnmlb_1/
# ./data/gid_2017_05_31_colmlb_seamlb_1/
# ./data/gid_2017_07_02_atlmlb_oakmlb_1/
# ./data/gid_2017_07_18_texmlb_balmlb_1/
# ./data/gid_2017_09_06_chnmlb_pitmlb_1/
# ./data/gid_2017_04_12_houmlb_seamlb_1/
# ./data/gid_2017_04_04_clemlb_texmlb_1/
# ./data/gid_2017_07_08_detmlb_clemlb_1/
# ./data/gid_2017_04_11_atlmlb_miamlb_1/
# ./data/gid_2017_08_28_miamlb_wasmlb_1/
# ./data/gid_2017_04_29_atlmlb_milmlb_1/
# ./data/gid_2017_05_12_lanmlb_colmlb_1/
# ./data/gid_2017_04_07_tormlb_tbamlb_1/
# ./data/gid_2017_04_11_houmlb_seamlb_1/
# ./data/gid_2017_04_21_atlmlb_phimlb_1/
# ./data/gid_2017_05_07_milmlb_pitmlb_1/
# ./data/gid_2017_05_29_cinmlb_tormlb_1/
# ./data/gid_2017_08_28_oakmlb_anamlb_1/
# ./data/gid_2017_04_21_tormlb_anamlb_1/
# ./data/gid_2017_09_14_nynmlb_chnmlb_1/
# ./data/gid_2017_09_18_bosmlb_balmlb_1/
# ./data/gid_2017_09_17_kcamlb_clemlb_1/
# ./data/gid_2017_09_02_phimlb_miamlb_1/
# ./data/gid_2017_09_08_detmlb_tormlb_1/
# ./data/gid_2017_09_29_lanmlb_colmlb_1/
# ./data/gid_2017_07_08_milmlb_nyamlb_1/
# ./data/gid_2017_05_29_nyamlb_balmlb_1/
# ./data/gid_2017_08_06_milmlb_tbamlb_1/
# ./data/gid_2017_04_22_bosmlb_balmlb_1/
# ./data/gid_2017_05_12_phimlb_wasmlb_1/
# ./data/gid_2017_08_24_miamlb_phimlb_1/
# ./data/gid_2017_08_18_miamlb_nynmlb_1/
# ./data/gid_2017_05_03_arimlb_wasmlb_1/
# ./data/gid_2017_08_31_slnmlb_sfnmlb_1/
# ./data/gid_2017_07_30_chnmlb_milmlb_1/
# ./data/gid_2017_04_14_nynmlb_miamlb_1/
# ./data/gid_2017_04_30_nynmlb_wasmlb_1/
# ./data/gid_2017_07_29_clemlb_chamlb_1/
# ./data/gid_2017_04_12_texmlb_anamlb_1/
# ./data/gid_2017_09_09_minmlb_kcamlb_1/
# ./data/gid_2017_04_03_miamlb_wasmlb_1/
# ./data/gid_2017_05_01_clemlb_detmlb_1/
# ./data/gid_2017_06_08_miamlb_pitmlb_1/
# ./data/gid_2017_09_06_tormlb_bosmlb_1/
# ./data/gid_2017_07_21_wasmlb_arimlb_1/
# ./data/gid_2017_09_02_wasmlb_milmlb_1/
# ./data/gid_2017_04_10_nynmlb_phimlb_1/
# ./data/gid_2017_06_22_clemlb_balmlb_1/
# ./data/gid_2017_09_12_chamlb_kcamlb_1/
# ./data/gid_2017_04_15_chamlb_minmlb_1/
# ./data/gid_2017_09_08_colmlb_lanmlb_1/
# ./data/gid_2017_05_29_lanmlb_slnmlb_1/
# ./data/gid_2017_07_14_slnmlb_pitmlb_1/
# ./data/gid_2017_07_21_texmlb_tbamlb_1/
# ./data/gid_2017_07_25_houmlb_phimlb_1/
# ./data/gid_2017_10_19_lanmlb_chnmlb_1/
# ./data/gid_2017_07_14_nyamlb_bosmlb_1/
# ./data/gid_2017_06_19_houmlb_oakmlb_1/
# ./data/gid_2017_04_18_wasmlb_atlmlb_1/
# ./data/gid_2017_08_06_texmlb_minmlb_1/
# ./data/gid_2017_08_23_arimlb_nynmlb_1/
# ./data/gid_2017_06_11_miamlb_pitmlb_1/
# ./data/gid_2017_08_06_slnmlb_cinmlb_1/
# ./data/gid_2017_06_20_nynmlb_lanmlb_1/
# ./data/gid_2017_04_19_texmlb_oakmlb_1/
# ./data/gid_2017_06_06_chamlb_tbamlb_1/
# ./data/gid_2017_04_04_sdnmlb_lanmlb_1/
# ./data/gid_2017_08_15_atlmlb_colmlb_1/
# ./data/gid_2017_04_30_colmlb_arimlb_1/
# ./data/gid_2017_06_07_wasmlb_lanmlb_1/
# ./data/gid_2017_09_07_nyamlb_balmlb_1/
# ./data/gid_2017_07_05_miamlb_slnmlb_1/
# ./data/gid_2017_07_24_kcamlb_detmlb_1/
# ./data/gid_2017_04_07_nyamlb_balmlb_1/
# ./data/gid_2017_04_19_miamlb_seamlb_1/
# ./data/gid_2017_08_26_sfnmlb_arimlb_1/
# ./data/gid_2017_09_25_kcamlb_nyamlb_1/
# ./data/gid_2017_05_13_phimlb_wasmlb_1/
# ./data/gid_2017_06_06_wasmlb_lanmlb_1/
# ./data/gid_2017_05_07_slnmlb_atlmlb_1/
# ./data/gid_2017_05_08_clemlb_tormlb_1/
# ./data/gid_2017_09_10_phimlb_wasmlb_1/
# ./data/gid_2017_09_07_minmlb_kcamlb_1/
# ./data/gid_2017_09_05_minmlb_tbamlb_1/
# ./data/gid_2017_08_04_phimlb_colmlb_1/
# ./data/gid_2017_09_18_lanmlb_phimlb_1/
# ./data/gid_2017_05_10_pitmlb_lanmlb_1/
# ./data/gid_2017_08_06_tormlb_houmlb_1/
# ./data/gid_2017_08_14_houmlb_arimlb_1/
# ./data/gid_2017_07_22_miamlb_cinmlb_1/
# ./data/gid_2017_08_19_chamlb_texmlb_1/
# ./data/gid_2017_04_14_colmlb_sfnmlb_1/
# ./data/gid_2017_04_08_clemlb_arimlb_1/
# ./data/gid_2017_08_18_wasmlb_sdnmlb_1/
# ./data/gid_2017_09_15_milmlb_miamlb_1/
# ./data/gid_2017_08_22_chnmlb_cinmlb_1/
# ./data/gid_2017_04_24_tormlb_anamlb_1/
# ./data/gid_2017_07_23_nyamlb_seamlb_1/
# ./data/gid_2017_06_02_chamlb_detmlb_1/
# ./data/gid_2017_09_28_detmlb_kcamlb_1/
# ./data/gid_2017_04_23_clemlb_chamlb_1/
# ./data/gid_2017_06_30_clemlb_detmlb_1/
# ./data/gid_2017_09_14_atlmlb_wasmlb_1/
# ./data/gid_2017_09_27_balmlb_pitmlb_1/
# ./data/gid_2017_04_28_colmlb_arimlb_1/
# ./data/gid_2017_10_18_ahsmlb_alsmlb_1/
# ./data/gid_2017_07_22_bosmlb_anamlb_1/
# ./data/gid_2017_05_28_oakmlb_nyamlb_1/
# ./data/gid_2017_05_09_bosmlb_milmlb_1/
# ./data/gid_2017_09_30_detmlb_minmlb_1/
# ./data/gid_2017_05_29_bosmlb_chamlb_1/
# ./data/gid_2017_05_20_milmlb_chnmlb_1/
# ./data/gid_2017_08_30_clemlb_nyamlb_1/
# ./data/gid_2017_05_12_seamlb_tormlb_1/
# ./data/gid_2017_08_20_cinmlb_atlmlb_1/
# ./data/gid_2017_08_15_balmlb_seamlb_1/
# ./data/gid_2017_04_22_nyamlb_pitmlb_1/
# ./data/gid_2017_05_26_chnmlb_lanmlb_1/
# ./data/gid_2017_05_31_chnmlb_sdnmlb_1/
# ./data/gid_2017_08_18_lanmlb_detmlb_1/
# ./data/gid_2017_07_23_houmlb_balmlb_1/
# ./data/gid_2017_04_06_atlmlb_nynmlb_1/
# ./data/gid_2017_08_29_detmlb_colmlb_1/
# ./data/gid_2017_06_24_milmlb_atlmlb_1/
# ./data/gid_2017_04_24_tbamlb_balmlb_1/
# ./data/gid_2017_10_07_arimlb_lanmlb_1/
# ./data/gid_2017_05_04_pitmlb_cinmlb_1/
# ./data/gid_2017_08_15_houmlb_arimlb_1/
# ./data/gid_2017_07_18_detmlb_kcamlb_1/
# ./data/gid_2017_06_03_nyamlb_tormlb_1/
# ./data/gid_2017_09_23_kcamlb_chamlb_1/
# ./data/gid_2017_09_24_kcamlb_chamlb_1/
# ./data/gid_2017_09_29_cinmlb_chnmlb_1/
# ./data/gid_2017_09_28_minmlb_clemlb_1/
# ./data/gid_2017_06_18_kcamlb_anamlb_1/
# ./data/gid_2017_06_21_detmlb_seamlb_1/
# ./data/gid_2017_08_29_atlmlb_phimlb_1/
# ./data/gid_2017_06_09_phimlb_slnmlb_1/
# ./data/gid_2017_09_20_clemlb_anamlb_1/
# ./data/gid_2017_06_23_phimlb_arimlb_1/
# ./data/gid_2017_09_12_miamlb_phimlb_1/
# ./data/gid_2017_07_22_chamlb_kcamlb_1/
# ./data/gid_2017_07_06_balmlb_minmlb_1/
# ./data/gid_2017_07_22_sdnmlb_sfnmlb_1/
# ./data/gid_2017_07_05_anamlb_minmlb_1/
# ./data/gid_2017_07_21_oakmlb_nynmlb_1/
# ./data/gid_2017_04_15_anamlb_kcamlb_1/
# ./data/gid_2017_05_03_sfnmlb_lanmlb_1/
# ./data/gid_2017_04_22_tormlb_anamlb_1/
# ./data/gid_2017_05_16_phimlb_texmlb_1/
# ./data/gid_2017_07_16_arimlb_atlmlb_1/
# ./data/gid_2017_07_17_wasmlb_cinmlb_1/
# ./data/gid_2017_06_01_colmlb_seamlb_1/
# ./data/gid_2017_07_14_colmlb_nynmlb_1/
# ./data/gid_2017_09_12_pitmlb_milmlb_1/
# ./data/gid_2017_04_26_sdnmlb_arimlb_1/
# ./data/gid_2017_04_20_arimlb_sdnmlb_1/
# ./data/gid_2017_07_16_slnmlb_pitmlb_1/
# ./data/gid_2017_04_17_tbamlb_bosmlb_1/
# ./data/gid_2017_05_14_phimlb_wasmlb_1/
# ./data/gid_2017_04_17_anamlb_houmlb_1/
# ./data/gid_2017_08_11_atlmlb_slnmlb_1/
# ./data/gid_2017_10_06_ndhmlb_wasmlb_1/
# ./data/gid_2017_07_25_cinmlb_nyamlb_1/
# ./data/gid_2017_07_01_clemlb_detmlb_1/
# ./data/gid_2017_10_06_nyamlb_clemlb_1/
# ./data/gid_2017_06_04_pitmlb_nynmlb_1/
# ./data/gid_2017_09_08_sdnmlb_arimlb_1/
# ./data/gid_2017_07_05_balmlb_milmlb_1/
# ./data/gid_2017_05_14_nynmlb_milmlb_1/
# ./data/gid_2017_09_05_milmlb_cinmlb_1/
# ./data/gid_2017_09_24_slnmlb_pitmlb_1/
# ./data/gid_2017_08_18_chamlb_texmlb_1/
# ./data/gid_2017_04_12_arimlb_sfnmlb_1/
# ./data/gid_2017_10_22_chnmlb_lanmlb_1/
# ./data/gid_2017_07_01_chnmlb_cinmlb_1/
# ./data/gid_2017_04_21_seamlb_oakmlb_1/
# ./data/gid_2017_08_31_tormlb_balmlb_1/
# ./data/gid_2017_07_19_seamlb_houmlb_1/
# ./data/gid_2017_09_20_milmlb_pitmlb_1/
# ./data/gid_2017_08_20_arimlb_minmlb_1/
# ./data/gid_2017_05_28_detmlb_chamlb_1/
# ./data/gid_2017_07_16_nyamlb_bosmlb_1/
# ./data/gid_2017_09_26_sdnmlb_lanmlb_1/
# ./data/gid_2017_09_27_tbamlb_nyamlb_1/
# ./data/gid_2017_04_15_phimlb_wasmlb_1/
# ./data/gid_2017_06_29_nyamlb_chamlb_1/
# ./data/gid_2017_05_23_sdnmlb_nynmlb_1/
# ./data/gid_2017_05_28_nynmlb_pitmlb_1/
# ./data/gid_2017_05_26_oakmlb_nyamlb_1/
# ./data/gid_2017_06_26_phimlb_arimlb_1/
# ./data/gid_2017_08_18_slnmlb_pitmlb_1/
# ./data/gid_2017_05_09_wasmlb_balmlb_1/
# ./data/gid_2017_09_12_detmlb_clemlb_1/
# ./data/gid_2017_08_11_colmlb_miamlb_1/
# ./data/gid_2017_06_14_nyamlb_anamlb_1/
# ./data/gid_2017_07_23_miamlb_cinmlb_1/
# ./data/gid_2017_05_17_oakmlb_seamlb_1/
# ./data/gid_2017_09_13_sdnmlb_minmlb_1/
# ./data/gid_2017_07_25_minmlb_lanmlb_1/
# ./data/gid_2017_05_09_slnmlb_miamlb_1/
# ./data/gid_2017_05_11_minmlb_chamlb_1/
# ./data/gid_2017_06_01_lanmlb_slnmlb_1/
# ./data/gid_2017_05_14_phimlb_wasmlb_2/
# ./data/gid_2017_09_23_miamlb_arimlb_1/
# ./data/gid_2017_04_26_miamlb_phimlb_1/
# ./data/gid_2017_09_26_tbamlb_nyamlb_1/
# ./data/gid_2017_09_13_colmlb_arimlb_1/
# ./data/gid_2017_09_10_cinmlb_nynmlb_1/
# ./data/gid_2017_08_12_minmlb_detmlb_1/
# ./data/gid_2017_05_24_detmlb_houmlb_1/
# ./data/gid_2017_08_13_sfnmlb_wasmlb_2/
# ./data/gid_2017_09_14_tormlb_minmlb_1/
# ./data/gid_2017_06_29_minmlb_bosmlb_1/
# ./data/gid_2017_09_13_lanmlb_sfnmlb_1/
# ./data/gid_2017_09_25_seamlb_oakmlb_1/
# ./data/gid_2017_04_19_anamlb_houmlb_1/
# ./data/gid_2017_10_01_sdnmlb_sfnmlb_1/
# ./data/gid_2017_09_26_wasmlb_phimlb_1/
# ./data/gid_2017_04_21_houmlb_tbamlb_1/
# ./data/gid_2017_07_25_colmlb_slnmlb_1/
# ./data/gid_2017_08_03_phimlb_anamlb_1/
# ./data/gid_2017_07_26_miamlb_texmlb_1/
# ./data/gid_2017_04_09_atlmlb_pitmlb_1/
# ./data/gid_2017_08_12_chnmlb_arimlb_1/
# ./data/gid_2017_04_29_balmlb_nyamlb_1/
# ./data/gid_2017_06_17_chnmlb_pitmlb_1/
# ./data/gid_2017_09_04_clemlb_chamlb_1/
# ./data/gid_2017_07_05_pitmlb_phimlb_1/
# ./data/gid_2017_08_30_slnmlb_milmlb_1/
# ./data/gid_2017_04_22_clemlb_chamlb_1/
# ./data/gid_2017_04_10_houmlb_seamlb_1/
# ./data/gid_2017_07_25_bosmlb_seamlb_1/
# ./data/gid_2017_08_21_seamlb_atlmlb_1/
# ./data/gid_2017_05_13_nynmlb_milmlb_1/
# ./data/gid_2017_08_11_cinmlb_milmlb_1/
# ./data/gid_2017_06_11_oakmlb_tbamlb_1/
# ./data/gid_2017_08_14_tbamlb_tormlb_1/
# ./data/gid_2017_05_26_anamlb_miamlb_1/
# ./data/gid_2017_09_03_tbamlb_chamlb_1/
# ./data/gid_2017_08_24_minmlb_chamlb_1/
# ./data/gid_2017_09_24_phimlb_atlmlb_1/
# ./data/gid_2017_09_27_seamlb_oakmlb_1/
# ./data/gid_2017_04_12_lanmlb_chnmlb_1/
# ./data/gid_2017_04_16_tbamlb_bosmlb_1/
# ./data/gid_2017_08_30_pitmlb_chnmlb_1/
# ./data/gid_2017_08_21_milmlb_sfnmlb_1/
# ./data/gid_2017_04_16_pitmlb_chnmlb_1/
# ./data/gid_2017_08_25_sfnmlb_arimlb_1/
# ./data/gid_2017_08_19_oakmlb_houmlb_1/
# ./data/gid_2017_09_27_wasmlb_phimlb_1/
# ./data/gid_2017_06_15_kcamlb_anamlb_1/
# ./data/gid_2017_05_06_chamlb_balmlb_1/
# ./data/gid_2017_07_14_clemlb_oakmlb_1/
# ./data/gid_2017_07_04_miamlb_slnmlb_1/
# ./data/gid_2017_05_19_phimlb_pitmlb_1/
# ./data/gid_2017_05_31_tbamlb_texmlb_1/
# ./data/gid_2017_05_31_bosmlb_chamlb_1/
# ./data/gid_2017_09_03_arimlb_colmlb_1/
# ./data/gid_2017_04_25_tbamlb_balmlb_1/
# ./data/gid_2017_09_02_cinmlb_pitmlb_1/
# ./data/gid_2017_06_28_kcamlb_detmlb_1/
# ./data/gid_2017_06_01_milmlb_nynmlb_1/
# ./data/gid_2017_06_26_nyamlb_chamlb_1/
# ./data/gid_2017_06_17_chamlb_tormlb_1/
# ./data/gid_2017_09_23_slnmlb_pitmlb_1/
# ./data/gid_2017_07_20_sdnmlb_sfnmlb_1/
# ./data/gid_2017_06_08_sfnmlb_milmlb_1/
# ./data/gid_2017_06_03_sfnmlb_phimlb_1/
# ./data/gid_2017_08_22_lanmlb_pitmlb_1/
# ./data/gid_2017_06_27_chnmlb_wasmlb_1/
# ./data/gid_2017_04_01_cifmin_cinmlb_1/
# ./data/gid_2017_06_12_nyamlb_anamlb_1/
# ./data/gid_2017_06_17_lanmlb_cinmlb_1/
# ./data/gid_2017_09_21_colmlb_sdnmlb_1/
# ./data/gid_2017_07_06_sdnmlb_clemlb_1/
# ./data/gid_2017_05_19_texmlb_detmlb_1/
# ./data/gid_2017_09_04_slnmlb_sdnmlb_1/
# ./data/gid_2017_07_09_sdnmlb_phimlb_1/
# ./data/gid_2017_07_09_miamlb_sfnmlb_1/
# ./data/gid_2017_04_06_miamlb_wasmlb_1/
# ./data/gid_2017_06_04_minmlb_anamlb_1/
# ./data/gid_2017_07_18_seamlb_houmlb_1/
# ./data/gid_2017_07_26_cinmlb_nyamlb_1/
# ./data/gid_2017_07_09_bosmlb_tbamlb_1/
# ./data/gid_2017_06_25_oakmlb_chamlb_1/
# ./data/gid_2017_07_26_oakmlb_tormlb_1/
# ./data/gid_2017_07_17_seamlb_houmlb_1/
# ./data/gid_2017_06_20_slnmlb_phimlb_1/
# ./data/gid_2017_09_25_atlmlb_nynmlb_1/
# ./data/gid_2017_05_19_anamlb_nynmlb_1/
# ./data/gid_2017_06_08_balmlb_wasmlb_1/
# ./data/gid_2017_07_29_atlmlb_phimlb_1/
# ./data/gid_2017_08_25_balmlb_bosmlb_1/
# ./data/gid_2017_04_29_cinmlb_slnmlb_1/
# ./data/gid_2017_07_06_miamlb_slnmlb_1/
# ./data/gid_2017_09_12_atlmlb_wasmlb_1/
# ./data/gid_2017_06_06_slnmlb_cinmlb_1/
# ./data/gid_2017_05_11_houmlb_nyamlb_1/
# ./data/gid_2017_09_20_nynmlb_miamlb_1/
# ./data/gid_2017_09_19_bosmlb_balmlb_1/
# ./data/gid_2017_08_14_atlmlb_colmlb_1/
# ./data/gid_2017_08_31_atlmlb_chnmlb_1/
# ./data/gid_2017_05_21_kcamlb_minmlb_1/
# ./data/gid_2017_04_30_phimlb_lanmlb_1/
# ./data/gid_2017_08_13_houmlb_texmlb_1/
# ./data/gid_2017_06_19_detmlb_seamlb_1/
# ./data/gid_2017_08_06_miamlb_atlmlb_1/
# ./data/gid_2017_05_20_arimlb_sdnmlb_1/
# ./data/gid_2017_09_28_chnmlb_slnmlb_1/
# ./data/gid_2017_08_22_texmlb_anamlb_1/
# ./data/gid_2017_10_20_nyamlb_houmlb_1/
# ./data/gid_2017_05_08_sfnmlb_nynmlb_1/
# ./data/gid_2017_06_01_bosmlb_balmlb_1/
# ./data/gid_2017_08_10_lanmlb_arimlb_1/
# ./data/gid_2017_06_13_oakmlb_miamlb_1/
# ./data/gid_2017_06_18_tbamlb_detmlb_1/
# ./data/gid_2017_06_17_sdnmlb_milmlb_1/
# ./data/gid_2017_08_28_tbamlb_kcamlb_1/
# ./data/gid_2017_08_15_tbamlb_tormlb_1/
# ./data/gid_2017_08_17_clemlb_minmlb_2/
# ./data/gid_2017_10_05_awcmlb_adtmlb_1/
# ./data/gid_2017_09_23_minmlb_detmlb_1/
# ./data/gid_2017_07_23_bosmlb_anamlb_1/
# ./data/gid_2017_04_30_pitmlb_miamlb_1/
# ./data/gid_2017_09_19_milmlb_pitmlb_1/
# ./data/gid_2017_06_05_phimlb_atlmlb_1/
# ./data/gid_2017_08_16_clemlb_minmlb_1/
# ./data/gid_2017_08_27_sfnmlb_arimlb_1/
# ./data/gid_2017_06_06_anamlb_detmlb_1/
# ./data/gid_2017_05_12_balmlb_kcamlb_1/
# ./data/gid_2017_07_08_pitmlb_chnmlb_1/
# ./data/gid_2017_09_30_milmlb_slnmlb_1/
# ./data/gid_2017_05_25_texmlb_bosmlb_1/
# ./data/gid_2017_10_21_nlsmlb_nhsmlb_1/
# ./data/gid_2017_09_06_milmlb_cinmlb_1/
# ./data/gid_2017_05_30_oakmlb_clemlb_1/
# ./data/gid_2017_04_10_oakmlb_kcamlb_1/
# ./data/gid_2017_04_19_sfnmlb_kcamlb_1/
# ./data/gid_2017_08_05_lanmlb_nynmlb_1/
# ./data/gid_2017_08_31_bosmlb_nyamlb_1/
# ./data/gid_2017_08_25_kcamlb_clemlb_1/
# ./data/gid_2017_07_03_cinmlb_colmlb_1/
# ./data/gid_2017_04_04_colmlb_milmlb_1/
# ./data/gid_2017_09_13_cinmlb_slnmlb_1/
# ./data/gid_2017_04_17_sdnmlb_atlmlb_1/
# ./data/gid_2017_07_16_chnmlb_balmlb_1/
# ./data/gid_2017_07_24_nynmlb_sdnmlb_1/
# ./data/gid_2017_05_04_anamlb_seamlb_1/
# ./data/gid_2017_08_25_tbamlb_slnmlb_1/
# ./data/gid_2017_06_29_balmlb_tormlb_1/
# ./data/gid_2017_09_06_wasmlb_miamlb_1/
# ./data/gid_2017_05_09_kcamlb_tbamlb_1/
# ./data/gid_2017_07_15_phimlb_milmlb_1/
# ./data/gid_2017_09_27_anamlb_chamlb_1/
# ./data/gid_2017_05_25_detmlb_houmlb_1/
# ./data/gid_2017_06_09_chamlb_clemlb_1/
# ./data/gid_2017_09_17_chamlb_detmlb_1/
# ./data/gid_2017_09_19_oakmlb_detmlb_1/
# ./data/gid_2017_09_08_milmlb_chnmlb_1/
# ./data/gid_2017_06_05_tormlb_oakmlb_1/
# ./data/gid_2017_05_24_texmlb_bosmlb_1/
# ./data/gid_2017_06_28_minmlb_bosmlb_1/
# ./data/gid_2017_05_05_milmlb_pitmlb_1/
# ./data/gid_2017_07_02_tbamlb_balmlb_1/
# ./data/gid_2017_07_08_balmlb_minmlb_1/
# ./data/gid_2017_04_05_detmlb_chamlb_1/
# ./data/gid_2017_04_27_houmlb_clemlb_1/
# ./data/gid_2017_06_20_sdnmlb_chnmlb_1/
# ./data/gid_2017_10_06_chnmlb_wasmlb_1/
# ./data/gid_2017_07_23_tormlb_clemlb_1/
# ./data/gid_2017_05_04_clemlb_detmlb_1/
# ./data/gid_2017_07_05_kcamlb_seamlb_1/
# ./data/gid_2017_07_31_detmlb_nyamlb_1/
# ./data/gid_2017_08_29_clemlb_nyamlb_1/
# ./data/gid_2017_06_13_nyamlb_anamlb_1/
# ./data/gid_2017_06_28_nynmlb_miamlb_1/
# ./data/gid_2017_04_08_miamlb_nynmlb_1/
# ./data/gid_2017_05_29_atlmlb_anamlb_1/
# ./data/gid_2017_04_25_kcamlb_chamlb_1/
# ./data/gid_2017_07_15_colmlb_nynmlb_1/
# ./data/gid_2017_09_09_phimlb_wasmlb_1/
# ./data/gid_2017_05_23_chamlb_arimlb_1/
# ./data/gid_2017_07_04_bosmlb_texmlb_1/
# ./data/gid_2017_05_18_colmlb_minmlb_1/
# ./data/gid_2017_05_09_seamlb_phimlb_1/
# ./data/gid_2017_05_11_pitmlb_arimlb_1/
# ./data/gid_2017_10_09_lanmlb_arimlb_1/
# ./data/gid_2017_09_05_chnmlb_pitmlb_1/
# ./data/gid_2017_07_15_slnmlb_pitmlb_1/
# ./data/gid_2017_08_23_miamlb_phimlb_1/
# ./data/gid_2017_05_10_sfnmlb_nynmlb_1/
# ./data/gid_2017_04_21_slnmlb_milmlb_1/
# ./data/gid_2017_06_14_kcamlb_sfnmlb_1/
# ./data/gid_2017_07_07_atlmlb_wasmlb_1/
# ./data/gid_2017_07_05_nynmlb_wasmlb_1/
# ./data/gid_2017_05_19_tormlb_balmlb_1/
# ./data/gid_2017_05_06_arimlb_colmlb_1/
# ./data/gid_2017_07_22_tormlb_clemlb_1/
# ./data/gid_2017_07_07_pitmlb_chnmlb_1/
# ./data/gid_2017_07_19_clemlb_sfnmlb_1/
# ./data/gid_2017_08_06_lanmlb_nynmlb_1/
# ./data/gid_2017_06_14_chnmlb_nynmlb_1/
# ./data/gid_2017_10_07_nwcmlb_lanmlb_1/
# ./data/gid_2017_06_06_clemlb_colmlb_1/
# ./data/gid_2017_09_08_balmlb_clemlb_1/
# ./data/gid_2017_08_23_nyamlb_detmlb_1/
# ./data/gid_2017_04_03_colmlb_milmlb_1/
# ./data/gid_2017_06_30_chnmlb_cinmlb_1/
# ./data/gid_2017_04_08_tormlb_tbamlb_1/
# ./data/gid_2017_05_17_lanmlb_sfnmlb_1/
# ./data/gid_2017_05_14_chnmlb_slnmlb_1/
# ./data/gid_2017_08_28_detmlb_colmlb_1/
# ./data/gid_2017_04_25_sdnmlb_arimlb_1/
# ./data/gid_2017_06_04_clemlb_kcamlb_1/
# ./data/gid_2017_06_16_wasmlb_nynmlb_1/
# ./data/gid_2017_09_21_clemlb_anamlb_1/
# ./data/gid_2017_09_13_balmlb_tormlb_1/
# ./data/gid_2017_07_09_detmlb_clemlb_1/
# ./data/gid_2017_08_25_seamlb_nyamlb_1/
# ./data/gid_2017_07_17_phimlb_miamlb_1/
# ./data/gid_2017_05_18_balmlb_detmlb_1/
# ./data/gid_2017_05_02_tormlb_nyamlb_1/
# ./data/gid_2017_10_18_lanmlb_nlsmlb_1/
# ./data/gid_2017_07_30_cinmlb_miamlb_1/
# ./data/gid_2017_08_07_detmlb_pitmlb_1/
# ./data/gid_2017_04_14_milmlb_cinmlb_1/
