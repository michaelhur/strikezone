# %%
import time
import requests
import json
import re

# %%
base_url = "http://statsapi.mlb.com/api/"
alt_base_url = "https://beta-statsapi.mlb.com:443/api/"

# %%
def get_json(url):
    ## get_json: str -> json
    ## get_json() function takes 'url' and returns the response in json format from the MLB Stats API.
    
    response = requests.get(url)
    if (response.status_code != 200):
        print('status code: %s' % response.status_code)
        time.sleep(1.0)
        get_json(url)
    else:
        content = response.content
        json_content = json.loads(content)
        return(json_content)

# %% [markdown]
# #### Functions to pull data from API

# %%
from datetime import datetime 
import pytz

# %%
eastern = pytz.timezone('US/Eastern')
fmt = '%Y-%m-%d'
today = datetime.today().astimezone().strftime(fmt)

# %% [markdown]
# ### Attendance

# %%
def get_attendance(Id,
                teamOrleague = "team",
                date = None,
                startDate = None,
                endDate = None,
                season = None,
                field = "Ytd"):

    url = alt_base_url + 'v1/attendance'
    attedance_field = "attendanceAverage" + field 
    
    attendance_dict = {}
       
    if not any([date, startDate, endDate, season]):
        date = today
    
    if date is not None:
        suffix = "?date={}".format(date)
        
    if (startDate is not None and endDate is None) or (startDate is None and endDate is not None):
        ValueError("Specify both Start Date and End Date in MM/DD/YYYY format.")
        print
        
    if season is not None:
        if type(season) is list:
            suffix = "&season={}".format(','.join(str(s) for s in season))
            
        else:
            suffix = "&season={}".format(season)
            
    
    
    if teamOrleague == "team":
        
        if type(Id) is list:
            ID_str = ','.join(str(i) for i in Id)

        else:
            ID_str = Id

        if teamOrleague == "team":
            suffix = suffix + "&teamId={teamId}".format(teamId = ID_str)
                
        attendance_content = get_json(url + suffix)

        records = attendance_content['records']

        for record in records:
            team = record['team']['id']
            attendance = record[attedance_field]

            if date is not None:
                attendance_dict.update({team: {date: attendance}})
            
            if season is not None:
                if type(season) is list:
                    for s in season:
                        s = record['year']
                        attendance_dict.update({team: {s: attendance}})
                
                else:
                    attendance_dict.update({team: {season: attendance}})
                    
    
    
    if teamOrleague == "league":
        
        if type(Id) is not list:
            Ids = list(Id)
            
        else: 
            Ids = Id
        
        for i in Ids:
            suffix = suffix + "&leagueId={leagueId}".format(leagueId = i)

            attendance_content = get_json(url + suffix)

            records = attendance_content['records']

            for record in records:
                league = i
                attendance = record[attedance_field]

                if date is not None:
                    attendance_dict.update({league: {date: attendance}})
                    
                if season is not None:
                    if type(season) is list:
                        for s in season:
                            s = record['year']
                            attendance_dict.update({league: {s: attendance}})

                    else:
                        attendance_dict.update({league: {season: attendance}})
                        
                        
    return(attendance_dict)

# %%
get_attendance(141, date = "2021-04-01")
# Out:
# {141: {'2021-04-01': 5425}}

# %%
get_attendance([103,104],"league",date = "2021-04-01")
# Out:
# {103: {'2021-04-01': 9155}, 104: {'2021-04-01': 10285}}

# %% [markdown]
# ### Divisions

# %%
def get_division():
    
    division_url = "http://statsapi.mlb.com/api/v1/divisions?sportId=1"
    division_content = get_json(division_url)
    divisions = division_content['divisions']
    
    division_filter = ['id', 'name', 'nameShort', 'abbreviation']
    
    division_list = [{k:v for k,v in d.items() if k in division_filter} for d in divisions]
    
    return(division_list)

# %%
get_division()
# Out:
# [{'id': 200,
#   'name': 'American League West',
#   'nameShort': 'AL West',
#   'abbreviation': 'ALW'},
#  {'id': 201,
#   'name': 'American League East',
#   'nameShort': 'AL East',
#   'abbreviation': 'ALE'},
#  {'id': 202,
#   'name': 'American League Central',
#   'nameShort': 'AL Central',
#   'abbreviation': 'ALC'},
#  {'id': 203,
#   'name': 'National League West',
#   'nameShort': 'NL West',
#   'abbreviation': 'NLW'},
#  {'id': 204,
#   'name': 'National League East',
#   'nameShort': 'NL East',
#   'abbreviation': 'NLE'},
#  {'id': 205,
#   'name': 'National League Central',
#   'nameShort': 'NL Central',
#   'abbreviation': 'NLC'}]

# %%
def lookup_division(divisionId, field = "nameShort"):
    
    division_list = get_division()
    division_wanted = [d[field] for d in division_list if divisionId in d.values()][0]
    
    return(division_wanted)

# %%
lookup_division(200)
# Out:
# 'AL West'

# %% [markdown]
# ### Linescore

# %%
def get_linescore(gamePk):
    
    team_url = base_url + "v1/schedule?gamePk={gamePk}".format(gamePk = gamePk)
    team_content = get_json(team_url)
    
    teams = team_content['dates'][0]['games'][0]['teams']
    
    team_dict = {"teams": {k: {x: y for x,y in v['team'].items() if x == 'id' or x == 'name'} for k, v in teams.items()}}
    
    
    ls_url = base_url + "/v1/game/{gamePk}/linescore".format(gamePk = gamePk)
    linescore_content = get_json(ls_url)
    
    linescore_dict = {}
    
    innings = linescore_content['innings']
    
    for inning in innings:
        inn_count = inning['ordinalNum']
        home = {x: y for x, y in inning['home'].items() if x != 'leftOnBase'} 
        away = {x: y for x, y in inning['away'].items() if x != 'leftOnBase'} 
        
        linescore_dict.update({inn_count: {"home": home, "away": away}})
    
    linescore_dict.update(team_dict)
    
    return(linescore_dict)

# %%
get_linescore(634645)
# Out:
# {'1st': {'home': {'runs': 2, 'hits': 3, 'errors': 0},
#   'away': {'runs': 0, 'hits': 1, 'errors': 0}},
#  '2nd': {'home': {'runs': 1, 'hits': 1, 'errors': 0},
#   'away': {'runs': 0, 'hits': 0, 'errors': 1}},
#  '3rd': {'home': {'runs': 0, 'hits': 0, 'errors': 0},
#   'away': {'runs': 0, 'hits': 0, 'errors': 0}},
#  '4th': {'home': {'runs': 0, 'hits': 0, 'errors': 0},
#   'away': {'runs': 0, 'hits': 1, 'errors': 0}},
#  '5th': {'home': {'runs': 0, 'hits': 1, 'errors': 0},
#   'away': {'runs': 0, 'hits': 0, 'errors': 0}},
#  '6th': {'home': {'runs': 0, 'hits': 0, 'errors': 0},
#   'away': {'runs': 0, 'hits': 1, 'errors': 0}},
#  '7th': {'home': {'runs': 0, 'hits': 0, 'errors': 0},
#   'away': {'runs': 0, 'hits': 0, 'errors': 0}},
#  '8th': {'home': {'runs': 0, 'hits': 0, 'errors': 0},
#   'away': {'runs': 0, 'hits': 1, 'errors': 0}},
#  '9th': {'home': {'hits': 0, 'errors': 0},
#   'away': {'runs': 2, 'hits': 2, 'errors': 0}},
#  'teams': {'away': {'id': 114, 'name': 'Cleveland Indians'},
#   'home': {'id': 116, 'name': 'Detroit Tigers'}}}

# %% [markdown]
# ### Pitch f/x

# %%
def get_pitchfx(gamePk):
    
    bs_url = base_url + "/v1/game/{gamePk}/boxscore".format(gamePk = gamePk)
    bs_content = get_json(bs_url)
    bs_info = bs_content['info']

    umpires = [l for l in bs_info if l['label'] == "Umpires"][0]['value']
    home_umpire = re.findall("HP: [\w \.]+ 1B:", umpires)[0].lstrip("HP: ").rstrip(". 1B:")
    

    pbp_url = base_url + "/v1/game/{gamePk}/playByPlay".format(gamePk = gamePk)
    pbp_content = get_json(pbp_url)
    
    allPlays = pbp_content['allPlays']
       
    atBat_dict = {"home_umpire": home_umpire}
    
    for play in allPlays:
                
        about = play['about']
        
        atBat_count = about['atBatIndex']        
        inning = about['inning']
        home = "home" if about['isTopInning'] else "away"
        
        matchup = play['matchup']
        pitcher = matchup['pitcher']
        batter = matchup['batter']
        pitchHand = matchup['pitchHand']['code']
        batSide = matchup['batSide']['code']      
        
        """
        matchup_dict = {'pitcher': pitcher,
                       'batter': batter,
                       'pitchHand': pitchHand,
                       'batSide': batSide}
        """
        atBat_dict.update({atBat_count: {"inning": inning, 
                                         "home": home, 
                                         'pitcher': pitcher,
                                         'batter': batter,
                                         'pitchHand': pitchHand,
                                         'batSide': batSide}})
        
        events = play['playEvents']     
        pitched_events = (event for event in events if event['isPitch'])
        
        pitch_list = []
        
        for event in pitched_events:
            
            if not event['isPitch']:
                continue
            
            """
            if event['details']['isInPlay']:
                continue
            
            strike = event['details']['isStrike']
            
            pitch_index = event['index']
            """
            
            strike = "strike" if not event['details']['isBall'] else "ball"
            
            pitch_data = event['pitchData']
            
            sz_top = pitch_data['strikeZoneTop']
            sz_bottom = pitch_data['strikeZoneBottom']
            x = pitch_data['coordinates']['pX']
            z = pitch_data['coordinates']['pZ']
            
            #pitch_dict = {pitch_index: {'call': strike, 'sz_top': sz_top, 'sz_bottom': sz_bottom, 'x': x, 'z': z}}
            pitch_list.append({'call': strike, 'sz_top': sz_top, 'sz_bottom': sz_bottom, 'x': x, 'z': z})
            
        atBat_dict[atBat_count]['pitchData'] = pitch_list
            
    return(atBat_dict)

# %%
get_pitchfx(634583)
# Out:
# {'home_umpire': 'Ed Hickox',
#  0: {'inning': 1,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 543760,
#    'fullName': 'Marcus Semien',
#    'link': '/api/v1/people/543760'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': 0.02,
#     'z': 3.3}]},
#  1: {'inning': 1,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 624415,
#    'fullName': 'Cavan Biggio',
#    'link': '/api/v1/people/624415'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.51,
#     'sz_bottom': 1.61,
#     'x': -0.15,
#     'z': 2.45},
#    {'call': 'ball', 'sz_top': 3.42, 'sz_bottom': 1.59, 'x': -0.74, 'z': 4.41},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.17,
#     'z': 2.23},
#    {'call': 'ball', 'sz_top': 3.48, 'sz_bottom': 1.59, 'x': 1.72, 'z': 0.76},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.59,
#     'x': 0.73,
#     'z': 2.82}]},
#  2: {'inning': 1,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 666182,
#    'fullName': 'Bo Bichette',
#    'link': '/api/v1/people/666182'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.61,
#     'sz_bottom': 1.7,
#     'x': 0.72,
#     'z': 2.05},
#    {'call': 'ball', 'sz_top': 3.52, 'sz_bottom': 1.66, 'x': 1.09, 'z': 1.6},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.53, 'x': 0.57, 'z': 1.97},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': 0.77,
#     'z': 2.05}]},
#  3: {'inning': 1,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 643396,
#    'fullName': 'Isiah Kiner-Falefa',
#    'link': '/api/v1/people/643396'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.44,
#     'sz_bottom': 1.66,
#     'x': -0.41,
#     'z': 2.57},
#    {'call': 'ball', 'sz_top': 3.27, 'sz_bottom': 1.51, 'x': -0.37, 'z': 4.15},
#    {'call': 'strike', 'sz_top': 3.18, 'sz_bottom': 1.51, 'x': 0.42, 'z': 1.78},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.53,
#     'z': 2.96},
#    {'call': 'strike', 'sz_top': 3.32, 'sz_bottom': 1.51, 'x': 0.77, 'z': 1.55},
#    {'call': 'ball', 'sz_top': 3.23, 'sz_bottom': 1.51, 'x': -0.18, 'z': 4.57},
#    {'call': 'strike',
#     'sz_top': 3.22,
#     'sz_bottom': 1.51,
#     'x': -0.81,
#     'z': 2.06}]},
#  4: {'inning': 1,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 621311,
#    'fullName': 'David Dahl',
#    'link': '/api/v1/people/621311'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.28,
#     'sz_bottom': 1.59,
#     'x': 0.13,
#     'z': 1.98},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.47,
#     'z': 2.31},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -1.84,
#     'z': 1.94}]},
#  5: {'inning': 1,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 608336,
#    'fullName': 'Joey Gallo',
#    'link': '/api/v1/people/608336'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.57,
#     'sz_bottom': 1.68,
#     'x': -1.62,
#     'z': 1.86},
#    {'call': 'strike', 'sz_top': 3.58, 'sz_bottom': 1.68, 'x': -0.45, 'z': 2.7},
#    {'call': 'ball', 'sz_top': 3.31, 'sz_bottom': 1.58, 'x': 0.71, 'z': 1.79},
#    {'call': 'strike', 'sz_top': 3.58, 'sz_bottom': 1.68, 'x': 0.04, 'z': 2.63},
#    {'call': 'strike',
#     'sz_top': 3.58,
#     'sz_bottom': 1.68,
#     'x': -1.25,
#     'z': 0.73}]},
#  6: {'inning': 2,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 606192,
#    'fullName': 'Teoscar Hernandez',
#    'link': '/api/v1/people/606192'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.73,
#     'z': 3.36}]},
#  7: {'inning': 2,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 665489,
#    'fullName': 'Vladimir Guerrero Jr.',
#    'link': '/api/v1/people/665489'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.57,
#     'sz_bottom': 1.62,
#     'x': -0.11,
#     'z': 3.04},
#    {'call': 'ball', 'sz_top': 3.61, 'sz_bottom': 1.61, 'x': 1.56, 'z': 1.57},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.7,
#     'z': 2.02}]},
#  8: {'inning': 2,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 666971,
#    'fullName': 'Lourdes Gurriel Jr.',
#    'link': '/api/v1/people/666971'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.44,
#     'sz_bottom': 1.63,
#     'x': -0.12,
#     'z': 1.78},
#    {'call': 'ball', 'sz_top': 3.48, 'sz_bottom': 1.63, 'x': 1.76, 'z': 1.11},
#    {'call': 'strike', 'sz_top': 3.55, 'sz_bottom': 1.63, 'x': 0.45, 'z': 2.15},
#    {'call': 'ball', 'sz_top': 3.44, 'sz_bottom': 1.63, 'x': 0.44, 'z': 1.0},
#    {'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': -0.46,
#     'z': 1.93},
#    {'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': -0.07,
#     'z': 1.52}]},
#  9: {'inning': 2,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 545341,
#    'fullName': 'Randal Grichuk',
#    'link': '/api/v1/people/545341'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.14,
#     'sz_bottom': 1.42,
#     'x': 1.25,
#     'z': 0.27},
#    {'call': 'strike', 'sz_top': 3.2, 'sz_bottom': 1.56, 'x': 0.76, 'z': 2.43},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.28,
#     'z': 3.13},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 1.02,
#     'z': 2.69}]},
#  10: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 669256,
#    'fullName': 'Nick Solak',
#    'link': '/api/v1/people/669256'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.35,
#     'sz_bottom': 1.59,
#     'x': 0.63,
#     'z': 2.88},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.3,
#     'z': 2.55}]},
#  11: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 663993,
#    'fullName': 'Nate Lowe',
#    'link': '/api/v1/people/663993'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.34,
#     'sz_bottom': 1.48,
#     'x': -0.39,
#     'z': 1.73},
#    {'call': 'strike',
#     'sz_top': 3.42,
#     'sz_bottom': 1.61,
#     'x': -0.74,
#     'z': 2.35},
#    {'call': 'strike',
#     'sz_top': 3.48,
#     'sz_bottom': 1.61,
#     'x': -0.84,
#     'z': 2.75}]},
#  12: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 624431,
#    'fullName': 'Jose Trevino',
#    'link': '/api/v1/people/624431'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.28,
#     'z': 2.03}]},
#  13: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 642201,
#    'fullName': 'Eli White',
#    'link': '/api/v1/people/642201'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.71,
#     'sz_bottom': 1.76,
#     'x': 1.03,
#     'z': 3.86},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.6, 'x': 0.28, 'z': 1.39},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.6, 'x': 1.2, 'z': 2.47},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.6, 'x': 0.8, 'z': 1.86}]},
#  14: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 665750,
#    'fullName': 'Leody Taveras',
#    'link': '/api/v1/people/665750'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.87,
#     'z': 2.77}]},
#  15: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 518586,
#    'fullName': 'Charlie Culberson',
#    'link': '/api/v1/people/518586'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.35,
#     'sz_bottom': 1.56,
#     'x': 0.47,
#     'z': 1.87},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': 0.9,
#     'z': 2.08}]},
#  16: {'inning': 2,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 643396,
#    'fullName': 'Isiah Kiner-Falefa',
#    'link': '/api/v1/people/643396'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.32,
#     'z': 3.93},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.67,
#     'z': 2.89}]},
#  17: {'inning': 3,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 605412,
#    'fullName': 'Joe Panik',
#    'link': '/api/v1/people/605412'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.17,
#     'sz_bottom': 1.31,
#     'x': -0.78,
#     'z': 2.36},
#    {'call': 'ball', 'sz_top': 3.12, 'sz_bottom': 1.39, 'x': -1.18, 'z': 2.58},
#    {'call': 'ball', 'sz_top': 3.19, 'sz_bottom': 1.37, 'x': -1.51, 'z': 2.26},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': -0.66,
#     'z': 2.34}]},
#  18: {'inning': 3,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 643376,
#    'fullName': 'Danny Jansen',
#    'link': '/api/v1/people/643376'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.71,
#     'z': 1.9},
#    {'call': 'ball', 'sz_top': 3.17, 'sz_bottom': 1.55, 'x': 0.49, 'z': 1.41},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.41, 'z': 1.78},
#    {'call': 'ball', 'sz_top': 3.16, 'sz_bottom': 1.5, 'x': 1.62, 'z': 0.64},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.43,
#     'z': 3.16}]},
#  19: {'inning': 3,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 543760,
#    'fullName': 'Marcus Semien',
#    'link': '/api/v1/people/543760'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.36,
#     'sz_bottom': 1.53,
#     'x': 1.74,
#     'z': 1.46},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': 0.44,
#     'z': 2.78}]},
#  20: {'inning': 3,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 624415,
#    'fullName': 'Cavan Biggio',
#    'link': '/api/v1/people/624415'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.5,
#     'z': 2.21},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.03,
#     'z': 3.51}]},
#  21: {'inning': 3,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 666182,
#    'fullName': 'Bo Bichette',
#    'link': '/api/v1/people/666182'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.7,
#     'sz_bottom': 1.8,
#     'x': 1.09,
#     'z': 2.51},
#    {'call': 'ball', 'sz_top': 3.6, 'sz_bottom': 1.66, 'x': -1.77, 'z': 3.07},
#    {'call': 'ball', 'sz_top': 3.6, 'sz_bottom': 1.7, 'x': 1.03, 'z': 2.67},
#    {'call': 'strike', 'sz_top': 3.61, 'sz_bottom': 1.62, 'x': 0.27, 'z': 1.75},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': -0.39,
#     'z': 3.42},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': -0.44,
#     'z': 2.38}]},
#  22: {'inning': 3,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 621311,
#    'fullName': 'David Dahl',
#    'link': '/api/v1/people/621311'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.34,
#     'sz_bottom': 1.59,
#     'x': -0.39,
#     'z': 1.49},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.54, 'z': 3.18},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -1.07,
#     'z': 1.93}]},
#  23: {'inning': 3,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 608336,
#    'fullName': 'Joey Gallo',
#    'link': '/api/v1/people/608336'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.65,
#     'sz_bottom': 1.68,
#     'x': -0.45,
#     'z': 2.11},
#    {'call': 'ball', 'sz_top': 3.51, 'sz_bottom': 1.55, 'x': -0.53, 'z': 3.3},
#    {'call': 'strike',
#     'sz_top': 3.58,
#     'sz_bottom': 1.68,
#     'x': 0.47,
#     'z': 1.63}]},
#  24: {'inning': 3,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 669256,
#    'fullName': 'Nick Solak',
#    'link': '/api/v1/people/669256'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 0.75,
#     'z': 2.2},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 0.73,
#     'z': 2.06}]},
#  25: {'inning': 4,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 606192,
#    'fullName': 'Teoscar Hernandez',
#    'link': '/api/v1/people/606192'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -1.51,
#     'z': 2.55},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.85, 'z': 1.28},
#    {'call': 'ball', 'sz_top': 3.38, 'sz_bottom': 1.59, 'x': 1.95, 'z': 0.73},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.87, 'z': 2.24},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.76, 'z': 3.77},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -1.09,
#     'z': 2.25},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.62,
#     'z': 2.41},
#    {'call': 'ball', 'sz_top': 3.41, 'sz_bottom': 1.59, 'x': 1.13, 'z': 1.33},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.28,
#     'z': 1.07}]},
#  26: {'inning': 4,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 665489,
#    'fullName': 'Vladimir Guerrero Jr.',
#    'link': '/api/v1/people/665489'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.57,
#     'sz_bottom': 1.59,
#     'x': 1.13,
#     'z': 1.7},
#    {'call': 'strike', 'sz_top': 3.52, 'sz_bottom': 1.59, 'x': 0.57, 'z': 2.91},
#    {'call': 'strike', 'sz_top': 3.52, 'sz_bottom': 1.59, 'x': 0.58, 'z': 1.62},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.57,
#     'z': 0.34}]},
#  27: {'inning': 4,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 666971,
#    'fullName': 'Lourdes Gurriel Jr.',
#    'link': '/api/v1/people/666971'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': 0.96,
#     'z': 1.04},
#    {'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': 0.29,
#     'z': 1.63}]},
#  28: {'inning': 4,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 663993,
#    'fullName': 'Nate Lowe',
#    'link': '/api/v1/people/663993'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.37,
#     'sz_bottom': 1.52,
#     'x': -1.09,
#     'z': 2.06},
#    {'call': 'strike', 'sz_top': 3.48, 'sz_bottom': 1.61, 'x': 0.69, 'z': 3.1},
#    {'call': 'strike', 'sz_top': 3.48, 'sz_bottom': 1.61, 'x': 0.51, 'z': 2.0},
#    {'call': 'strike', 'sz_top': 3.48, 'sz_bottom': 1.61, 'x': 0.72, 'z': 1.92},
#    {'call': 'ball', 'sz_top': 3.43, 'sz_bottom': 1.61, 'x': -0.91, 'z': 1.34},
#    {'call': 'strike',
#     'sz_top': 3.48,
#     'sz_bottom': 1.61,
#     'x': 0.59,
#     'z': 2.49}]},
#  29: {'inning': 4,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 624431,
#    'fullName': 'Jose Trevino',
#    'link': '/api/v1/people/624431'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 2.98,
#     'sz_bottom': 1.41,
#     'x': 1.21,
#     'z': 2.11},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 0.36,
#     'z': 2.68}]},
#  30: {'inning': 4,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 642201,
#    'fullName': 'Eli White',
#    'link': '/api/v1/people/642201'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.68,
#     'sz_bottom': 1.73,
#     'x': 0.0,
#     'z': 2.55},
#    {'call': 'ball', 'sz_top': 3.68, 'sz_bottom': 1.6, 'x': -0.44, 'z': 4.22},
#    {'call': 'ball', 'sz_top': 3.69, 'sz_bottom': 1.69, 'x': 1.39, 'z': 3.45},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.6, 'x': 0.64, 'z': 2.28},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.6,
#     'x': 0.28,
#     'z': 2.19}]},
#  31: {'inning': 5,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 545341,
#    'fullName': 'Randal Grichuk',
#    'link': '/api/v1/people/545341'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.12,
#     'sz_bottom': 1.42,
#     'x': 1.57,
#     'z': 2.37},
#    {'call': 'strike', 'sz_top': 3.17, 'sz_bottom': 1.42, 'x': 0.12, 'z': 1.82},
#    {'call': 'ball', 'sz_top': 3.17, 'sz_bottom': 1.46, 'x': 0.68, 'z': 1.24},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.06,
#     'z': 2.88}]},
#  32: {'inning': 5,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 605412,
#    'fullName': 'Joe Panik',
#    'link': '/api/v1/people/605412'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': -0.8,
#     'z': 2.49}]},
#  33: {'inning': 5,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 643376,
#    'fullName': 'Danny Jansen',
#    'link': '/api/v1/people/643376'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.19,
#     'sz_bottom': 1.52,
#     'x': -0.61,
#     'z': 3.54},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.17,
#     'z': 2.09},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.14, 'z': 2.16},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.01,
#     'z': 2.41}]},
#  34: {'inning': 5,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 543760,
#    'fullName': 'Marcus Semien',
#    'link': '/api/v1/people/543760'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.22,
#     'sz_bottom': 1.53,
#     'x': 2.61,
#     'z': 0.34},
#    {'call': 'ball', 'sz_top': 3.36, 'sz_bottom': 1.53, 'x': 1.08, 'z': 1.56},
#    {'call': 'ball', 'sz_top': 3.29, 'sz_bottom': 1.53, 'x': 1.48, 'z': 1.37},
#    {'call': 'strike', 'sz_top': 3.24, 'sz_bottom': 1.44, 'x': 0.88, 'z': 1.37},
#    {'call': 'ball', 'sz_top': 3.34, 'sz_bottom': 1.53, 'x': 0.07, 'z': 1.24}]},
#  35: {'inning': 5,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 624415,
#    'fullName': 'Cavan Biggio',
#    'link': '/api/v1/people/624415'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.46,
#     'z': 1.99}]},
#  36: {'inning': 5,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 665750,
#    'fullName': 'Leody Taveras',
#    'link': '/api/v1/people/665750'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.48,
#     'sz_bottom': 1.59,
#     'x': -0.39,
#     'z': 2.37},
#    {'call': 'ball', 'sz_top': 3.5, 'sz_bottom': 1.59, 'x': 1.18, 'z': 1.59},
#    {'call': 'strike', 'sz_top': 3.44, 'sz_bottom': 1.59, 'x': 0.66, 'z': 2.12},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.59,
#     'x': 0.59,
#     'z': 1.43}]},
#  37: {'inning': 5,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 518586,
#    'fullName': 'Charlie Culberson',
#    'link': '/api/v1/people/518586'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.3,
#     'sz_bottom': 1.75,
#     'x': -0.5,
#     'z': 1.5},
#    {'call': 'strike', 'sz_top': 3.41, 'sz_bottom': 1.56, 'x': -0.4, 'z': 3.17},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': -0.7,
#     'z': 2.74}]},
#  38: {'inning': 5,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 643396,
#    'fullName': 'Isiah Kiner-Falefa',
#    'link': '/api/v1/people/643396'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 1.37,
#     'z': 2.3},
#    {'call': 'ball', 'sz_top': 3.25, 'sz_bottom': 1.51, 'x': -0.11, 'z': 3.37},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.21,
#     'z': 2.99}]},
#  39: {'inning': 5,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 621311,
#    'fullName': 'David Dahl',
#    'link': '/api/v1/people/621311'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.39,
#     'z': 3.08}]},
#  40: {'inning': 6,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 666182,
#    'fullName': 'Bo Bichette',
#    'link': '/api/v1/people/666182'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.47,
#     'sz_bottom': 1.66,
#     'x': 1.22,
#     'z': 1.21},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': 0.55,
#     'z': 2.3}]},
#  41: {'inning': 6,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 606192,
#    'fullName': 'Teoscar Hernandez',
#    'link': '/api/v1/people/606192'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.3,
#     'sz_bottom': 1.59,
#     'x': 0.5,
#     'z': 2.2},
#    {'call': 'ball', 'sz_top': 3.48, 'sz_bottom': 1.59, 'x': -1.26, 'z': 3.27},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 1.05, 'z': 0.77},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.35, 'z': 2.34},
#    {'call': 'strike',
#     'sz_top': 3.51,
#     'sz_bottom': 1.59,
#     'x': 0.7,
#     'z': 2.36}]},
#  42: {'inning': 6,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 665489,
#    'fullName': 'Vladimir Guerrero Jr.',
#    'link': '/api/v1/people/665489'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.39,
#     'z': 2.08}]},
#  43: {'inning': 6,
#   'home': 'home',
#   'pitcher': {'id': 502043,
#    'fullName': 'Kyle Gibson',
#    'link': '/api/v1/people/502043'},
#   'batter': {'id': 666971,
#    'fullName': 'Lourdes Gurriel Jr.',
#    'link': '/api/v1/people/666971'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': 0.52,
#     'z': 2.56}]},
#  44: {'inning': 6,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 608336,
#    'fullName': 'Joey Gallo',
#    'link': '/api/v1/people/608336'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.58,
#     'sz_bottom': 1.68,
#     'x': 0.01,
#     'z': 2.11},
#    {'call': 'ball', 'sz_top': 3.61, 'sz_bottom': 1.68, 'x': -1.27, 'z': 2.2},
#    {'call': 'strike',
#     'sz_top': 3.58,
#     'sz_bottom': 1.68,
#     'x': -1.03,
#     'z': 2.5}]},
#  45: {'inning': 6,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 669256,
#    'fullName': 'Nick Solak',
#    'link': '/api/v1/people/669256'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 0.07,
#     'z': 1.83},
#    {'call': 'strike', 'sz_top': 3.38, 'sz_bottom': 1.56, 'x': 0.81, 'z': 1.84},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 0.62,
#     'z': 1.99}]},
#  46: {'inning': 6,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 663993,
#    'fullName': 'Nate Lowe',
#    'link': '/api/v1/people/663993'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.63,
#     'x': -0.31,
#     'z': 1.66},
#    {'call': 'ball', 'sz_top': 3.41, 'sz_bottom': 1.61, 'x': -1.14, 'z': 1.94},
#    {'call': 'strike',
#     'sz_top': 3.48,
#     'sz_bottom': 1.61,
#     'x': -0.67,
#     'z': 2.82},
#    {'call': 'strike',
#     'sz_top': 3.48,
#     'sz_bottom': 1.61,
#     'x': -0.42,
#     'z': 2.75}]},
#  47: {'inning': 7,
#   'home': 'home',
#   'pitcher': {'id': 622250,
#    'fullName': 'Josh Sborz',
#    'link': '/api/v1/people/622250'},
#   'batter': {'id': 545341,
#    'fullName': 'Randal Grichuk',
#    'link': '/api/v1/people/545341'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.06,
#     'z': 2.55},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.17, 'z': 3.32},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 1.22,
#     'z': 2.4}]},
#  48: {'inning': 7,
#   'home': 'home',
#   'pitcher': {'id': 622250,
#    'fullName': 'Josh Sborz',
#    'link': '/api/v1/people/622250'},
#   'batter': {'id': 605412,
#    'fullName': 'Joe Panik',
#    'link': '/api/v1/people/605412'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': 0.22,
#     'z': 3.31},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': -0.63,
#     'z': 3.52}]},
#  49: {'inning': 7,
#   'home': 'home',
#   'pitcher': {'id': 622250,
#    'fullName': 'Josh Sborz',
#    'link': '/api/v1/people/622250'},
#   'batter': {'id': 643376,
#    'fullName': 'Danny Jansen',
#    'link': '/api/v1/people/643376'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.19,
#     'sz_bottom': 1.44,
#     'x': 0.74,
#     'z': 1.24},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.65,
#     'z': 2.72}]},
#  50: {'inning': 7,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 624431,
#    'fullName': 'Jose Trevino',
#    'link': '/api/v1/people/624431'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 2.98,
#     'sz_bottom': 1.36,
#     'x': 0.01,
#     'z': 1.86},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': 0.41,
#     'z': 2.37}]},
#  51: {'inning': 7,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 642201,
#    'fullName': 'Eli White',
#    'link': '/api/v1/people/642201'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.6,
#     'x': 0.61,
#     'z': 1.58},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.6, 'x': -0.51, 'z': 1.67},
#    {'call': 'ball', 'sz_top': 3.66, 'sz_bottom': 1.66, 'x': 0.51, 'z': 0.96},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.6,
#     'x': 0.48,
#     'z': 1.89}]},
#  52: {'inning': 7,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 665750,
#    'fullName': 'Leody Taveras',
#    'link': '/api/v1/people/665750'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 0.67,
#     'z': 3.51}]},
#  53: {'inning': 7,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 518586,
#    'fullName': 'Charlie Culberson',
#    'link': '/api/v1/people/518586'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.29,
#     'sz_bottom': 1.56,
#     'x': 0.42,
#     'z': 1.96},
#    {'call': 'ball', 'sz_top': 3.24, 'sz_bottom': 1.53, 'x': 0.88, 'z': 3.3},
#    {'call': 'ball', 'sz_top': 3.34, 'sz_bottom': 1.56, 'x': 1.41, 'z': 1.85},
#    {'call': 'ball', 'sz_top': 3.27, 'sz_bottom': 1.47, 'x': 1.53, 'z': 2.56},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': -1.04,
#     'z': 2.32},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': 0.17,
#     'z': 2.99}]},
#  54: {'inning': 7,
#   'home': 'away',
#   'pitcher': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'batter': {'id': 643396,
#    'fullName': 'Isiah Kiner-Falefa',
#    'link': '/api/v1/people/643396'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.19,
#     'sz_bottom': 1.51,
#     'x': -1.16,
#     'z': 0.61},
#    {'call': 'ball', 'sz_top': 3.06, 'sz_bottom': 1.42, 'x': 1.16, 'z': 2.41},
#    {'call': 'strike', 'sz_top': 3.32, 'sz_bottom': 1.51, 'x': 0.73, 'z': 2.49},
#    {'call': 'strike', 'sz_top': 3.32, 'sz_bottom': 1.51, 'x': 0.55, 'z': 1.0},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.83,
#     'z': 1.82}]},
#  55: {'inning': 8,
#   'home': 'home',
#   'pitcher': {'id': 456713,
#    'fullName': 'Matt Bush',
#    'link': '/api/v1/people/456713'},
#   'batter': {'id': 543760,
#    'fullName': 'Marcus Semien',
#    'link': '/api/v1/people/543760'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.26,
#     'sz_bottom': 1.53,
#     'x': 1.49,
#     'z': 0.4},
#    {'call': 'ball', 'sz_top': 3.2, 'sz_bottom': 1.53, 'x': 1.36, 'z': -0.73},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': -0.47,
#     'z': 3.54},
#    {'call': 'ball', 'sz_top': 3.26, 'sz_bottom': 1.53, 'x': 0.42, 'z': 1.04},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': -0.65,
#     'z': 1.95}]},
#  56: {'inning': 8,
#   'home': 'home',
#   'pitcher': {'id': 456713,
#    'fullName': 'Matt Bush',
#    'link': '/api/v1/people/456713'},
#   'batter': {'id': 624415,
#    'fullName': 'Cavan Biggio',
#    'link': '/api/v1/people/624415'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.42,
#     'sz_bottom': 1.59,
#     'x': -0.31,
#     'z': 2.57},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.05, 'z': 1.54},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.77,
#     'z': 3.54},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.02, 'z': 3.45},
#    {'call': 'ball', 'sz_top': 3.47, 'sz_bottom': 1.53, 'x': 0.5, 'z': -0.9},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.48,
#     'z': 2.94}]},
#  57: {'inning': 8,
#   'home': 'home',
#   'pitcher': {'id': 456713,
#    'fullName': 'Matt Bush',
#    'link': '/api/v1/people/456713'},
#   'batter': {'id': 666182,
#    'fullName': 'Bo Bichette',
#    'link': '/api/v1/people/666182'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.57,
#     'sz_bottom': 1.63,
#     'x': 0.44,
#     'z': 1.58},
#    {'call': 'ball', 'sz_top': 3.56, 'sz_bottom': 1.67, 'x': 1.24, 'z': 0.07},
#    {'call': 'strike', 'sz_top': 3.37, 'sz_bottom': 1.53, 'x': 0.31, 'z': 3.57},
#    {'call': 'strike',
#     'sz_top': 3.37,
#     'sz_bottom': 1.53,
#     'x': 1.14,
#     'z': 1.42}]},
#  58: {'inning': 8,
#   'home': 'home',
#   'pitcher': {'id': 456713,
#    'fullName': 'Matt Bush',
#    'link': '/api/v1/people/456713'},
#   'batter': {'id': 606192,
#    'fullName': 'Teoscar Hernandez',
#    'link': '/api/v1/people/606192'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.47,
#     'sz_bottom': 1.61,
#     'x': 1.98,
#     'z': 1.94},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.22, 'z': 3.15},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': 0.05, 'z': 3.18},
#    {'call': 'ball', 'sz_top': 3.31, 'sz_bottom': 1.59, 'x': 0.99, 'z': 1.77},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': 1.43,
#     'z': 1.1}]},
#  59: {'inning': 8,
#   'home': 'home',
#   'pitcher': {'id': 456713,
#    'fullName': 'Matt Bush',
#    'link': '/api/v1/people/456713'},
#   'batter': {'id': 665489,
#    'fullName': 'Vladimir Guerrero Jr.',
#    'link': '/api/v1/people/665489'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.5,
#     'sz_bottom': 1.59,
#     'x': 1.0,
#     'z': 1.15},
#    {'call': 'ball', 'sz_top': 3.53, 'sz_bottom': 1.59, 'x': 1.44, 'z': 1.92},
#    {'call': 'ball', 'sz_top': 3.49, 'sz_bottom': 1.59, 'x': 1.74, 'z': 0.53},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.64,
#     'z': 3.21}]},
#  60: {'inning': 8,
#   'home': 'away',
#   'pitcher': {'id': 641835,
#    'fullName': 'Tim Mayza',
#    'link': '/api/v1/people/641835'},
#   'batter': {'id': 621311,
#    'fullName': 'David Dahl',
#    'link': '/api/v1/people/621311'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.23,
#     'sz_bottom': 1.55,
#     'x': -0.73,
#     'z': 2.81},
#    {'call': 'strike', 'sz_top': 3.47, 'sz_bottom': 1.59, 'x': -1.19, 'z': 2.5},
#    {'call': 'ball', 'sz_top': 3.27, 'sz_bottom': 1.59, 'x': -2.06, 'z': 2.33},
#    {'call': 'ball', 'sz_top': 3.32, 'sz_bottom': 1.59, 'x': -1.07, 'z': 1.54},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -1.14,
#     'z': 1.54}]},
#  61: {'inning': 8,
#   'home': 'away',
#   'pitcher': {'id': 641835,
#    'fullName': 'Tim Mayza',
#    'link': '/api/v1/people/641835'},
#   'batter': {'id': 608336,
#    'fullName': 'Joey Gallo',
#    'link': '/api/v1/people/608336'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.58,
#     'sz_bottom': 1.68,
#     'x': 0.4,
#     'z': 2.31}]},
#  62: {'inning': 8,
#   'home': 'away',
#   'pitcher': {'id': 641835,
#    'fullName': 'Tim Mayza',
#    'link': '/api/v1/people/641835'},
#   'batter': {'id': 669256,
#    'fullName': 'Nick Solak',
#    'link': '/api/v1/people/669256'},
#   'pitchHand': 'L',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -2.48,
#     'z': 2.49}]},
#  63: {'inning': 8,
#   'home': 'away',
#   'pitcher': {'id': 641835,
#    'fullName': 'Tim Mayza',
#    'link': '/api/v1/people/641835'},
#   'batter': {'id': 663993,
#    'fullName': 'Nate Lowe',
#    'link': '/api/v1/people/663993'},
#   'pitchHand': 'L',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.48,
#     'sz_bottom': 1.61,
#     'x': 1.17,
#     'z': 2.97}]},
#  64: {'inning': 8,
#   'home': 'away',
#   'pitcher': {'id': 503569,
#    'fullName': 'Rafael Dolis',
#    'link': '/api/v1/people/503569'},
#   'batter': {'id': 624431,
#    'fullName': 'Jose Trevino',
#    'link': '/api/v1/people/624431'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.02,
#     'sz_bottom': 1.38,
#     'x': -0.63,
#     'z': 3.54},
#    {'call': 'strike', 'sz_top': 2.87, 'sz_bottom': 1.3, 'x': -0.09, 'z': 1.57},
#    {'call': 'strike', 'sz_top': 3.32, 'sz_bottom': 1.51, 'x': -0.1, 'z': 2.96},
#    {'call': 'strike',
#     'sz_top': 3.32,
#     'sz_bottom': 1.51,
#     'x': -0.9,
#     'z': 2.29}]},
#  65: {'inning': 9,
#   'home': 'home',
#   'pitcher': {'id': 453178,
#    'fullName': 'Ian Kennedy',
#    'link': '/api/v1/people/453178'},
#   'batter': {'id': 666971,
#    'fullName': 'Lourdes Gurriel Jr.',
#    'link': '/api/v1/people/666971'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': 0.52,
#     'z': 3.03},
#    {'call': 'strike', 'sz_top': 3.55, 'sz_bottom': 1.63, 'x': 0.29, 'z': 3.11},
#    {'call': 'ball', 'sz_top': 3.26, 'sz_bottom': 1.63, 'x': -0.17, 'z': 1.36},
#    {'call': 'ball', 'sz_top': 3.28, 'sz_bottom': 1.56, 'x': 0.8, 'z': 4.59},
#    {'call': 'strike',
#     'sz_top': 3.31,
#     'sz_bottom': 1.63,
#     'x': 0.72,
#     'z': 1.88}]},
#  66: {'inning': 9,
#   'home': 'home',
#   'pitcher': {'id': 453178,
#    'fullName': 'Ian Kennedy',
#    'link': '/api/v1/people/453178'},
#   'batter': {'id': 545341,
#    'fullName': 'Randal Grichuk',
#    'link': '/api/v1/people/545341'},
#   'pitchHand': 'R',
#   'batSide': 'R',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.3,
#     'z': 3.08},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.46,
#     'z': 1.33},
#    {'call': 'strike',
#     'sz_top': 3.47,
#     'sz_bottom': 1.59,
#     'x': -0.47,
#     'z': 1.25}]},
#  67: {'inning': 9,
#   'home': 'home',
#   'pitcher': {'id': 453178,
#    'fullName': 'Ian Kennedy',
#    'link': '/api/v1/people/453178'},
#   'batter': {'id': 605412,
#    'fullName': 'Joe Panik',
#    'link': '/api/v1/people/605412'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'ball',
#     'sz_top': 3.08,
#     'sz_bottom': 1.37,
#     'x': -1.16,
#     'z': 1.87},
#    {'call': 'strike',
#     'sz_top': 3.09,
#     'sz_bottom': 1.42,
#     'x': -0.85,
#     'z': 2.49},
#    {'call': 'strike', 'sz_top': 3.41, 'sz_bottom': 1.56, 'x': 0.28, 'z': 2.75},
#    {'call': 'ball', 'sz_top': 3.06, 'sz_bottom': 1.39, 'x': 0.97, 'z': 3.39},
#    {'call': 'strike',
#     'sz_top': 3.41,
#     'sz_bottom': 1.56,
#     'x': -0.7,
#     'z': 2.13}]},
#  68: {'inning': 9,
#   'home': 'home',
#   'pitcher': {'id': 453178,
#    'fullName': 'Ian Kennedy',
#    'link': '/api/v1/people/453178'},
#   'batter': {'id': 642133,
#    'fullName': 'Rowdy Tellez',
#    'link': '/api/v1/people/642133'},
#   'pitchHand': 'R',
#   'batSide': 'L',
#   'pitchData': [{'call': 'strike',
#     'sz_top': 3.59,
#     'sz_bottom': 1.63,
#     'x': 0.28,
#     'z': 2.34},
#    {'call': 'ball', 'sz_top': 3.42, 'sz_bottom': 1.63, 'x': -0.73, 'z': 3.48},
#    {'call': 'ball', 'sz_top': 3.64, 'sz_bottom': 1.63, 'x': 0.11, 'z': 0.45},
#    {'call': 'ball', 'sz_top': 3.66, 'sz_bottom': 1.63, 'x': -1.65, 'z': 2.14},
#    {'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': -0.72,
#     'z': 3.23},
#    {'call': 'strike',
#     'sz_top': 3.55,
#     'sz_bottom': 1.63,
#     'x': -0.48,
#     'z': 2.9}]}}

# %% [markdown]
# ### Persons

# %% [markdown]
# #### Basic Info

# %%
import re

def lookup_player(name):
    """
    returns personId for given player name
    """
    sports_url = base_url + "/v1/sports/1/players"
    sports_content = get_json(sports_url)
    
    players = sports_content['people']
    
    matching_player = [player for player in players if str(name).lower() in str(player.values()).lower()]
    
    if len(matching_player) == 1:
        return(matching_player[0]['id'])
    
    return(matching_player)

# %%
lookup_player("ryu")
# Out:
# 547943

# %%
def lookup_player_info(playerId):
    
    person_url = base_url + "v1/people/{}/".format(playerId)
    person_content = get_json(person_url)
    profile = person_content['people'][0]
    
    return(profile)

# %%
lookup_player_info(547943)
# Out:
# {'id': 547943,
#  'fullName': 'Hyun Jin Ryu',
#  'link': '/api/v1/people/547943',
#  'firstName': 'Hyun Jin',
#  'lastName': 'Ryu',
#  'primaryNumber': '99',
#  'birthDate': '1987-03-25',
#  'currentAge': 34,
#  'birthCity': 'Incheon',
#  'birthCountry': 'South Korea',
#  'height': '6\' 3"',
#  'weight': 255,
#  'active': True,
#  'primaryPosition': {'code': '1',
#   'name': 'Pitcher',
#   'type': 'Pitcher',
#   'abbreviation': 'P'},
#  'useName': 'Hyun Jin',
#  'boxscoreName': 'Ryu',
#  'nickName': 'Monster',
#  'gender': 'M',
#  'isPlayer': True,
#  'isVerified': True,
#  'pronunciation': 'he-yun jin ree-yoo',
#  'mlbDebutDate': '2013-04-02',
#  'batSide': {'code': 'R', 'description': 'Right'},
#  'pitchHand': {'code': 'L', 'description': 'Left'},
#  'nameFirstLast': 'Hyun Jin Ryu',
#  'nameSlug': 'hyun-jin-ryu-547943',
#  'firstLastName': 'Hyun Jin Ryu',
#  'lastFirstName': 'Ryu, Hyun Jin',
#  'lastInitName': 'Ryu, H',
#  'initLastName': 'H Ryu',
#  'fullFMLName': 'Hyun Jin Ryu',
#  'fullLFMName': 'Ryu, Hyun Jin',
#  'strikeZoneTop': 3.49,
#  'strikeZoneBottom': 1.601}

# %% [markdown]
# #### Game-specific Player Stat

# %%
def player_game_stat(personId, gamePk):
    
    game_stat_url = base_url + "v1/people/{playerId}/stats/game/{gamePk}".format(playerId = personId, gamePk = gamePk)
    game_stat_content = get_json(game_stat_url)
    game_stat = game_stat_content['stats']
    
    stats = [s for s in game_stat if s['splits']]
    
    stat_dict = {}
    
    try:    
        for s in stats:        
            t = s["group"]["displayName"]
            splits = s["splits"]
            stat = splits[0]["stat"]
            stat_dict.update({t:stat})
        return(stat_dict)

    except:
        print("The player did not play in the stated game.")

# %%
player_game_stat(547943, 634645)
# Out:
# {'pitching': {'groundOuts': 1,
#   'airOuts': 1,
#   'runs': 2,
#   'doubles': 0,
#   'triples': 1,
#   'homeRuns': 0,
#   'strikeOuts': 2,
#   'baseOnBalls': 0,
#   'intentionalWalks': 0,
#   'hits': 2,
#   'hitByPitch': 0,
#   'avg': '.333',
#   'atBats': 6,
#   'obp': '.333',
#   'slg': '.667',
#   'ops': '1.000',
#   'caughtStealing': 0,
#   'stolenBases': 0,
#   'stolenBasePercentage': '.---',
#   'groundIntoDoublePlay': 0,
#   'numberOfPitches': 25,
#   'totalBases': 4,
#   'groundOutsToAirouts': '1.00',
#   'rbi': 0,
#   'strikeoutWalkRatio': '-.--',
#   'sacBunts': 0,
#   'sacFlies': 0}}

# %% [markdown]
# ### Schedule

# %%
su = base_url + "/v1/schedule?sportId=1"
s = get_json(su)
s
# Out:
# {'copyright': 'Copyright 2021 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'totalItems': 15,
#  'totalEvents': 0,
#  'totalGames': 15,
#  'totalGamesInProgress': 0,
#  'dates': [{'date': '2021-06-15',
#    'totalItems': 15,
#    'totalEvents': 0,
#    'totalGames': 15,
#    'totalGamesInProgress': 0,
#    'games': [{'gamePk': 633684,
#      'link': '/api/v1.1/game/633684/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-15T23:05:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 23,
#         'losses': 42,
#         'pct': '.354'},
#        'score': 0,
#        'team': {'id': 134,
#         'name': 'Pittsburgh Pirates',
#         'link': '/api/v1/teams/134'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 28, 'losses': 35, 'pct': '.444'},
#        'score': 0,
#        'team': {'id': 120,
#         'name': 'Washington Nationals',
#         'link': '/api/v1/teams/120'},
#        'splitSquad': False,
#        'seriesNumber': 21}},
#      'venue': {'id': 3309,
#       'name': 'Nationals Park',
#       'link': '/api/v1/venues/3309'},
#      'content': {'link': '/api/v1/game/633684/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633684-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633653,
#      'link': '/api/v1.1/game/633653/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-15T23:07:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 33,
#         'losses': 32,
#         'pct': '.508'},
#        'team': {'id': 147,
#         'name': 'New York Yankees',
#         'link': '/api/v1/teams/147'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 33, 'losses': 31, 'pct': '.516'},
#        'team': {'id': 141,
#         'name': 'Toronto Blue Jays',
#         'link': '/api/v1/teams/141'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 2756,
#       'name': 'Sahlen Field',
#       'link': '/api/v1/venues/2756'},
#      'content': {'link': '/api/v1/game/633653/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633653-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'description': 'in Buffalo, NY',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633769,
#      'link': '/api/v1.1/game/633769/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-15T23:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 22,
#         'losses': 43,
#         'pct': '.338'},
#        'score': 0,
#        'team': {'id': 110,
#         'name': 'Baltimore Orioles',
#         'link': '/api/v1/teams/110'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 35, 'losses': 28, 'pct': '.556'},
#        'score': 0,
#        'team': {'id': 114,
#         'name': 'Cleveland Indians',
#         'link': '/api/v1/teams/114'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 5,
#       'name': 'Progressive Field',
#       'link': '/api/v1/venues/5'},
#      'content': {'link': '/api/v1/game/633769/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633769-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633681,
#      'link': '/api/v1.1/game/633681/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-15T23:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 38,
#         'losses': 28,
#         'pct': '.576'},
#        'score': 0,
#        'team': {'id': 112,
#         'name': 'Chicago Cubs',
#         'link': '/api/v1/teams/112'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 33, 'losses': 25, 'pct': '.569'},
#        'score': 0,
#        'team': {'id': 121,
#         'name': 'New York Mets',
#         'link': '/api/v1/teams/121'},
#        'splitSquad': False,
#        'seriesNumber': 21}},
#      'venue': {'id': 3289,
#       'name': 'Citi Field',
#       'link': '/api/v1/venues/3289'},
#      'content': {'link': '/api/v1/game/633681/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633681-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 145,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633724,
#      'link': '/api/v1.1/game/633724/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-15T23:20:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 40,
#         'losses': 27,
#         'pct': '.597'},
#        'score': 0,
#        'team': {'id': 111,
#         'name': 'Boston Red Sox',
#         'link': '/api/v1/teams/111'},
#        'splitSquad': False,
#        'seriesNumber': 23},
#       'home': {'leagueRecord': {'wins': 30, 'losses': 33, 'pct': '.476'},
#        'score': 0,
#        'team': {'id': 144,
#         'name': 'Atlanta Braves',
#         'link': '/api/v1/teams/144'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 4705,
#       'name': 'Truist Park',
#       'link': '/api/v1/venues/4705'},
#      'content': {'link': '/api/v1/game/633724/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633724-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 2,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633755,
#      'link': '/api/v1.1/game/633755/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T00:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 27,
#         'losses': 39,
#         'pct': '.409'},
#        'team': {'id': 116,
#         'name': 'Detroit Tigers',
#         'link': '/api/v1/teams/116'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 30, 'losses': 35, 'pct': '.462'},
#        'team': {'id': 118,
#         'name': 'Kansas City Royals',
#         'link': '/api/v1/teams/118'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 7,
#       'name': 'Kauffman Stadium',
#       'link': '/api/v1/venues/7'},
#      'content': {'link': '/api/v1/game/633755/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633755-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633829,
#      'link': '/api/v1.1/game/633829/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T00:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 25,
#         'losses': 41,
#         'pct': '.379'},
#        'team': {'id': 140,
#         'name': 'Texas Rangers',
#         'link': '/api/v1/teams/140'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 37, 'losses': 28, 'pct': '.569'},
#        'team': {'id': 117,
#         'name': 'Houston Astros',
#         'link': '/api/v1/teams/117'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 2392,
#       'name': 'Minute Maid Park',
#       'link': '/api/v1/venues/2392'},
#      'content': {'link': '/api/v1/game/633829/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633829-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 2,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633676,
#      'link': '/api/v1.1/game/633676/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T00:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 43,
#         'losses': 24,
#         'pct': '.642'},
#        'score': 0,
#        'team': {'id': 139,
#         'name': 'Tampa Bay Rays',
#         'link': '/api/v1/teams/139'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 41, 'losses': 25, 'pct': '.621'},
#        'score': 0,
#        'team': {'id': 145,
#         'name': 'Chicago White Sox',
#         'link': '/api/v1/teams/145'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 4,
#       'name': 'Guaranteed Rate Field',
#       'link': '/api/v1/venues/4'},
#      'content': {'link': '/api/v1/game/633676/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633676-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633714,
#      'link': '/api/v1.1/game/633714/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T00:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 33,
#         'losses': 31,
#         'pct': '.516'},
#        'score': 0,
#        'team': {'id': 113,
#         'name': 'Cincinnati Reds',
#         'link': '/api/v1/teams/113'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 38, 'losses': 28, 'pct': '.576'},
#        'score': 0,
#        'team': {'id': 158,
#         'name': 'Milwaukee Brewers',
#         'link': '/api/v1/teams/158'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 32,
#       'name': 'American Family Field',
#       'link': '/api/v1/venues/32'},
#      'content': {'link': '/api/v1/game/633714/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633714-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633694,
#      'link': '/api/v1.1/game/633694/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T00:15:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'S',
#       'detailedState': 'Scheduled',
#       'statusCode': 'S',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 29,
#         'losses': 37,
#         'pct': '.439'},
#        'team': {'id': 146,
#         'name': 'Miami Marlins',
#         'link': '/api/v1/teams/146'},
#        'splitSquad': False,
#        'seriesNumber': 23},
#       'home': {'leagueRecord': {'wins': 33, 'losses': 33, 'pct': '.500'},
#        'team': {'id': 138,
#         'name': 'St. Louis Cardinals',
#         'link': '/api/v1/teams/138'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 2889,
#       'name': 'Busch Stadium',
#       'link': '/api/v1/venues/2889'},
#      'content': {'link': '/api/v1/game/633694/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633694-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633701,
#      'link': '/api/v1.1/game/633701/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T00:40:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'P',
#       'detailedState': 'Pre-Game',
#       'statusCode': 'P',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 38,
#         'losses': 30,
#         'pct': '.559'},
#        'team': {'id': 135,
#         'name': 'San Diego Padres',
#         'link': '/api/v1/teams/135'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 26, 'losses': 41, 'pct': '.388'},
#        'team': {'id': 115,
#         'name': 'Colorado Rockies',
#         'link': '/api/v1/teams/115'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 19, 'name': 'Coors Field', 'link': '/api/v1/venues/19'},
#      'content': {'link': '/api/v1/game/633701/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633701-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633656,
#      'link': '/api/v1.1/game/633656/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T01:40:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'S',
#       'detailedState': 'Scheduled',
#       'statusCode': 'S',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 33,
#         'losses': 33,
#         'pct': '.500'},
#        'team': {'id': 108,
#         'name': 'Los Angeles Angels',
#         'link': '/api/v1/teams/108'},
#        'splitSquad': False,
#        'seriesNumber': 23},
#       'home': {'leagueRecord': {'wins': 41, 'losses': 27, 'pct': '.603'},
#        'team': {'id': 133,
#         'name': 'Oakland Athletics',
#         'link': '/api/v1/teams/133'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 10,
#       'name': 'Oakland Coliseum',
#       'link': '/api/v1/venues/10'},
#      'content': {'link': '/api/v1/game/633656/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633656-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633679,
#      'link': '/api/v1.1/game/633679/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T01:45:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'S',
#       'detailedState': 'Scheduled',
#       'statusCode': 'S',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 20,
#         'losses': 47,
#         'pct': '.299'},
#        'team': {'id': 109,
#         'name': 'Arizona Diamondbacks',
#         'link': '/api/v1/teams/109'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 41, 'losses': 25, 'pct': '.621'},
#        'team': {'id': 137,
#         'name': 'San Francisco Giants',
#         'link': '/api/v1/teams/137'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 2395,
#       'name': 'Oracle Park',
#       'link': '/api/v1/venues/2395'},
#      'content': {'link': '/api/v1/game/633679/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633679-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633626,
#      'link': '/api/v1.1/game/633626/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T02:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'S',
#       'detailedState': 'Scheduled',
#       'statusCode': 'S',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 26,
#         'losses': 40,
#         'pct': '.394'},
#        'team': {'id': 142,
#         'name': 'Minnesota Twins',
#         'link': '/api/v1/teams/142'},
#        'splitSquad': False,
#        'seriesNumber': 23},
#       'home': {'leagueRecord': {'wins': 33, 'losses': 35, 'pct': '.485'},
#        'team': {'id': 136,
#         'name': 'Seattle Mariners',
#         'link': '/api/v1/teams/136'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 680,
#       'name': 'T-Mobile Park',
#       'link': '/api/v1/venues/680'},
#      'content': {'link': '/api/v1/game/633626/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633626-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 633675,
#      'link': '/api/v1.1/game/633675/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-06-16T02:10:00Z',
#      'officialDate': '2021-06-15',
#      'status': {'abstractGameState': 'Preview',
#       'codedGameState': 'S',
#       'detailedState': 'Scheduled',
#       'statusCode': 'S',
#       'startTimeTBD': False,
#       'abstractGameCode': 'P'},
#      'teams': {'away': {'leagueRecord': {'wins': 32,
#         'losses': 32,
#         'pct': '.500'},
#        'team': {'id': 143,
#         'name': 'Philadelphia Phillies',
#         'link': '/api/v1/teams/143'},
#        'splitSquad': False,
#        'seriesNumber': 22},
#       'home': {'leagueRecord': {'wins': 40, 'losses': 26, 'pct': '.606'},
#        'team': {'id': 119,
#         'name': 'Los Angeles Dodgers',
#         'link': '/api/v1/teams/119'},
#        'splitSquad': False,
#        'seriesNumber': 22}},
#      'venue': {'id': 22,
#       'name': 'Dodger Stadium',
#       'link': '/api/v1/venues/22'},
#      'content': {'link': '/api/v1/game/633675/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-633675-2021-06-15',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 2,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'}],
#    'events': []}]}

# %%
def get_schedule(date = None,
                 startDate = None,
                 endDate = None,
                 teamId = None,
                 season = None,
                 sportId = 1):
    
    schedule_base_url = base_url + "/v1/schedule?sportId=1"
    
    """
    if not any([date, startDate, endDate]):
        date = today
    """
    suffix = ""
    
    if date is not None:
        suffix += "&date={}".format(date)
        
    if (startDate is not None and endDate is None) or (startDate is None and endDate is not None):
        ValueError("Specify both Start Date and End Date in MM/DD/YYYY format.")
        
    if startDate is not None and endDate is not None:
        suffix += "&startDate={startDate}&endDate={endDate}".format(startDate = startDate, endDate = endDate)
        
    if teamId is not None:
        suffix += "&teamId={}".format(teamId)
        
    schedule_url = schedule_base_url + suffix
    print(schedule_url)
    schedule_content = get_json(schedule_url)
    
    schedule_dict = {}
    
    dates = schedule_content['dates']
    
    for d in dates:
        day = d['date']
        games = d['games']
        
        games_list = []
        
        for game in games:
            gameID = game['gamePk']
            
            teams = game['teams']
            away = teams['away']
            away_name = away['team']['name']
            away_Id = away['team']['id']
            
            home = teams['home']
            home_name = home['team']['name']
            home_Id = home['team']['id']
            
            games_list.append({'gamePk': gameID, 
                               'home': {'ID': home_Id, 'name': home_name},
                               'away':{'ID': away_Id, 'name': away_name}})
            
        schedule_dict.update({day:games_list})
        
    return(schedule_dict)

# %%
get_schedule(teamId=141)
# Out:
# http://statsapi.mlb.com/api//v1/schedule?sportId=1&teamId=141
# {'2021-06-15': [{'gamePk': 633653,
#    'home': {'ID': 141, 'name': 'Toronto Blue Jays'},
#    'away': {'ID': 147, 'name': 'New York Yankees'}}]}

# %% [markdown]
# ### Add postseanson query

# %% [markdown]
# ### Season

# %%
def get_season(season):
    """
    returns season start and end dates
    """
    season_url = base_url + "v1/seasons?season={}&sportId=1".format(season)
    season_content = get_json(season_url)
    
    return(season_content['seasons'][0])

# %%
get_season(2021)
# Out:
# {'seasonId': '2021',
#  'hasWildcard': True,
#  'regularSeasonStartDate': '2021-04-01',
#  'regularSeasonEndDate': '2021-10-03',
#  'preSeasonStartDate': '2021-02-28',
#  'preSeasonEndDate': '2021-03-30',
#  'postSeasonStartDate': '2021-10-04',
#  'postSeasonEndDate': '2021-10-31',
#  'lastDate1stHalf': '2021-07-11',
#  'firstDate2ndHalf': '2021-07-15',
#  'allStarDate': '2021-07-13',
#  'seasonStartDate': '2021-02-28',
#  'seasonEndDate': '2021-10-31'}

# %% [markdown]
# ### Standings

# %%
def get_standings(leagueID = None, season = 2021):
    """
    leagueId is the mandatory parameter in this API query.
    """
    suffix = ""
    base_standings_url = base_url + "v1/standings"
    
    if leagueID is None:
        suffix += "?leagueId=103,104"
        
    else:
        suffix += "?leaugeId={}".format(leagueId)
    
    suffix += "&season={}".format(season)
    
    standings_url = base_standings_url + suffix
    records = get_json(standings_url)['records']
    
    division_dict = {}
    
    for record in records:
        
        division = lookup_division(record['division']['id'])
        
        team_records = record['teamRecords']
        
        tr_dict = {}
        
        for tr in team_records:

            team_name = tr['team']['name']
            rank = tr['divisionRank']
            gamesPlayed = tr['gamesPlayed']
            gamesBack = tr['gamesBack']
            wins = tr['leagueRecord']['wins']
            losses = tr['leagueRecord']['losses']
            pct = tr['leagueRecord']['pct']

            tr_dict.update({team_name:{"rank":rank, 'Played': gamesPlayed, "W": wins, "L": losses, "%": pct, "gamesBack": gamesBack}})
            
        division_dict.update({division:tr_dict})
        
    return(division_dict)

# %%
get_standings()
# Out:
# {'AL West': {'Oakland Athletics': {'rank': '1',
#    'Played': 68,
#    'W': 41,
#    'L': 27,
#    '%': '.603',
#    'gamesBack': '-'},
#   'Houston Astros': {'rank': '2',
#    'Played': 65,
#    'W': 37,
#    'L': 28,
#    '%': '.569',
#    'gamesBack': '2.5'},
#   'Los Angeles Angels': {'rank': '3',
#    'Played': 66,
#    'W': 33,
#    'L': 33,
#    '%': '.500',
#    'gamesBack': '7.0'},
#   'Seattle Mariners': {'rank': '4',
#    'Played': 68,
#    'W': 33,
#    'L': 35,
#    '%': '.485',
#    'gamesBack': '8.0'},
#   'Texas Rangers': {'rank': '5',
#    'Played': 66,
#    'W': 25,
#    'L': 41,
#    '%': '.379',
#    'gamesBack': '15.0'}},
#  'AL East': {'Tampa Bay Rays': {'rank': '1',
#    'Played': 67,
#    'W': 43,
#    'L': 24,
#    '%': '.642',
#    'gamesBack': '-'},
#   'Boston Red Sox': {'rank': '2',
#    'Played': 67,
#    'W': 40,
#    'L': 27,
#    '%': '.597',
#    'gamesBack': '3.0'},
#   'Toronto Blue Jays': {'rank': '3',
#    'Played': 64,
#    'W': 33,
#    'L': 31,
#    '%': '.516',
#    'gamesBack': '8.5'},
#   'New York Yankees': {'rank': '4',
#    'Played': 65,
#    'W': 33,
#    'L': 32,
#    '%': '.508',
#    'gamesBack': '9.0'},
#   'Baltimore Orioles': {'rank': '5',
#    'Played': 65,
#    'W': 22,
#    'L': 43,
#    '%': '.338',
#    'gamesBack': '20.0'}},
#  'AL Central': {'Chicago White Sox': {'rank': '1',
#    'Played': 66,
#    'W': 41,
#    'L': 25,
#    '%': '.621',
#    'gamesBack': '-'},
#   'Cleveland Indians': {'rank': '2',
#    'Played': 63,
#    'W': 35,
#    'L': 28,
#    '%': '.556',
#    'gamesBack': '4.5'},
#   'Kansas City Royals': {'rank': '3',
#    'Played': 65,
#    'W': 30,
#    'L': 35,
#    '%': '.462',
#    'gamesBack': '10.5'},
#   'Detroit Tigers': {'rank': '4',
#    'Played': 66,
#    'W': 27,
#    'L': 39,
#    '%': '.409',
#    'gamesBack': '14.0'},
#   'Minnesota Twins': {'rank': '5',
#    'Played': 66,
#    'W': 26,
#    'L': 40,
#    '%': '.394',
#    'gamesBack': '15.0'}},
#  'NL Central': {'Chicago Cubs': {'rank': '1',
#    'Played': 66,
#    'W': 38,
#    'L': 28,
#    '%': '.576',
#    'gamesBack': '-'},
#   'Milwaukee Brewers': {'rank': '2',
#    'Played': 66,
#    'W': 38,
#    'L': 28,
#    '%': '.576',
#    'gamesBack': '-'},
#   'Cincinnati Reds': {'rank': '3',
#    'Played': 64,
#    'W': 33,
#    'L': 31,
#    '%': '.516',
#    'gamesBack': '4.0'},
#   'St. Louis Cardinals': {'rank': '4',
#    'Played': 66,
#    'W': 33,
#    'L': 33,
#    '%': '.500',
#    'gamesBack': '5.0'},
#   'Pittsburgh Pirates': {'rank': '5',
#    'Played': 65,
#    'W': 23,
#    'L': 42,
#    '%': '.354',
#    'gamesBack': '14.5'}},
#  'NL West': {'San Francisco Giants': {'rank': '1',
#    'Played': 66,
#    'W': 41,
#    'L': 25,
#    '%': '.621',
#    'gamesBack': '-'},
#   'Los Angeles Dodgers': {'rank': '2',
#    'Played': 66,
#    'W': 40,
#    'L': 26,
#    '%': '.606',
#    'gamesBack': '1.0'},
#   'San Diego Padres': {'rank': '3',
#    'Played': 68,
#    'W': 38,
#    'L': 30,
#    '%': '.559',
#    'gamesBack': '4.0'},
#   'Colorado Rockies': {'rank': '4',
#    'Played': 67,
#    'W': 26,
#    'L': 41,
#    '%': '.388',
#    'gamesBack': '15.5'},
#   'Arizona Diamondbacks': {'rank': '5',
#    'Played': 67,
#    'W': 20,
#    'L': 47,
#    '%': '.299',
#    'gamesBack': '21.5'}},
#  'NL East': {'New York Mets': {'rank': '1',
#    'Played': 58,
#    'W': 33,
#    'L': 25,
#    '%': '.569',
#    'gamesBack': '-'},
#   'Philadelphia Phillies': {'rank': '2',
#    'Played': 64,
#    'W': 32,
#    'L': 32,
#    '%': '.500',
#    'gamesBack': '4.0'},
#   'Atlanta Braves': {'rank': '3',
#    'Played': 63,
#    'W': 30,
#    'L': 33,
#    '%': '.476',
#    'gamesBack': '5.5'},
#   'Washington Nationals': {'rank': '4',
#    'Played': 63,
#    'W': 28,
#    'L': 35,
#    '%': '.444',
#    'gamesBack': '7.5'},
#   'Miami Marlins': {'rank': '5',
#    'Played': 66,
#    'W': 29,
#    'L': 37,
#    '%': '.439',
#    'gamesBack': '8.0'}}}

# %% [markdown]
# ### Team

# %% [markdown]
# Team ID

# %%
def lookup_team(name):
    """
    returns personId for given player name
    """
    team_url = base_url + "/v1/teams?sportId=1"
    team_content = get_json(team_url)
    teams = team_content['teams']
    
    matching_team = [team for team in teams if str(name).lower() in str(team.values()).lower()]
    
    if len(matching_team) == 1:
        return(matching_team[0]['id'])
    
    return(matching_team)

# %% [markdown]
# #### Roster

# %%
def lookup_roster(teamId, season = 2021, rosterType = "40man"):
    """
    rosterType can be either one of "40man", "fullSeason", "full", or "active"
    """
    
    roster_url = base_url + "v1/teams/{teamId}/roster/{rosterType}?season={season}".format(teamId = teamId,
                                                                                          rosterType = rosterType,
                                                                                          season = season)
    
    roster = get_json(roster_url)['roster']
    
    return(roster)

# %%
lookup_roster(141)
# Out:
# [{'person': {'id': 666201,
#    'fullName': 'Alek Manoah',
#    'link': '/api/v1/people/666201'},
#   'jerseyNumber': '6',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 621593,
#    'fullName': 'Anthony Castro',
#    'link': '/api/v1/people/621593'},
#   'jerseyNumber': '63',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 666182,
#    'fullName': 'Bo Bichette',
#    'link': '/api/v1/people/666182'},
#   'jerseyNumber': '11',
#   'position': {'code': '6',
#    'name': 'Shortstop',
#    'type': 'Infielder',
#    'abbreviation': 'SS'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 605218,
#    'fullName': 'Carl Edwards Jr.',
#    'link': '/api/v1/people/605218'},
#   'jerseyNumber': '43',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 624415,
#    'fullName': 'Cavan Biggio',
#    'link': '/api/v1/people/624415'},
#   'jerseyNumber': '8',
#   'position': {'code': '5',
#    'name': 'Third Base',
#    'type': 'Infielder',
#    'abbreviation': '3B'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 547943,
#    'fullName': 'Hyun Jin Ryu',
#    'link': '/api/v1/people/547943'},
#   'jerseyNumber': '99',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 676886,
#    'fullName': 'Jeremy Beasley',
#    'link': '/api/v1/people/676886'},
#   'jerseyNumber': '59',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 605412,
#    'fullName': 'Joe Panik',
#    'link': '/api/v1/people/605412'},
#   'jerseyNumber': '2',
#   'position': {'code': '5',
#    'name': 'Third Base',
#    'type': 'Infielder',
#    'abbreviation': '3B'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 606303,
#    'fullName': 'Joel Payamps',
#    'link': '/api/v1/people/606303'},
#   'jerseyNumber': '54',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 641505,
#    'fullName': 'Jonathan Davis',
#    'link': '/api/v1/people/641505'},
#   'jerseyNumber': '3',
#   'position': {'code': '8',
#    'name': 'Outfielder',
#    'type': 'Outfielder',
#    'abbreviation': 'CF'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 605447,
#    'fullName': 'Jordan Romano',
#    'link': '/api/v1/people/605447'},
#   'jerseyNumber': '68',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 666971,
#    'fullName': 'Lourdes Gurriel Jr.',
#    'link': '/api/v1/people/666971'},
#   'jerseyNumber': '13',
#   'position': {'code': '7',
#    'name': 'Outfielder',
#    'type': 'Outfielder',
#    'abbreviation': 'LF'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 543760,
#    'fullName': 'Marcus Semien',
#    'link': '/api/v1/people/543760'},
#   'jerseyNumber': '10',
#   'position': {'code': '4',
#    'name': 'Second Base',
#    'type': 'Infielder',
#    'abbreviation': '2B'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 503569,
#    'fullName': 'Rafael Dolis',
#    'link': '/api/v1/people/503569'},
#   'jerseyNumber': '41',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 545341,
#    'fullName': 'Randal Grichuk',
#    'link': '/api/v1/people/545341'},
#   'jerseyNumber': '15',
#   'position': {'code': '8',
#    'name': 'Outfielder',
#    'type': 'Outfielder',
#    'abbreviation': 'CF'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 624512,
#    'fullName': 'Reese McGuire',
#    'link': '/api/v1/people/624512'},
#   'jerseyNumber': '7',
#   'position': {'code': '2',
#    'name': 'Catcher',
#    'type': 'Catcher',
#    'abbreviation': 'C'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 656180,
#    'fullName': 'Riley Adams',
#    'link': '/api/v1/people/656180'},
#   'jerseyNumber': '50',
#   'position': {'code': '2',
#    'name': 'Catcher',
#    'type': 'Catcher',
#    'abbreviation': 'C'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 592662,
#    'fullName': 'Robbie Ray',
#    'link': '/api/v1/people/592662'},
#   'jerseyNumber': '38',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 548389,
#    'fullName': 'Ross Stripling',
#    'link': '/api/v1/people/548389'},
#   'jerseyNumber': '48',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 642133,
#    'fullName': 'Rowdy Tellez',
#    'link': '/api/v1/people/642133'},
#   'jerseyNumber': '44',
#   'position': {'code': '3',
#    'name': 'First Base',
#    'type': 'Infielder',
#    'abbreviation': '1B'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 642048,
#    'fullName': 'Tayler Saucedo',
#    'link': '/api/v1/people/642048'},
#   'jerseyNumber': '52',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 606192,
#    'fullName': 'Teoscar Hernandez',
#    'link': '/api/v1/people/606192'},
#   'jerseyNumber': '37',
#   'position': {'code': '9',
#    'name': 'Outfielder',
#    'type': 'Outfielder',
#    'abbreviation': 'RF'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 641835,
#    'fullName': 'Tim Mayza',
#    'link': '/api/v1/people/641835'},
#   'jerseyNumber': '58',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 663423,
#    'fullName': 'Trent Thornton',
#    'link': '/api/v1/people/663423'},
#   'jerseyNumber': '57',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 543022,
#    'fullName': 'Tyler Chatwood',
#    'link': '/api/v1/people/543022'},
#   'jerseyNumber': '34',
#   'position': {'code': '1',
#    'name': 'Pitcher',
#    'type': 'Pitcher',
#    'abbreviation': 'P'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141},
#  {'person': {'id': 665489,
#    'fullName': 'Vladimir Guerrero Jr.',
#    'link': '/api/v1/people/665489'},
#   'jerseyNumber': '27',
#   'position': {'code': '3',
#    'name': 'First Base',
#    'type': 'Infielder',
#    'abbreviation': '1B'},
#   'status': {'code': 'A', 'description': 'Active'},
#   'parentTeamId': 141}]
