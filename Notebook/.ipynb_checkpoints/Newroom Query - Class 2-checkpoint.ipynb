# %% [markdown]
# ## Imports & Liz's Newsroom Code

# %%
import pandas as pd
import string
import time
import sys
import requests
from lxml import etree
from newsroom_query import NovusSearchQuery
import newsroom_query as nq
import numpy as np
import novus_document

# %%
class NovusSearchQuery(object):

    def __init__(self, name, permids, languages, search_terms):
        self.name = name
        self.permids = permids
        self.languages = languages
        self.search_terms = search_terms
        if not self.permids and not any(search_terms.values()):
            raise ValueError("Cannot create an empty Query: please specify some search terms")

    def get_query_string(self):
        query_components = []
        if self.permids:
            permids_list = [str(permid) for permid in self.permids]
            query_components.append("OAID({})".format(" ".join(permids_list)))
        if self.languages:
            query_components.append("LANGUAGE({})".format(" ".join(self.languages)))
        for field, search_terms in self.search_terms.items():
            query_components.append("{}({})".format(field, " OR ".join(search_terms)))

        query = " & ".join(query_components)

        print 'NovusQuery: ', query
        return query

# %%
import sys

__author__ = 'eroman'

import requests
from lxml import etree
from newsroom_query import NovusSearchQuery
import newsroom_query as nq
import numpy as np
import novus_document


def make_prod_client(collection_set="NRALLNEWS"):
    return NewsRoomSearchClient("http://newsroom.ta.int.thomsonreuters.com/newsroom", "TESTUI", "KY3P_DIL_POC",
                                collection_set=collection_set)


class SearchHit(object):
    # A SearchHit represent the (q, D) pair -> (query, Document)

    def __init__(self, query, collection, guid, document_xml=None, headline=None):
        self.query = query
        self.collection = collection
        self.guid = guid
        self.document_xml = document_xml
        self.headline = headline

    def set_document_xml(self, document_xml):
        self.document_xml = document_xml

    def to_csv_row(self):
        # permid, article_snippet, article_date, source_url=(collection, doc_guid), risk_score, risk_type, relevance_score, confidence_score

        # permid
        permid = "{}".format(" ".join(str(p) for p in self.query.permids))

        root = etree.XML(self.document_xml)

        # date
        date = root.xpath("//sort-pub-date")[0].text

        # relevancy & confidence

        xpath_expr = "./n-docbody/document/indexing/extraction-terms/extr-company-block//norm-company-wrap/company-ids/oa-id[text()='{}']".format(permid)
        oaid = root.xpath(xpath_expr)
        if not oaid:
            raise ValueError("No norm_company_wrap elements found in this document, this result should be discarded")
        oaid = oaid[0]
        norm_company_wrap = oaid.getparent().getparent()

        relevance_score = np.nan
        relevancies = norm_company_wrap.xpath("./relevancy")
        if relevancies:
            relevance_score = float(relevancies[0].text)

        confidence = np.nan
        confidences = norm_company_wrap.xpath("./confidence")
        if confidences:
            confidence = float(confidences[0].text)

        return [permid,
                self.document_xml,
                date,
                self.collection,
                self.guid,
                0,
                self.query.name,
                relevance_score,
                confidence]


class NewsRoomSearchClient(object):
    def __init__(self, url, product_id, root_guid, collection_set="NRALLNEWS"):
        self.url = url
        self.product_id = product_id
        self.root_guid = root_guid
        self.collection_set = collection_set


    def get_publications(self, version="v1"):
        headers = {'Content-type':'application/xml',
                   'Accept':'application/json',
                   'x-trmr-product': self.product_id,
                   'x-trmr-rootguid': self.root_guid}
        request_url = self.url + "/{}/ui/publications".format(version)
        r = requests.get(request_url, headers=headers).json()
        return r


    def get_publication_languages(self):
        headers = {'Content-type':'application/json',
                   'Accept':'application/json',
                   'x-trmr-product': self.product_id,
                   'x-trmr-rootguid': self.root_guid}
        request_url = self.url + "/v2/publication/languages/{}".format(self.collection_set)
        r = requests.get(request_url, headers=headers).json()
        return [d['label'] for d in r['languages']]

    def get_document(self, hit):
        headers = {'Content-type':'application/xml',
                   'Accept':'application/xml',
                   'x-trmr-product': self.product_id,
                   'x-trmr-rootguid': self.root_guid}
        request_url = self.url + "/v1/document/{}/{}".format(hit.collection, hit.guid)
        r = requests.get(request_url, headers=headers)
        if hit:
            response_element = etree.fromstring(r.text)
            doc_xml_string = etree.tostring(response_element.xpath("./doc")[0])
            hit.set_document_xml(doc_xml_string)
        return r

    def get_document_with_guid(self, collection, guid):
        headers = {'Content-type':'application/xml',
                   'Accept':'application/xml',
                   'x-trmr-product': self.product_id,
                   'x-trmr-rootguid': self.root_guid}
        request_url = self.url + "/v1/document/{}/{}".format(collection, guid)
        r = requests.get(request_url, headers=headers)

        response_element = etree.fromstring(r.text)
        doc_xml_string = etree.tostring(response_element.xpath("./doc")[0])
        return doc_xml_string

    def search(self, query):
        print query.get_query_string()
        headers = {'Content-type' : 'application/xml',
                   'x-trmr-product': self.product_id,
                   'x-trmr-rootguid': self.root_guid}
        request_url = self.url + "/v1/search"
        xml_body = """<tns:SearchRequest xmlns:tns="http://west.newsroom.westlan.com/newsroom/v1" queryType="BOOLEAN" collectionSet="{}" exactMatch="false" fullWidthToHalfWidthConversionEnabled="false" querySyntax="NATIVE" useQueryWarnings="true" cacheSearchResults="true" maxResultsToReturn="10000" highlightWordRanges="true" idOnly="false" ignoreStopWords="true" returnLatestBookmark="false" filterDuplicates="true" returnSearchSummaryResultOnly="false">
                    <query>
                        <![CDATA[ {} ]]>
                    </query>
                 </tns:SearchRequest>""".format(self.collection_set, query.get_query_string())
        #print xml_body
        return requests.post(request_url, headers=headers, data=xml_body)

    def retrieve_hits(self, name, permid=None, languages=["en"], search_terms={}):
        permid_query_term = [permid] if permid else []
        query = NovusSearchQuery(name, permid_query_term, languages, search_terms)
        hits = []
        r = self.search(query)
        root = etree.fromstring(r.text)
        for element in root.iter("doc"):
            title = element.xpath("n-docbody/document/title-info")[0].xpath("string()")
            hits.append(SearchHit(query, element.get("collection"), element.get("guid"), headline=title))

        return hits

# %%
from datetime import datetime, timedelta
import calendar

def has_exact_date(row):
    """
    check the excistence of the exact date
    """
    answer = not(row["exact_date"] == "00")
    return answer
    
def generate_exact_dates(exact_date, delta_days_before = 8, delta_days_after = 45):
    """
    return a 14-day interval for an exact date
    """
    date_object = datetime.strptime(exact_date, '%d %B %Y')
    date_from = date_object - timedelta(days = delta_days_before)  
    date_to = date_object + timedelta(days = delta_days_after)  
    return date_from, date_to


def generate_rough_dates(rough_date_in):
    date_from = datetime.strptime(rough_date_in, '%B %Y').date()
    month = date_from.month
    year = date_from.year
    last_day =  calendar.monthrange(year,month)[1]
    date_to = datetime.strptime(str(year)+str(month)+str(last_day), '%Y%m%d').date()
    rough_date = date_from.strftime("%Y%m")
    return date_from, date_to, rough_date


# from http://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python
from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

#start_date = date(2013, 1, 1)
#end_date = date(2015, 6, 2)

# %% [markdown]
# -------- Up until this point, it is identical to Amir's Code -------

# %% [markdown]
# ## Class 2 Exact Date

# %%
## function of exact_date
def generate_class2_exact_dates(exact_date, delta_days_before = 8, delta_days_after = 45, class2_before_window = 120, class2_after_window = 120):
    """
    return a 14-day interval for an exact date
    """
    date_object = datetime.strptime(exact_date, '%d %B %Y')
    class2_preevent_end = date_object - timedelta(days = delta_days_before + 1)
    class2_preevent_start = class2_preevent_end - timedelta(days = class2_before_window)
    class2_postevent_start = date_object + timedelta(days = delta_days_after + 1)  
    class2_postevent_end = class2_postevent_start +  timedelta(days = class2_after_window) 
    
    return class2_preevent_start, class2_preevent_end, class2_postevent_start, class2_postevent_end

# %%
generate_class2_exact_dates('20 June 2010')
# Out:
# (datetime.datetime(2010, 2, 11, 0, 0),
#  datetime.datetime(2010, 6, 11, 0, 0),
#  datetime.datetime(2010, 8, 5, 0, 0),
#  datetime.datetime(2010, 12, 3, 0, 0))

# %% [markdown]
# ## Class 2 Rough Date

# %%
def generate_class2_rough_dates(rough_date_in, class2_preevent_window = 120, class2_postevent_window = 120):
    date_from, date_to, rough_date = generate_rough_dates(rough_date_in)
    class2_preevent_end = date_from - timedelta(days = 1)
    class2_preevent_start = class2_preevent_end - timedelta(days = class2_preevent_window)
    class2_postevent_start = date_to + timedelta(days = 1)  
    class2_postevent_end = class2_postevent_start +  timedelta(days = class2_postevent_window) 
    return class2_preevent_start, class2_preevent_end, class2_postevent_start, class2_postevent_end

# %%
generate_class2_rough_dates('December 2010')
# Out:
# (datetime.date(2010, 8, 2),
#  datetime.date(2010, 11, 30),
#  datetime.date(2011, 1, 1),
#  datetime.date(2011, 5, 1))

# %%
## For all text, replace ; with ,
## Use ; as separator

client = make_prod_client()

# read events file
df = pd.read_csv('../data/usbank_permid.csv',index_col=0)

# output file:
a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
a.to_csv("./output_dir/usbank_class1.csv")

# %% [markdown]
# ## Remove # before run. Otherwise, it won't save files

# %%
start_time = datetime.now()

for index, row in df[623:].iterrows():
    
    if (index % 10 == 0) & (index > 0):
        time.sleep(300)
        
    output_name = './output_dir/class2_' + str(index) + '.csv'
    
    a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
    a.to_csv(output_name)

    print index
    print row["id"]
    permid = string.split(row["id"], "-")[1]
    print row["exact_date"]
    class2_preevent_start, class2_preevent_end, class2_postevent_start, class2_postevent_end = generate_class2_exact_dates(row["exact_date"])
    print("found exact date", permid)
    class2_preevent_daterange = list(daterange(class2_preevent_start, class2_preevent_end))
    class2_postevent_daterange = list(daterange(class2_postevent_start, class2_postevent_end))
    for single_date in class2_preevent_daterange + class2_postevent_daterange:
        a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
        exact_date = single_date.strftime("%Y%m%d")
        search_terms = {'DATE':[exact_date]}
        hits = client.retrieve_hits("corning_query", permid, search_terms=search_terms)
        for hit in hits:
            client.get_document(hit)
            doc = novus_document.NewsroomNovusDocument(hit.document_xml)
            article = [permid, doc.date(), doc.headline_or_title(), doc.get_stripped_text().replace("\n"," ").replace(';',',')]
            a1 = pd.DataFrame(article, index=["permid", "date", "headline", "txt"]).T
            a = pd.concat([a,a1])
        a.to_csv("./output_dir/usbank_class2.csv", mode='a', header=False, encoding='utf-8')
        a.to_csv(output_name, mode='a',header=False, encoding='utf-8')

end_time = datetime.now()
print 'Elapsed:', end_time - start_time

# %%
## For all text, replace ; with ,
## Use ; as separator

client = make_prod_client()

# read events file
df_overlap = pd.read_csv('../data/usbank_overlap.csv')
#df = df.reset_index(drop=True)
#df['date'] = df['date'].map(lambda x: convert_rough_date(x))
#df['exact_date'] = df['exact_date'].map(lambda x: convert_exact_date(x) if x == x else "00")

# output file:
a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
a.to_csv("./class2_tagged.csv")

# %% [markdown]
# The server tends to get slow after a while. So I made it rest for 1 minute after each run of 10 queries.
# Note that for Class 2, it takes 15 - 25 min per 10 queries.

# %% [markdown]
# 1. Extracts time interval for two Class 2 windows using generate_class2_exact_date or generate_class2_rough_date
# 2. Add two

# %%
start_time = datetime.now()

for index, row in df.iterrows():
    
    if (index % 10 == 0) & (index > 0):
        time.sleep(60)
        
    #output_name = './class2_article_event ' + str(index) + '.csv'
    
    #a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
    #a.to_csv(output_name)

    print index
    print row["id"]
    permid = string.split(row["id"], "-")[1]
    if has_exact_date(row):
        print row["exact_date"]
        class2_preevent_start, class2_preevent_end, class2_postevent_start, class2_postevent_end = generate_class2_exact_dates(row["exact_date"])
        print("found exact date", permid)
    else:
        print row['date']
        print("got a rough date", permid)
        class2_preevent_start, class2_preevent_end, class2_postevent_start, class2_postevent_end = generate_class2_rough_dates(row["date"])
    class2_preevent_daterange = list(daterange(class2_preevent_start, class2_preevent_end))
    class2_postevent_daterange = list(daterange(class2_postevent_start, class2_postevent_end))
    for single_date in class2_preevent_daterange + class2_postevent_daterange:
        a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
        exact_date = single_date.strftime("%Y%m%d")
        search_terms = {'DATE':[exact_date]}
        hits = client.retrieve_hits("corning_query", permid, search_terms=search_terms)
        for hit in hits:
            client.get_document(hit)
            doc = novus_document.NewsroomNovusDocument(hit.document_xml)
            article = [permid, doc.date(), doc.headline_or_title(), doc.get_stripped_text().replace("\n"," ").replace(';',',')]
            a1 = pd.DataFrame(article, index=["permid", "date", "headline", "txt"]).T
            a = pd.concat([a,a1])
        #a.to_csv("class2_tagged.csv", mode='a', header=False, encoding='utf-8')
        #a.to_csv(output_name, mode='a',header=False, encoding='utf-8')

end_time = datetime.now()
print 'Elapsed:', end_time - start_time
# Out:
# 0
# https://permid.org/1-4295903973
# 07 September 2008
# ('found exact date', '4295903973')
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080501)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080501)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080501)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080502)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080502)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080502)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080503)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080503)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080503)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080504)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080504)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080504)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080505)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080505)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080505)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080506)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080506)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080506)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080507)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080507)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080507)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080508)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080508)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080508)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080509)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080509)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080509)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080510)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080510)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080510)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080511)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080511)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080511)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080512)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080512)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080512)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080513)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080513)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080513)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080514)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080514)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080514)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080515)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080515)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080515)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080516)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080516)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080516)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080517)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080517)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080517)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080518)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080518)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080518)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080519)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080519)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080519)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080520)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080520)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080520)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080521)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080521)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080521)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080522)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080522)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080522)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080523)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080523)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080523)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080524)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080524)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080524)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080525)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080525)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080525)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080526)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080526)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080526)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080527)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080527)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080527)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080528)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080528)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080528)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080529)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080529)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080529)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080530)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080530)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080530)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080531)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080531)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080531)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080601)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080601)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080601)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080602)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080602)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080602)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080603)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080603)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080603)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080604)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080604)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080604)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080605)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080605)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080605)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080606)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080606)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080606)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080607)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080607)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080607)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080608)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080608)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080608)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080609)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080609)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080609)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080610)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080610)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080610)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080611)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080611)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080611)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080612)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080612)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080612)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080613)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080613)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080613)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080614)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080614)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080614)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080615)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080615)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080615)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080616)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080616)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080616)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080617)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080617)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080617)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080618)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080618)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080618)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080619)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080619)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080619)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080620)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080620)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080620)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080621)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080621)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080621)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080622)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080622)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080622)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080623)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080623)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080623)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080624)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080624)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080624)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080625)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080625)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080625)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080626)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080626)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080626)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080627)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080627)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080627)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080628)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080628)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080628)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080629)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080629)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080629)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080630)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080630)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080630)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080701)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080701)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080701)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080702)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080702)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080702)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080703)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080703)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080703)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080704)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080704)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080704)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080705)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080705)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080705)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080706)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080706)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080706)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080707)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080707)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080707)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080708)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080708)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080708)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080709)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080709)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080709)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080710)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080710)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080710)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080711)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080711)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080711)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080712)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080712)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080712)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080713)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080713)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080713)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080714)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080714)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080714)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080715)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080715)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080715)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080716)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080716)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080716)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080717)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080717)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080717)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080718)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080718)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080718)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080719)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080719)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080719)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080720)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080720)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080720)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080721)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080721)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080721)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080722)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080722)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080722)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080723)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080723)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080723)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080724)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080724)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080724)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080725)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080725)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080725)

# %%
import time

start_time = datetime.now()

for index, row in df_eikon.iterrows():
    
    if (index % 10 == 0) & (index > 0):
        time.sleep(60)
    
    print index
    output_name = './output_dir/class1_eikon_' + str(index) + '.csv'
    
    a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
    a.to_csv(output_name)

    print row["id"]
    permid = string.split(row["id"], "-")[1]
    date_from, date_to = generate_exact_dates(row["exact_date"])
    print(permid, row["exact_date"], date_from, date_to)
    for single_date in daterange(date_from, date_to):
        a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
        exact_date = single_date.strftime("%Y%m%d")
        search_terms = {'DATE':[exact_date]}
        hits = client.retrieve_hits("corning_query", permid, search_terms=search_terms)
        for hit in hits:
            client.get_document(hit)
            doc = novus_document.NewsroomNovusDocument(hit.document_xml)
            article = [permid, doc.date(), doc.headline_or_title(), doc.get_stripped_text().replace("\n"," ").replace(';',',')]
            a1 = pd.DataFrame(article, index=["permid", "date", "headline", "txt"]).T
            a = pd.concat([a,a1])
        a.to_csv("./output_dir/usbank_class1_eikon.csv", mode='a', header=False, encoding='utf-8')
        a.to_csv(output_name,mode='a',header=False, encoding='utf-8')

    time.sleep(0.5)
    
end_time = datetime.now()
print 'Elapsed:', end_time - start_time
# Out:
# 0
# https://permid.org/1-4295903973
# ('4295903973', '07 September 2008', datetime.datetime(2008, 8, 30, 0, 0), datetime.datetime(2008, 10, 22, 0, 0))
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080830)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080830)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080830)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080831)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080831)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080831)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080901)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080901)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080901)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080902)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080902)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080902)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080903)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080903)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080903)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080904)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080904)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080904)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080905)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080905)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080905)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080906)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080906)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080906)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080907)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080907)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080907)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080908)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080908)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080908)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080909)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080909)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080909)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080910)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080910)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080910)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080911)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080911)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080911)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080912)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080912)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080912)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080913)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080913)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080913)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080914)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080914)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080914)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080915)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080915)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080915)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080916)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080916)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080916)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080917)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080917)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080917)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080918)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080918)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080918)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080919)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080919)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080919)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080920)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080920)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080920)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080921)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080921)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080921)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080922)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080922)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080922)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080923)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080924)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080925)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080926)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080927)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080928)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080929)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080930)
# OAID(4295903973) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081001)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081002)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081003)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081004)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081005)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081006)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081007)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081008)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081009)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081010)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081011)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081012)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081013)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081014)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081015)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081016)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081017)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081018)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081019)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081020)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081021)
# OAID(4295903973) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295903973) & LANGUAGE(en) & DATE(20081021)
# 1
# https://permid.org/1-4295903970
# ('4295903970', '07 September 2008', datetime.datetime(2008, 8, 30, 0, 0), datetime.datetime(2008, 10, 22, 0, 0))
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080830)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080830)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080830)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080831)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080831)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080831)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080901)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080901)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080901)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080902)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080902)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080902)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080903)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080903)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080903)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080904)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080904)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080904)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080905)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080905)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080905)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080906)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080906)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080906)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080907)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080907)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080907)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080908)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080908)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080908)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080909)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080909)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080909)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080910)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080910)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080910)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080911)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080911)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080911)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080912)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080912)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080912)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080913)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080913)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080913)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080914)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080914)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080914)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080915)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080915)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080915)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080916)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080916)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080916)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080917)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080917)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080917)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080918)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080918)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080918)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080919)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080919)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080919)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080920)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080920)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080920)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080921)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080921)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080921)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080922)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080922)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080922)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080923)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080924)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080925)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080926)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080927)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080928)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080929)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080930)
# OAID(4295903970) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081001)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081002)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081003)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081004)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081005)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081006)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081007)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081008)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081009)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081010)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081011)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081012)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081013)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081014)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081015)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081016)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081017)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081018)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081019)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081020)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081021)
# OAID(4295903970) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295903970) & LANGUAGE(en) & DATE(20081021)
# 2
# https://permid.org/1-4295903341
# ('4295903341', '16 September 2008', datetime.datetime(2008, 9, 8, 0, 0), datetime.datetime(2008, 10, 31, 0, 0))
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080908)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080908)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080908)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080909)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080909)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080909)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080910)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080910)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080910)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080911)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080911)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080911)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080912)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080912)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080912)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080913)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080913)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080913)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080914)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080914)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080914)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080915)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080915)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080915)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080916)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080916)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080916)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080917)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080917)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080917)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080918)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080918)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080918)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080919)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080919)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080919)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080920)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080920)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080920)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080921)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080921)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080921)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080922)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080922)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080922)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080923)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080924)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080925)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080926)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080927)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080928)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080929)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080930)
# OAID(4295903341) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081001)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081002)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081003)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081004)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081005)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081006)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081007)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081008)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081009)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081010)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081011)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081012)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081013)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081014)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081015)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081016)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081017)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081018)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081019)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081020)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081021)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081022)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081023)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081024)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081025)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081026)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081027)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081028)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081029)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081030)
# OAID(4295903341) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(4295903341) & LANGUAGE(en) & DATE(20081030)
# 3
# https://permid.org/1-4295914749
# ('4295914749', '24 October 2008', datetime.datetime(2008, 10, 16, 0, 0), datetime.datetime(2008, 12, 8, 0, 0))
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081016)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081017)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081018)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081019)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081020)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081021)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081022)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081023)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081024)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081025)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081026)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081027)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081028)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081029)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081030)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081031)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081031)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081031)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081101)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081101)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081101)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081102)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081102)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081102)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081103)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081103)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081103)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081104)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081104)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081104)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081105)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081105)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081105)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081106)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081106)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081106)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081107)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081107)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081107)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081108)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081108)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081108)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081109)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081109)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081109)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081110)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081110)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081110)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081111)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081111)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081111)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081112)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081112)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081112)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081113)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081113)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081113)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081114)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081114)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081114)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081115)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081115)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081115)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081116)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081116)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081116)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081117)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081117)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081117)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081118)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081118)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081118)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081119)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081119)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081119)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081120)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081120)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081120)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081121)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081121)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081121)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081122)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081122)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081122)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081123)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081123)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081123)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081124)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081124)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081124)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081125)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081125)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081125)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081126)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081126)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081126)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081127)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081127)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081127)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081128)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081128)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081128)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081129)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081129)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081129)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081130)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081130)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081130)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081201)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081201)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081201)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081202)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081202)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081202)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081203)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081203)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081203)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081204)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081204)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081204)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081205)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081205)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081205)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081206)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081206)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081206)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081207)
# OAID(4295914749) & LANGUAGE(en) & DATE(20081207)
# NovusQuery:  OAID(4295914749) & LANGUAGE(en) & DATE(20081207)
# 4
# https://permid.org/1-8589934248
# ('8589934248', '26 October 2008', datetime.datetime(2008, 10, 18, 0, 0), datetime.datetime(2008, 12, 10, 0, 0))
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081018)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081019)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081020)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081021)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081022)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081023)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081024)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081025)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081026)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081027)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081028)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081029)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081030)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081031)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081031)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081031)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081101)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081101)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081101)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081102)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081102)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081102)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081103)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081103)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081103)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081104)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081104)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081104)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081105)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081105)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081105)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081106)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081106)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081106)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081107)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081107)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081107)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081108)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081108)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081108)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081109)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081109)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081109)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081110)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081110)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081110)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081111)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081111)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081111)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081112)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081112)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081112)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081113)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081113)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081113)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081114)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081114)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081114)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081115)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081115)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081115)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081116)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081116)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081116)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081117)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081117)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081117)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081118)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081118)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081118)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081119)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081119)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081119)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081120)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081120)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081120)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081121)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081121)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081121)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081122)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081122)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081122)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081123)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081123)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081123)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081124)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081124)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081124)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081125)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081125)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081125)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081126)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081126)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081126)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081127)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081127)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081127)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081128)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081128)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081128)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081129)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081129)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081129)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081130)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081130)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081130)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081201)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081201)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081201)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081202)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081202)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081202)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081203)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081203)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081203)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081204)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081204)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081204)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081205)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081205)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081205)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081206)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081206)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081206)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081207)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081207)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081207)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081208)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081208)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081208)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081209)
# OAID(8589934248) & LANGUAGE(en) & DATE(20081209)
# NovusQuery:  OAID(8589934248) & LANGUAGE(en) & DATE(20081209)
# 5
# https://permid.org/1-4295906733
# ('4295906733', '27 October 2008', datetime.datetime(2008, 10, 19, 0, 0), datetime.datetime(2008, 12, 11, 0, 0))
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081019)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081020)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081021)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081022)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081023)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081024)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081025)
# OAID(4295906733) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4295906733) & LANGUAGE(en) & DATE(20081026)
# ...
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091228)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091229)
# OAID(5000181211) & LANGUAGE(en) & DATE(20091229)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091229)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091230)
# OAID(5000181211) & LANGUAGE(en) & DATE(20091230)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091230)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091231)
# OAID(5000181211) & LANGUAGE(en) & DATE(20091231)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20091231)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100101)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100101)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100101)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100102)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100102)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100102)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100103)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100103)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100103)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100104)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100104)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100104)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100105)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100105)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100105)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100106)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100106)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100106)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100107)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100107)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100107)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100108)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100108)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100108)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100109)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100109)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100109)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100110)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100110)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100110)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100111)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100111)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100111)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100112)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100112)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100112)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100113)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100113)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100113)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100114)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100114)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100114)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100115)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100115)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100115)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100116)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100116)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100116)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100117)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100117)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100117)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100118)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100118)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100118)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100119)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100119)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100119)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100120)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100120)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100120)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100121)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100121)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100121)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100122)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100122)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100122)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100123)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100123)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100123)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100124)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100124)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100124)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100125)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100125)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100125)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100126)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100126)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100126)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100127)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100127)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100127)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100128)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100128)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100128)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100129)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100129)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100129)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100130)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100130)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100130)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100131)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100131)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100131)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100201)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100201)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100201)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100202)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100202)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100202)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100203)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100203)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100203)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100204)
# OAID(5000181211) & LANGUAGE(en) & DATE(20100204)
# NovusQuery:  OAID(5000181211) & LANGUAGE(en) & DATE(20100204)
# 71
# https://permid.org/1-4295900840
# ('4295900840', '30 December 2009', datetime.datetime(2009, 12, 22, 0, 0), datetime.datetime(2010, 2, 13, 0, 0))
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091222)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091222)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091222)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091223)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091223)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091223)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091224)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091224)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091224)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091225)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091225)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091225)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091226)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091226)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091226)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091227)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091227)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091227)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091228)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091228)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091228)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091229)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091229)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091229)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091230)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091230)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091230)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091231)
# OAID(4295900840) & LANGUAGE(en) & DATE(20091231)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20091231)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100101)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100101)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100101)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100102)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100102)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100102)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100103)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100103)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100103)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100104)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100104)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100104)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100105)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100105)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100105)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100106)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100106)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100106)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100107)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100107)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100107)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100108)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100108)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100108)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100109)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100109)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100109)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100110)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100110)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100110)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100111)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100111)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100111)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100112)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100112)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100112)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100113)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100113)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100113)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100114)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100114)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100114)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100115)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100115)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100115)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100116)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100116)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100116)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100117)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100117)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100117)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100118)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100118)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100118)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100119)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100119)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100119)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100120)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100120)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100120)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100121)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100121)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100121)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100122)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100122)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100122)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100123)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100123)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100123)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100124)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100124)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100124)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100125)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100125)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100125)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100126)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100126)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100126)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100127)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100127)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100127)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100128)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100128)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100128)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100129)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100129)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100129)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100130)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100130)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100130)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100131)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100131)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100131)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100201)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100201)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100201)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100202)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100202)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100202)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100203)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100203)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100203)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100204)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100204)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100204)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100205)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100205)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100205)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100206)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100206)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100206)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100207)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100207)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100207)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100208)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100208)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100208)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100209)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100209)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100209)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100210)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100210)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100210)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100211)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100211)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100211)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100212)
# OAID(4295900840) & LANGUAGE(en) & DATE(20100212)
# NovusQuery:  OAID(4295900840) & LANGUAGE(en) & DATE(20100212)
# Elapsed: 0:55:32.442525

# %%
## For all text, replace ; with ,
## Use ; as separator

client = make_prod_client()

# read events file
df_eikon = pd.read_csv('../data/usbank_only_in_eikon.csv')
#df = df.reset_index(drop=True)
#df['date'] = df['date'].map(lambda x: convert_rough_date(x))
#df['exact_date'] = df['exact_date'].map(lambda x: convert_exact_date(x) if x == x else "00")

# output file:
a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
a.to_csv("./output_dir/usbank_class1_eikon.csv")

# %%
start_time = datetime.now()


a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
a.to_csv("./output_dir/usbank_class2_overlap.csv")

for index, row in df_overlap.iterrows():
    
    if (index % 10 == 0) & (index > 0):
        time.sleep(60)
        
    output_name = './output_dir/class2_overlap_' + str(index) + '.csv'
    
    a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
    a.to_csv(output_name)

    print index
    print row["id"]
    permid = string.split(row["id"], "-")[1]
    print row["exact_date"]
    class2_preevent_start, class2_preevent_end, class2_postevent_start, class2_postevent_end = generate_class2_exact_dates(row["exact_date"])
    print("found exact date", permid)
    class2_preevent_daterange = list(daterange(class2_preevent_start, class2_preevent_end))
    class2_postevent_daterange = list(daterange(class2_postevent_start, class2_postevent_end))
    for single_date in class2_preevent_daterange + class2_postevent_daterange:
        a = pd.DataFrame(index=["permid", "date", "headline", "txt"]).T
        exact_date = single_date.strftime("%Y%m%d")
        search_terms = {'DATE':[exact_date]}
        hits = client.retrieve_hits("corning_query", permid, search_terms=search_terms)
        for hit in hits:
            client.get_document(hit)
            doc = novus_document.NewsroomNovusDocument(hit.document_xml)
            article = [permid, doc.date(), doc.headline_or_title(), doc.get_stripped_text().replace("\n"," ").replace(';',',')]
            a1 = pd.DataFrame(article, index=["permid", "date", "headline", "txt"]).T
            a = pd.concat([a,a1])
        a.to_csv("./output_dir/usbank_class2_overlap.csv", mode='a', header=False, encoding='utf-8')
        a.to_csv(output_name, mode='a',header=False, encoding='utf-8')

end_time = datetime.now()
print 'Elapsed:', end_time - start_time
# Out:
# 0
# https://permid.org/1-4296525121
# 27 February 2009
# ('found exact date', '4296525121')
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081021)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081022)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081023)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081024)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081025)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081026)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081027)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081028)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081029)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081029)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081030)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081030)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081031)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081031)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081031)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081101)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081101)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081101)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081102)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081102)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081102)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081103)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081103)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081103)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081104)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081104)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081104)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081105)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081105)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081105)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081106)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081106)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081106)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081107)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081107)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081107)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081108)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081108)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081108)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081109)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081109)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081109)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081110)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081110)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081110)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081111)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081111)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081111)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081112)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081112)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081112)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081113)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081113)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081113)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081114)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081114)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081114)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081115)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081115)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081115)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081116)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081116)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081116)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081117)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081117)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081117)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081118)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081118)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081118)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081119)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081119)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081119)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081120)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081120)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081120)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081121)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081121)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081121)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081122)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081122)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081122)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081123)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081123)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081123)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081124)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081124)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081124)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081125)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081125)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081125)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081126)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081126)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081126)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081127)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081127)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081127)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081128)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081128)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081128)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081129)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081129)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081129)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081130)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081130)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081130)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081201)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081201)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081201)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081202)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081202)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081202)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081203)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081203)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081203)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081204)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081204)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081204)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081205)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081205)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081205)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081206)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081206)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081206)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081207)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081207)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081207)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081208)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081208)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081208)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081209)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081209)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081209)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081210)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081210)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081210)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081211)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081211)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081211)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081212)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081212)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081212)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081213)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081213)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081213)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081214)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081214)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081214)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081215)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081215)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081215)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081216)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081216)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081216)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081217)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081217)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081217)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081218)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081218)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081218)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081219)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081219)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081219)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081220)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081220)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081220)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081221)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081221)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081221)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081222)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081222)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081222)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081223)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081223)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081223)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081224)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081224)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081224)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081225)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081225)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081225)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081226)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081226)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081226)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081227)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081227)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081227)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081228)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081228)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081228)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081229)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081229)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081229)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081230)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081230)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081230)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081231)
# OAID(4296525121) & LANGUAGE(en) & DATE(20081231)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20081231)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090101)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090101)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090101)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090102)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090102)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090102)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090103)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090103)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090103)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090104)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090104)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090104)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090105)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090105)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090105)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090106)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090106)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090106)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090107)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090107)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090107)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090108)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090108)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090108)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090109)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090109)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090109)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090110)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090110)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090110)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090111)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090111)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090111)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090112)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090112)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090112)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090113)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090113)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090113)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090114)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090114)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090114)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090115)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090115)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090115)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090116)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090116)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090116)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090117)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090117)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090117)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090118)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090118)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090118)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090119)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090119)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090119)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090120)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090120)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090120)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090121)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090121)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090121)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090122)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090122)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090122)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090123)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090123)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090123)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090124)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090124)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090124)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090125)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090125)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090125)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090126)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090126)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090126)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090127)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090127)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090127)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090128)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090128)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090128)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090129)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090129)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090129)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090130)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090130)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090130)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090131)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090131)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090131)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090201)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090201)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090201)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090202)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090202)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090202)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090203)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090203)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090203)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090204)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090204)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090204)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090205)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090205)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090205)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090206)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090206)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090206)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090207)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090207)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090207)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090208)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090208)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090208)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090209)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090209)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090209)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090210)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090210)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090210)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090211)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090211)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090211)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090212)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090212)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090212)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090213)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090213)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090213)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090214)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090214)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090214)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090215)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090215)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090215)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090216)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090216)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090216)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090217)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090217)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090217)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090414)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090414)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090414)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090415)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090415)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090415)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090416)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090416)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090416)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090417)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090417)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090417)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090418)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090418)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090418)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090419)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090419)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090419)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090420)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090420)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090420)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090421)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090421)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090421)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090422)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090422)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090422)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090423)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090423)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090423)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090424)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090424)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090424)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090425)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090425)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090425)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090426)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090426)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090426)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090427)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090427)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090427)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090428)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090428)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090428)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090429)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090429)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090429)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090430)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090430)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090430)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090501)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090501)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090501)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090502)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090502)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090502)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090503)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090503)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090503)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090504)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090504)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090504)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090505)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090505)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090505)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090506)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090506)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090506)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090507)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090507)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090507)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090508)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090508)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090508)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090509)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090509)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090509)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090510)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090510)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090510)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090511)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090511)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090511)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090512)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090512)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090512)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090513)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090513)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090513)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090514)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090514)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090514)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090515)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090515)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090515)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090516)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090516)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090516)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090517)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090517)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090517)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090518)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090518)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090518)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090519)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090519)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090519)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090520)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090520)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090520)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090521)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090521)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090521)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090522)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090522)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090522)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090523)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090523)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090523)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090524)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090524)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090524)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090525)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090525)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090525)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090526)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090526)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090526)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090527)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090527)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090527)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090528)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090528)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090528)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090529)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090529)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090529)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090530)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090530)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090530)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090531)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090531)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090531)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090601)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090601)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090601)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090602)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090602)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090602)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090603)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090603)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090603)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090604)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090604)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090604)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090605)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090605)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090605)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090606)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090606)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090606)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090607)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090607)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090607)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090608)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090608)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090608)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090609)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090609)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090609)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090610)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090610)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090610)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090611)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090611)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090611)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090612)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090612)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090612)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090613)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090613)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090613)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090614)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090614)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090614)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090615)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090615)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090615)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090616)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090616)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090616)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090617)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090617)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090617)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090618)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090618)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090618)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090619)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090619)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090619)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090620)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090620)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090620)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090621)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090621)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090621)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090622)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090622)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090622)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090623)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090623)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090623)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090624)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090624)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090624)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090625)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090625)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090625)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090626)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090626)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090626)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090627)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090627)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090627)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090628)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090628)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090628)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090629)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090629)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090629)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090630)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090630)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090630)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090701)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090701)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090701)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090702)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090702)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090702)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090703)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090703)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090703)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090704)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090704)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090704)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090705)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090705)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090705)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090706)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090706)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090706)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090707)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090707)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090707)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090708)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090708)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090708)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090709)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090709)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090709)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090710)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090710)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090710)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090711)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090711)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090711)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090712)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090712)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090712)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090713)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090713)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090713)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090714)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090714)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090714)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090715)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090715)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090715)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090716)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090716)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090716)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090717)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090717)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090717)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090718)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090718)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090718)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090719)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090719)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090719)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090720)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090720)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090720)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090721)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090721)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090721)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090722)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090722)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090722)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090723)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090723)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090723)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090724)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090724)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090724)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090725)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090725)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090725)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090726)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090726)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090726)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090727)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090727)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090727)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090728)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090728)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090728)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090729)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090729)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090729)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090730)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090730)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090730)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090731)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090731)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090731)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090801)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090801)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090801)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090802)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090802)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090802)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090803)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090803)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090803)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090804)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090804)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090804)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090805)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090805)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090805)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090806)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090806)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090806)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090807)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090807)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090807)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090808)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090808)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090808)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090809)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090809)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090809)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090810)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090810)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090810)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090811)
# OAID(4296525121) & LANGUAGE(en) & DATE(20090811)
# NovusQuery:  OAID(4296525121) & LANGUAGE(en) & DATE(20090811)
# 1
# https://permid.org/1-4296965253
# 30 January 2009
# ('found exact date', '4296965253')
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080923)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080923)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080924)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080924)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080925)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080925)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080926)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080926)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080927)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080927)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080928)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080928)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080929)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080929)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080930)
# OAID(4296965253) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20080930)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081001)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081001)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081002)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081002)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081003)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081003)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081004)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081004)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081005)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081005)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081006)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081006)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081007)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081007)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081008)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081008)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081009)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081009)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081010)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081010)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081011)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081011)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081012)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081012)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081013)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081013)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081014)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081014)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081015)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081015)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081016)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081016)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081017)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081017)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081018)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081018)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081019)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081019)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081020)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081020)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081021)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081021)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081022)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081022)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081023)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081023)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081024)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081024)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081025)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081025)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081026)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081026)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081027)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081027)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081028)
# OAID(4296965253) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081028)
# NovusQuery:  OAID(4296965253) & LANGUAGE(en) & DATE(20081029)
# ...
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090331)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090331)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090331)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090401)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090401)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090401)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090402)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090402)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090402)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090403)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090403)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090403)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090404)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090404)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090404)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090405)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090405)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090405)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090406)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090406)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090406)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090407)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090407)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090407)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090408)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090408)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090408)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090409)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090409)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090409)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090410)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090410)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090410)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090411)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090411)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090411)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090412)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090412)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090412)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090413)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090413)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090413)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090414)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090414)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090414)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090415)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090415)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090415)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090416)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090416)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090416)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090417)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090417)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090417)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090418)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090418)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090418)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090419)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090419)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090419)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090420)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090420)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090420)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090421)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090421)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090421)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090422)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090422)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090422)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090423)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090423)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090423)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090424)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090424)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090424)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090425)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090425)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090425)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090426)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090426)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090426)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090427)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090427)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090427)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090428)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090428)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090428)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090429)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090429)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090429)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090430)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090430)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090430)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090501)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090501)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090501)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090502)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090502)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090502)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090503)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090503)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090503)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090504)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090504)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090504)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090505)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090505)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090505)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090506)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090506)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090506)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090507)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090507)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090507)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090508)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090508)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090508)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090509)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090509)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090509)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090510)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090510)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090510)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090511)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090511)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090511)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090512)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090512)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090512)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090513)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090513)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090513)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090514)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090514)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090514)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090515)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090515)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090515)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090516)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090516)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090516)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090517)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090517)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090517)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090518)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090518)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090518)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090519)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090519)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090519)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090520)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090520)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090520)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090521)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090521)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090521)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090522)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090522)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090522)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090523)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090523)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090523)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090524)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090524)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090524)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090525)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090525)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090525)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090526)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090526)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090526)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090527)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090527)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090527)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090528)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090528)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090528)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090529)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090529)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090529)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090530)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090530)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090530)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090531)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090531)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090531)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090601)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090601)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090601)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090602)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090602)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090602)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090603)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090603)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090603)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090604)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090604)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090604)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090605)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090605)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090605)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090606)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090606)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090606)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090607)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090607)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090607)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090608)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090608)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090608)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090609)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090609)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090609)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090610)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090610)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090610)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090611)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090611)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090611)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090612)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090612)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090612)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090613)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090613)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090613)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090614)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090614)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090614)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090615)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090615)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090615)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090616)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090616)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090616)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090617)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090617)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090617)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090618)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090618)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090618)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090619)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090619)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090619)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090620)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090620)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090620)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090621)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090621)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090621)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090622)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090622)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090622)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090623)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090623)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090623)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090624)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090624)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090624)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090625)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090625)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090625)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090626)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090626)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090626)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090627)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090627)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090627)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090628)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090628)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090628)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090629)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090629)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090629)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090630)
# OAID(4295906616) & LANGUAGE(en) & DATE(20090630)
# NovusQuery:  OAID(4295906616) & LANGUAGE(en) & DATE(20090630)
# Elapsed: 0:21:12.824038
