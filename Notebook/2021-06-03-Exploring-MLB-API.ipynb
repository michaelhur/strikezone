# %% [markdown]
# ### This notebook explores and attempts to systemically extract data from the MLB Stats API. The approach aligns with [this blog post](https://michaelhur.github.io/PyMLB)

# %% [markdown]
# This post has three goals:
#
# 1. From the `schedule` key, we extract the `game_pk` of the opening game of 2021 season.
# 2. Using this `game_pk`, we extract the `play-By-Play` data of the corresponding `game_pk.`
# 3. Putting it all together so that we can extract other data with a simple change to the query.

# %% [markdown]
# ## Import Libraries

# %%
import requests
import json

# %% [markdown]
# ### 1. Extract `game_pk` from the `schedule` endpoints

# %% [markdown]
# A quick tip:
# - The schedule endpoint requires either 'sportId' or 'game_pk'.
# - Former will be used to obtain schedule on the given date(s).
# - Latter is used to obtain schedule given the unique game ID. Which seems like a backward operation, but think of the scenario where we want to figure out the detailed schedule such as date, venue or home/away of the specific game.
# - Parameter 'sportId' should be 1

# %%
## Production version url
schedule_url = 'http://statsapi.mlb.com/api/v1/schedule?sportId=1&date=04/01/2021'

# %%
schedule_response = requests.get(schedule_url)
schedule_content = schedule_response.content
schedule_json_content = json.loads(schedule_content)

# %% [markdown]
# After a successful load of the content, we want to see what it looks like:

# %%
schedule_json_content
# Out:
# {'copyright': 'Copyright 2021 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'totalItems': 15,
#  'totalEvents': 0,
#  'totalGames': 15,
#  'totalGamesInProgress': 0,
#  'dates': [{'date': '2021-04-01',
#    'totalItems': 15,
#    'totalEvents': 0,
#    'totalGames': 15,
#    'totalGamesInProgress': 0,
#    'games': [{'gamePk': 634642,
#      'link': '/api/v1.1/game/634642/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T17:05:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 1,
#         'losses': 0,
#         'pct': '1.000'},
#        'score': 3,
#        'team': {'id': 141,
#         'name': 'Toronto Blue Jays',
#         'link': '/api/v1/teams/141'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#        'score': 2,
#        'team': {'id': 147,
#         'name': 'New York Yankees',
#         'link': '/api/v1/teams/147'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 3313,
#       'name': 'Yankee Stadium',
#       'link': '/api/v1/venues/3313'},
#      'content': {'link': '/api/v1/game/634642/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634642-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 145,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634645,
#      'link': '/api/v1.1/game/634645/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T17:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 2,
#        'team': {'id': 114,
#         'name': 'Cleveland Indians',
#         'link': '/api/v1/teams/114'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 3,
#        'team': {'id': 116,
#         'name': 'Detroit Tigers',
#         'link': '/api/v1/teams/116'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 2394,
#       'name': 'Comerica Park',
#       'link': '/api/v1/venues/2394'},
#      'content': {'link': '/api/v1/game/634645/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634645-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Tigers home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634638,
#      'link': '/api/v1.1/game/634638/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T18:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 5,
#        'team': {'id': 142,
#         'name': 'Minnesota Twins',
#         'link': '/api/v1/teams/142'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 6,
#        'team': {'id': 158,
#         'name': 'Milwaukee Brewers',
#         'link': '/api/v1/teams/158'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 32,
#       'name': 'American Family Field',
#       'link': '/api/v1/venues/32'},
#      'content': {'link': '/api/v1/game/634638/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634638-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Brewers home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634634,
#      'link': '/api/v1.1/game/634634/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T18:20:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 1,
#         'losses': 0,
#         'pct': '1.000'},
#        'score': 5,
#        'team': {'id': 134,
#         'name': 'Pittsburgh Pirates',
#         'link': '/api/v1/teams/134'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#        'score': 3,
#        'team': {'id': 112,
#         'name': 'Chicago Cubs',
#         'link': '/api/v1/teams/112'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 17, 'name': 'Wrigley Field', 'link': '/api/v1/venues/17'},
#      'content': {'link': '/api/v1/game/634634/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634634-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Cubs home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634622,
#      'link': '/api/v1.1/game/634622/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T19:05:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 2,
#        'team': {'id': 144,
#         'name': 'Atlanta Braves',
#         'link': '/api/v1/teams/144'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 3,
#        'team': {'id': 143,
#         'name': 'Philadelphia Phillies',
#         'link': '/api/v1/teams/143'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 2681,
#       'name': 'Citizens Bank Park',
#       'link': '/api/v1/venues/2681'},
#      'content': {'link': '/api/v1/game/634622/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634622-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Phillies home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634615,
#      'link': '/api/v1.1/game/634615/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T20:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 5,
#        'team': {'id': 119,
#         'name': 'Los Angeles Dodgers',
#         'link': '/api/v1/teams/119'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 8,
#        'team': {'id': 115,
#         'name': 'Colorado Rockies',
#         'link': '/api/v1/teams/115'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 19, 'name': 'Coors Field', 'link': '/api/v1/venues/19'},
#      'content': {'link': '/api/v1/game/634615/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634615-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Rockies home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 145,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634618,
#      'link': '/api/v1.1/game/634618/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T20:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 7,
#        'team': {'id': 109,
#         'name': 'Arizona Diamondbacks',
#         'link': '/api/v1/teams/109'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 8,
#        'team': {'id': 135,
#         'name': 'San Diego Padres',
#         'link': '/api/v1/teams/135'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 2680,
#       'name': 'Petco Park',
#       'link': '/api/v1/venues/2680'},
#      'content': {'link': '/api/v1/game/634618/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634618-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Padres home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634636,
#      'link': '/api/v1.1/game/634636/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T20:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 1,
#         'losses': 0,
#         'pct': '1.000'},
#        'score': 11,
#        'team': {'id': 138,
#         'name': 'St. Louis Cardinals',
#         'link': '/api/v1/teams/138'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#        'score': 6,
#        'team': {'id': 113,
#         'name': 'Cincinnati Reds',
#         'link': '/api/v1/teams/113'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 2602,
#       'name': 'Great American Ball Park',
#       'link': '/api/v1/venues/2602'},
#      'content': {'link': '/api/v1/game/634636/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634636-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Reds home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634630,
#      'link': '/api/v1.1/game/634630/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T20:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 10,
#        'team': {'id': 140,
#         'name': 'Texas Rangers',
#         'link': '/api/v1/teams/140'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 14,
#        'team': {'id': 118,
#         'name': 'Kansas City Royals',
#         'link': '/api/v1/teams/118'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 7,
#       'name': 'Kauffman Stadium',
#       'link': '/api/v1/venues/7'},
#      'content': {'link': '/api/v1/game/634630/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634630-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Royals home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634652,
#      'link': '/api/v1.1/game/634652/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T20:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 1,
#         'losses': 0,
#         'pct': '1.000'},
#        'score': 1,
#        'team': {'id': 139,
#         'name': 'Tampa Bay Rays',
#         'link': '/api/v1/teams/139'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#        'score': 0,
#        'team': {'id': 146,
#         'name': 'Miami Marlins',
#         'link': '/api/v1/teams/146'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 4169,
#       'name': 'loanDepot park',
#       'link': '/api/v1/venues/4169'},
#      'content': {'link': '/api/v1/game/634652/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634652-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Marlins home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634655,
#      'link': '/api/v1.1/game/634655/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-02T02:05:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 3,
#        'team': {'id': 145,
#         'name': 'Chicago White Sox',
#         'link': '/api/v1/teams/145'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 4,
#        'team': {'id': 108,
#         'name': 'Los Angeles Angels',
#         'link': '/api/v1/teams/108'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 1, 'name': 'Angel Stadium', 'link': '/api/v1/venues/1'},
#      'content': {'link': '/api/v1/game/634655/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634655-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'description': 'Angels home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634640,
#      'link': '/api/v1.1/game/634640/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-02T02:07:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 1,
#         'losses': 0,
#         'pct': '1.000'},
#        'score': 8,
#        'team': {'id': 117,
#         'name': 'Houston Astros',
#         'link': '/api/v1/teams/117'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#        'score': 1,
#        'team': {'id': 133,
#         'name': 'Oakland Athletics',
#         'link': '/api/v1/teams/133'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 10,
#       'name': 'Oakland Coliseum',
#       'link': '/api/v1/venues/10'},
#      'content': {'link': '/api/v1/game/634640/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634640-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'description': 'Athletics home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 145,
#      'gamesInSeries': 4,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634625,
#      'link': '/api/v1.1/game/634625/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-02T02:10:00Z',
#      'officialDate': '2021-04-01',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'F',
#       'detailedState': 'Final',
#       'statusCode': 'F',
#       'startTimeTBD': False,
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 0,
#         'losses': 1,
#         'pct': '.000'},
#        'score': 7,
#        'team': {'id': 137,
#         'name': 'San Francisco Giants',
#         'link': '/api/v1/teams/137'},
#        'isWinner': False,
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#        'score': 8,
#        'team': {'id': 136,
#         'name': 'Seattle Mariners',
#         'link': '/api/v1/teams/136'},
#        'isWinner': True,
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 680,
#       'name': 'T-Mobile Park',
#       'link': '/api/v1/venues/680'},
#      'content': {'link': '/api/v1/game/634625/content'},
#      'isTie': False,
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634625-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'description': 'Mariners home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634627,
#      'link': '/api/v1.1/game/634627/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T18:10:00Z',
#      'officialDate': '2021-04-02',
#      'rescheduleDate': '2021-04-02T18:10:00Z',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'D',
#       'detailedState': 'Postponed',
#       'statusCode': 'DR',
#       'startTimeTBD': False,
#       'reason': 'Rain',
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 1,
#         'losses': 0,
#         'pct': '1.000'},
#        'team': {'id': 110,
#         'name': 'Baltimore Orioles',
#         'link': '/api/v1/teams/110'},
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#        'team': {'id': 111,
#         'name': 'Boston Red Sox',
#         'link': '/api/v1/teams/111'},
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 3, 'name': 'Fenway Park', 'link': '/api/v1/venues/3'},
#      'content': {'link': '/api/v1/game/634627/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634627-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'day',
#      'description': 'Red Sox home opener',
#      'scheduledInnings': 9,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 120,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'},
#     {'gamePk': 634647,
#      'link': '/api/v1.1/game/634647/feed/live',
#      'gameType': 'R',
#      'season': '2021',
#      'gameDate': '2021-04-01T23:09:00Z',
#      'officialDate': '2021-06-19',
#      'rescheduleDate': '2021-06-19T17:05:00Z',
#      'status': {'abstractGameState': 'Final',
#       'codedGameState': 'D',
#       'detailedState': 'Postponed',
#       'statusCode': 'DE',
#       'startTimeTBD': False,
#       'reason': 'COVID-19',
#       'abstractGameCode': 'F'},
#      'teams': {'away': {'leagueRecord': {'wins': 26,
#         'losses': 21,
#         'pct': '.553'},
#        'team': {'id': 121,
#         'name': 'New York Mets',
#         'link': '/api/v1/teams/121'},
#        'splitSquad': False,
#        'seriesNumber': 1},
#       'home': {'leagueRecord': {'wins': 22, 'losses': 29, 'pct': '.431'},
#        'team': {'id': 120,
#         'name': 'Washington Nationals',
#         'link': '/api/v1/teams/120'},
#        'splitSquad': False,
#        'seriesNumber': 1}},
#      'venue': {'id': 3309,
#       'name': 'Nationals Park',
#       'link': '/api/v1/venues/3309'},
#      'content': {'link': '/api/v1/game/634647/content'},
#      'gameNumber': 1,
#      'publicFacing': True,
#      'doubleHeader': 'N',
#      'gamedayType': 'P',
#      'tiebreaker': 'N',
#      'calendarEventID': '14-634647-2021-04-01',
#      'seasonDisplay': '2021',
#      'dayNight': 'night',
#      'description': 'Nationals home opener',
#      'scheduledInnings': 7,
#      'reverseHomeAwayStatus': False,
#      'inningBreakLength': 145,
#      'gamesInSeries': 3,
#      'seriesGameNumber': 1,
#      'seriesDescription': 'Regular Season',
#      'recordSource': 'S',
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game'}],
#    'events': []}]}

# %% [markdown]
# A quick skim of the content implies that the most of the contents are under the key "dates." To check there are more endpoints of the schedule endpoints:

# %%
schedule_json_content.keys()
# Out:
# dict_keys(['copyright', 'totalItems', 'totalEvents', 'totalGames', 'totalGamesInProgress', 'dates'])

# %% [markdown]
# Since there is no other keys in this json object, we will explore more of the "dates" key.

# %%
dates_content = schedule_json_content['dates']
dates_content
# Out:
# [{'date': '2021-04-01',
#   'totalItems': 15,
#   'totalEvents': 0,
#   'totalGames': 15,
#   'totalGamesInProgress': 0,
#   'games': [{'gamePk': 634642,
#     'link': '/api/v1.1/game/634642/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T17:05:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 1,
#        'losses': 0,
#        'pct': '1.000'},
#       'score': 3,
#       'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 2,
#       'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 3313,
#      'name': 'Yankee Stadium',
#      'link': '/api/v1/venues/3313'},
#     'content': {'link': '/api/v1/game/634642/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634642-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 145,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634645,
#     'link': '/api/v1.1/game/634645/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T17:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 2,
#       'team': {'id': 114,
#        'name': 'Cleveland Indians',
#        'link': '/api/v1/teams/114'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 3,
#       'team': {'id': 116,
#        'name': 'Detroit Tigers',
#        'link': '/api/v1/teams/116'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 2394,
#      'name': 'Comerica Park',
#      'link': '/api/v1/venues/2394'},
#     'content': {'link': '/api/v1/game/634645/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634645-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Tigers home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634638,
#     'link': '/api/v1.1/game/634638/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T18:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 5,
#       'team': {'id': 142,
#        'name': 'Minnesota Twins',
#        'link': '/api/v1/teams/142'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 6,
#       'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 32,
#      'name': 'American Family Field',
#      'link': '/api/v1/venues/32'},
#     'content': {'link': '/api/v1/game/634638/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634638-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Brewers home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634634,
#     'link': '/api/v1.1/game/634634/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T18:20:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 1,
#        'losses': 0,
#        'pct': '1.000'},
#       'score': 5,
#       'team': {'id': 134,
#        'name': 'Pittsburgh Pirates',
#        'link': '/api/v1/teams/134'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 3,
#       'team': {'id': 112, 'name': 'Chicago Cubs', 'link': '/api/v1/teams/112'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 17, 'name': 'Wrigley Field', 'link': '/api/v1/venues/17'},
#     'content': {'link': '/api/v1/game/634634/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634634-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Cubs home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634622,
#     'link': '/api/v1.1/game/634622/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T19:05:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 2,
#       'team': {'id': 144,
#        'name': 'Atlanta Braves',
#        'link': '/api/v1/teams/144'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 3,
#       'team': {'id': 143,
#        'name': 'Philadelphia Phillies',
#        'link': '/api/v1/teams/143'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 2681,
#      'name': 'Citizens Bank Park',
#      'link': '/api/v1/venues/2681'},
#     'content': {'link': '/api/v1/game/634622/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634622-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Phillies home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634615,
#     'link': '/api/v1.1/game/634615/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T20:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 5,
#       'team': {'id': 119,
#        'name': 'Los Angeles Dodgers',
#        'link': '/api/v1/teams/119'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 8,
#       'team': {'id': 115,
#        'name': 'Colorado Rockies',
#        'link': '/api/v1/teams/115'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 19, 'name': 'Coors Field', 'link': '/api/v1/venues/19'},
#     'content': {'link': '/api/v1/game/634615/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634615-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Rockies home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 145,
#     'gamesInSeries': 4,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634618,
#     'link': '/api/v1.1/game/634618/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T20:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 7,
#       'team': {'id': 109,
#        'name': 'Arizona Diamondbacks',
#        'link': '/api/v1/teams/109'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 8,
#       'team': {'id': 135,
#        'name': 'San Diego Padres',
#        'link': '/api/v1/teams/135'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 2680, 'name': 'Petco Park', 'link': '/api/v1/venues/2680'},
#     'content': {'link': '/api/v1/game/634618/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634618-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Padres home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 4,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634636,
#     'link': '/api/v1.1/game/634636/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T20:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 1,
#        'losses': 0,
#        'pct': '1.000'},
#       'score': 11,
#       'team': {'id': 138,
#        'name': 'St. Louis Cardinals',
#        'link': '/api/v1/teams/138'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 6,
#       'team': {'id': 113,
#        'name': 'Cincinnati Reds',
#        'link': '/api/v1/teams/113'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 2602,
#      'name': 'Great American Ball Park',
#      'link': '/api/v1/venues/2602'},
#     'content': {'link': '/api/v1/game/634636/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634636-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Reds home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634630,
#     'link': '/api/v1.1/game/634630/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T20:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 10,
#       'team': {'id': 140,
#        'name': 'Texas Rangers',
#        'link': '/api/v1/teams/140'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 14,
#       'team': {'id': 118,
#        'name': 'Kansas City Royals',
#        'link': '/api/v1/teams/118'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 7, 'name': 'Kauffman Stadium', 'link': '/api/v1/venues/7'},
#     'content': {'link': '/api/v1/game/634630/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634630-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Royals home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634652,
#     'link': '/api/v1.1/game/634652/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T20:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 1,
#        'losses': 0,
#        'pct': '1.000'},
#       'score': 1,
#       'team': {'id': 139,
#        'name': 'Tampa Bay Rays',
#        'link': '/api/v1/teams/139'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 0,
#       'team': {'id': 146,
#        'name': 'Miami Marlins',
#        'link': '/api/v1/teams/146'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 4169,
#      'name': 'loanDepot park',
#      'link': '/api/v1/venues/4169'},
#     'content': {'link': '/api/v1/game/634652/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634652-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Marlins home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634655,
#     'link': '/api/v1.1/game/634655/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-02T02:05:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 3,
#       'team': {'id': 145,
#        'name': 'Chicago White Sox',
#        'link': '/api/v1/teams/145'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 4,
#       'team': {'id': 108,
#        'name': 'Los Angeles Angels',
#        'link': '/api/v1/teams/108'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 1, 'name': 'Angel Stadium', 'link': '/api/v1/venues/1'},
#     'content': {'link': '/api/v1/game/634655/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634655-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'night',
#     'description': 'Angels home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 4,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634640,
#     'link': '/api/v1.1/game/634640/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-02T02:07:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 1,
#        'losses': 0,
#        'pct': '1.000'},
#       'score': 8,
#       'team': {'id': 117,
#        'name': 'Houston Astros',
#        'link': '/api/v1/teams/117'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 1,
#       'team': {'id': 133,
#        'name': 'Oakland Athletics',
#        'link': '/api/v1/teams/133'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 10,
#      'name': 'Oakland Coliseum',
#      'link': '/api/v1/venues/10'},
#     'content': {'link': '/api/v1/game/634640/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634640-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'night',
#     'description': 'Athletics home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 145,
#     'gamesInSeries': 4,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634625,
#     'link': '/api/v1.1/game/634625/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-02T02:10:00Z',
#     'officialDate': '2021-04-01',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'F',
#      'detailedState': 'Final',
#      'statusCode': 'F',
#      'startTimeTBD': False,
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'score': 7,
#       'team': {'id': 137,
#        'name': 'San Francisco Giants',
#        'link': '/api/v1/teams/137'},
#       'isWinner': False,
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#       'score': 8,
#       'team': {'id': 136,
#        'name': 'Seattle Mariners',
#        'link': '/api/v1/teams/136'},
#       'isWinner': True,
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 680,
#      'name': 'T-Mobile Park',
#      'link': '/api/v1/venues/680'},
#     'content': {'link': '/api/v1/game/634625/content'},
#     'isTie': False,
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634625-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'night',
#     'description': 'Mariners home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634627,
#     'link': '/api/v1.1/game/634627/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T18:10:00Z',
#     'officialDate': '2021-04-02',
#     'rescheduleDate': '2021-04-02T18:10:00Z',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'D',
#      'detailedState': 'Postponed',
#      'statusCode': 'DR',
#      'startTimeTBD': False,
#      'reason': 'Rain',
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 1,
#        'losses': 0,
#        'pct': '1.000'},
#       'team': {'id': 110,
#        'name': 'Baltimore Orioles',
#        'link': '/api/v1/teams/110'},
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#       'team': {'id': 111,
#        'name': 'Boston Red Sox',
#        'link': '/api/v1/teams/111'},
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 3, 'name': 'Fenway Park', 'link': '/api/v1/venues/3'},
#     'content': {'link': '/api/v1/game/634627/content'},
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634627-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'day',
#     'description': 'Red Sox home opener',
#     'scheduledInnings': 9,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 120,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'},
#    {'gamePk': 634647,
#     'link': '/api/v1.1/game/634647/feed/live',
#     'gameType': 'R',
#     'season': '2021',
#     'gameDate': '2021-04-01T23:09:00Z',
#     'officialDate': '2021-06-19',
#     'rescheduleDate': '2021-06-19T17:05:00Z',
#     'status': {'abstractGameState': 'Final',
#      'codedGameState': 'D',
#      'detailedState': 'Postponed',
#      'statusCode': 'DE',
#      'startTimeTBD': False,
#      'reason': 'COVID-19',
#      'abstractGameCode': 'F'},
#     'teams': {'away': {'leagueRecord': {'wins': 26,
#        'losses': 21,
#        'pct': '.553'},
#       'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121'},
#       'splitSquad': False,
#       'seriesNumber': 1},
#      'home': {'leagueRecord': {'wins': 22, 'losses': 29, 'pct': '.431'},
#       'team': {'id': 120,
#        'name': 'Washington Nationals',
#        'link': '/api/v1/teams/120'},
#       'splitSquad': False,
#       'seriesNumber': 1}},
#     'venue': {'id': 3309,
#      'name': 'Nationals Park',
#      'link': '/api/v1/venues/3309'},
#     'content': {'link': '/api/v1/game/634647/content'},
#     'gameNumber': 1,
#     'publicFacing': True,
#     'doubleHeader': 'N',
#     'gamedayType': 'P',
#     'tiebreaker': 'N',
#     'calendarEventID': '14-634647-2021-04-01',
#     'seasonDisplay': '2021',
#     'dayNight': 'night',
#     'description': 'Nationals home opener',
#     'scheduledInnings': 7,
#     'reverseHomeAwayStatus': False,
#     'inningBreakLength': 145,
#     'gamesInSeries': 3,
#     'seriesGameNumber': 1,
#     'seriesDescription': 'Regular Season',
#     'recordSource': 'S',
#     'ifNecessary': 'N',
#     'ifNecessaryDescription': 'Normal Game'}],
#   'events': []}]

# %% [markdown]
# The output object is a list of json object(s). Since we queried only on a single date, we will have one json object in the list. Each 'date' json object has multiple "games" tags. Each tag corresponds to a game played on the given date.

# %%
games_content = dates_content[0]['games']
games_content
# Out:
# [{'gamePk': 634642,
#   'link': '/api/v1.1/game/634642/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T17:05:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 3,
#     'team': {'id': 141,
#      'name': 'Toronto Blue Jays',
#      'link': '/api/v1/teams/141'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 2,
#     'team': {'id': 147,
#      'name': 'New York Yankees',
#      'link': '/api/v1/teams/147'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 3313,
#    'name': 'Yankee Stadium',
#    'link': '/api/v1/venues/3313'},
#   'content': {'link': '/api/v1/game/634642/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634642-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 145,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634645,
#   'link': '/api/v1.1/game/634645/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T17:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 2,
#     'team': {'id': 114,
#      'name': 'Cleveland Indians',
#      'link': '/api/v1/teams/114'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 3,
#     'team': {'id': 116, 'name': 'Detroit Tigers', 'link': '/api/v1/teams/116'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 2394,
#    'name': 'Comerica Park',
#    'link': '/api/v1/venues/2394'},
#   'content': {'link': '/api/v1/game/634645/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634645-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Tigers home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634638,
#   'link': '/api/v1.1/game/634638/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T18:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 5,
#     'team': {'id': 142,
#      'name': 'Minnesota Twins',
#      'link': '/api/v1/teams/142'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 6,
#     'team': {'id': 158,
#      'name': 'Milwaukee Brewers',
#      'link': '/api/v1/teams/158'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 32,
#    'name': 'American Family Field',
#    'link': '/api/v1/venues/32'},
#   'content': {'link': '/api/v1/game/634638/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634638-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Brewers home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634634,
#   'link': '/api/v1.1/game/634634/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T18:20:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 5,
#     'team': {'id': 134,
#      'name': 'Pittsburgh Pirates',
#      'link': '/api/v1/teams/134'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 3,
#     'team': {'id': 112, 'name': 'Chicago Cubs', 'link': '/api/v1/teams/112'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 17, 'name': 'Wrigley Field', 'link': '/api/v1/venues/17'},
#   'content': {'link': '/api/v1/game/634634/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634634-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Cubs home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634622,
#   'link': '/api/v1.1/game/634622/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T19:05:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 2,
#     'team': {'id': 144, 'name': 'Atlanta Braves', 'link': '/api/v1/teams/144'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 3,
#     'team': {'id': 143,
#      'name': 'Philadelphia Phillies',
#      'link': '/api/v1/teams/143'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 2681,
#    'name': 'Citizens Bank Park',
#    'link': '/api/v1/venues/2681'},
#   'content': {'link': '/api/v1/game/634622/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634622-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Phillies home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634615,
#   'link': '/api/v1.1/game/634615/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T20:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 5,
#     'team': {'id': 119,
#      'name': 'Los Angeles Dodgers',
#      'link': '/api/v1/teams/119'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 8,
#     'team': {'id': 115,
#      'name': 'Colorado Rockies',
#      'link': '/api/v1/teams/115'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 19, 'name': 'Coors Field', 'link': '/api/v1/venues/19'},
#   'content': {'link': '/api/v1/game/634615/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634615-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Rockies home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 145,
#   'gamesInSeries': 4,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634618,
#   'link': '/api/v1.1/game/634618/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T20:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 7,
#     'team': {'id': 109,
#      'name': 'Arizona Diamondbacks',
#      'link': '/api/v1/teams/109'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 8,
#     'team': {'id': 135,
#      'name': 'San Diego Padres',
#      'link': '/api/v1/teams/135'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 2680, 'name': 'Petco Park', 'link': '/api/v1/venues/2680'},
#   'content': {'link': '/api/v1/game/634618/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634618-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Padres home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 4,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634636,
#   'link': '/api/v1.1/game/634636/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T20:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 11,
#     'team': {'id': 138,
#      'name': 'St. Louis Cardinals',
#      'link': '/api/v1/teams/138'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 6,
#     'team': {'id': 113,
#      'name': 'Cincinnati Reds',
#      'link': '/api/v1/teams/113'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 2602,
#    'name': 'Great American Ball Park',
#    'link': '/api/v1/venues/2602'},
#   'content': {'link': '/api/v1/game/634636/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634636-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Reds home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634630,
#   'link': '/api/v1.1/game/634630/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T20:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 10,
#     'team': {'id': 140, 'name': 'Texas Rangers', 'link': '/api/v1/teams/140'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 14,
#     'team': {'id': 118,
#      'name': 'Kansas City Royals',
#      'link': '/api/v1/teams/118'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 7, 'name': 'Kauffman Stadium', 'link': '/api/v1/venues/7'},
#   'content': {'link': '/api/v1/game/634630/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634630-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Royals home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634652,
#   'link': '/api/v1.1/game/634652/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T20:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 1,
#     'team': {'id': 139, 'name': 'Tampa Bay Rays', 'link': '/api/v1/teams/139'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 0,
#     'team': {'id': 146, 'name': 'Miami Marlins', 'link': '/api/v1/teams/146'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 4169,
#    'name': 'loanDepot park',
#    'link': '/api/v1/venues/4169'},
#   'content': {'link': '/api/v1/game/634652/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634652-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Marlins home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634655,
#   'link': '/api/v1.1/game/634655/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-02T02:05:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 3,
#     'team': {'id': 145,
#      'name': 'Chicago White Sox',
#      'link': '/api/v1/teams/145'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 4,
#     'team': {'id': 108,
#      'name': 'Los Angeles Angels',
#      'link': '/api/v1/teams/108'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 1, 'name': 'Angel Stadium', 'link': '/api/v1/venues/1'},
#   'content': {'link': '/api/v1/game/634655/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634655-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'night',
#   'description': 'Angels home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 4,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634640,
#   'link': '/api/v1.1/game/634640/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-02T02:07:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 8,
#     'team': {'id': 117, 'name': 'Houston Astros', 'link': '/api/v1/teams/117'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 1,
#     'team': {'id': 133,
#      'name': 'Oakland Athletics',
#      'link': '/api/v1/teams/133'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 10, 'name': 'Oakland Coliseum', 'link': '/api/v1/venues/10'},
#   'content': {'link': '/api/v1/game/634640/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634640-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'night',
#   'description': 'Athletics home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 145,
#   'gamesInSeries': 4,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634625,
#   'link': '/api/v1.1/game/634625/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-02T02:10:00Z',
#   'officialDate': '2021-04-01',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'score': 7,
#     'team': {'id': 137,
#      'name': 'San Francisco Giants',
#      'link': '/api/v1/teams/137'},
#     'isWinner': False,
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'score': 8,
#     'team': {'id': 136,
#      'name': 'Seattle Mariners',
#      'link': '/api/v1/teams/136'},
#     'isWinner': True,
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 680, 'name': 'T-Mobile Park', 'link': '/api/v1/venues/680'},
#   'content': {'link': '/api/v1/game/634625/content'},
#   'isTie': False,
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634625-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'night',
#   'description': 'Mariners home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634627,
#   'link': '/api/v1.1/game/634627/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T18:10:00Z',
#   'officialDate': '2021-04-02',
#   'rescheduleDate': '2021-04-02T18:10:00Z',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'D',
#    'detailedState': 'Postponed',
#    'statusCode': 'DR',
#    'startTimeTBD': False,
#    'reason': 'Rain',
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 1, 'losses': 0, 'pct': '1.000'},
#     'team': {'id': 110,
#      'name': 'Baltimore Orioles',
#      'link': '/api/v1/teams/110'},
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 0, 'losses': 1, 'pct': '.000'},
#     'team': {'id': 111, 'name': 'Boston Red Sox', 'link': '/api/v1/teams/111'},
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 3, 'name': 'Fenway Park', 'link': '/api/v1/venues/3'},
#   'content': {'link': '/api/v1/game/634627/content'},
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634627-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'day',
#   'description': 'Red Sox home opener',
#   'scheduledInnings': 9,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 120,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'},
#  {'gamePk': 634647,
#   'link': '/api/v1.1/game/634647/feed/live',
#   'gameType': 'R',
#   'season': '2021',
#   'gameDate': '2021-04-01T23:09:00Z',
#   'officialDate': '2021-06-19',
#   'rescheduleDate': '2021-06-19T17:05:00Z',
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'D',
#    'detailedState': 'Postponed',
#    'statusCode': 'DE',
#    'startTimeTBD': False,
#    'reason': 'COVID-19',
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'leagueRecord': {'wins': 26, 'losses': 21, 'pct': '.553'},
#     'team': {'id': 121, 'name': 'New York Mets', 'link': '/api/v1/teams/121'},
#     'splitSquad': False,
#     'seriesNumber': 1},
#    'home': {'leagueRecord': {'wins': 22, 'losses': 29, 'pct': '.431'},
#     'team': {'id': 120,
#      'name': 'Washington Nationals',
#      'link': '/api/v1/teams/120'},
#     'splitSquad': False,
#     'seriesNumber': 1}},
#   'venue': {'id': 3309,
#    'name': 'Nationals Park',
#    'link': '/api/v1/venues/3309'},
#   'content': {'link': '/api/v1/game/634647/content'},
#   'gameNumber': 1,
#   'publicFacing': True,
#   'doubleHeader': 'N',
#   'gamedayType': 'P',
#   'tiebreaker': 'N',
#   'calendarEventID': '14-634647-2021-04-01',
#   'seasonDisplay': '2021',
#   'dayNight': 'night',
#   'description': 'Nationals home opener',
#   'scheduledInnings': 7,
#   'reverseHomeAwayStatus': False,
#   'inningBreakLength': 145,
#   'gamesInSeries': 3,
#   'seriesGameNumber': 1,
#   'seriesDescription': 'Regular Season',
#   'recordSource': 'S',
#   'ifNecessary': 'N',
#   'ifNecessaryDescription': 'Normal Game'}]

# %% [markdown]
# Again, it returns a list of 'game' json object. Each 'game' object contains the information about each game played on the given date. These information include:
# - gamePk: The unique ID assigned to each game
# - link: The API link to this game
# - gameType: 'R' if regular game, 'P' if post-season, 'N' if pre-season
# - gameDate, officialDate: self-explanatory
# - status: has children tags such as detailedState, which tells us if the game is finished, cancelled, delayed, etc
# - teams: teams played the game, their current standings, scores, home/away status
#
# Since are interested in obtaining 'gamePk' of the opening game:

# %%
gamePk_opening = games_content[0]['gamePk']
gamePk_opening
# Out:
# 634642

# %% [markdown]
# To sum it up, we can find 'gamePk' parameter in the following order:
#
# - schedule -> dates -> games -> gamePk.
#
# Or (not so) Pythonically:

# %%
gamePk_opening_alt = schedule_json_content['dates'][0]['games'][0]['gamePk']
gamePk_opening_alt
# Out:
# 634642

# %% [markdown]
# ### 2. Using `gamePk` to extract `at-bat` data

# %% [markdown]
# [The API document](https://beta-statsapi.mlb.com/docs/#!/game/playByPlay) says that we need to input the following url:
#
# `http://statsapi.mlb.com/api/v1/game/{game_pk}/playByPlay`

# %%
playbyplay_url = "http://statsapi.mlb.com/api/v1/game/634642/playByPlay"

# %% [markdown]
# Following the same steps as we did with the schedule endpoints:

# %%
playbyplay_response = requests.get(playbyplay_url)
playbyplay_content = playbyplay_response.content
playbyplay_json_content = json.loads(playbyplay_content)

# %%
playbyplay_json_content
# Out:
# {'copyright': 'Copyright 2021 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'allPlays': [{'result': {'type': 'atBat',
#     'event': 'Groundout',
#     'eventType': 'field_out',
#     'description': 'Marcus Semien grounds out, shortstop Gleyber Torres to first baseman Jay Bruce.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 0,
#     'halfInning': 'top',
#     'isTopInning': True,
#     'inning': 1,
#     'startTime': '2021-04-01T16:38:06.807Z',
#     'endTime': '2021-04-01T17:10:52.200Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 1, 'strikes': 0, 'outs': 1},
#    'matchup': {'batter': {'id': 543760,
#      'fullName': 'Marcus Semien',
#      'link': '/api/v1/people/543760'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 543037,
#      'fullName': 'Gerrit Cole',
#      'link': '/api/v1/people/543037'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [3, 4],
#    'actionIndex': [0, 1, 2],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'originBase': None,
#       'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 1},
#      'details': {'event': 'Groundout',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 543760,
#        'fullName': 'Marcus Semien',
#        'link': '/api/v1/people/543760'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 4},
#      'credits': [{'player': {'id': 650402, 'link': '/api/v1/people/650402'},
#        'position': {'code': '6',
#         'name': 'Shortstop',
#         'type': 'Infielder',
#         'abbreviation': 'SS'},
#        'credit': 'f_assist'},
#       {'player': {'id': 457803, 'link': '/api/v1/people/457803'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'description': 'Status Change - Pre-Game',
#       'event': 'Game Advisory',
#       'eventType': 'game_advisory',
#       'awayScore': 0,
#       'homeScore': 0,
#       'isScoringPlay': False,
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#      'index': 0,
#      'startTime': '2021-04-01T16:38:06.807Z',
#      'endTime': '2021-04-01T16:56:47.520Z',
#      'isPitch': False,
#      'type': 'action',
#      'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#     {'details': {'description': 'Status Change - Warmup',
#       'event': 'Game Advisory',
#       'eventType': 'game_advisory',
#       'awayScore': 0,
#       'homeScore': 0,
#       'isScoringPlay': False,
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#      'index': 1,
#      'startTime': '2021-04-01T16:56:47.520Z',
#      'endTime': '2021-04-01T17:10:02.256Z',
#      'isPitch': False,
#      'type': 'action',
#      'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#     {'details': {'description': 'Status Change - In Progress',
#       'event': 'Game Advisory',
#       'eventType': 'game_advisory',
#       'awayScore': 0,
#       'homeScore': 0,
#       'isScoringPlay': False,
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#      'index': 2,
#      'startTime': '2021-04-01T17:10:02.256Z',
#      'isPitch': False,
#      'type': 'action',
#      'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 0, 'outs': 0},
#      'pitchData': {'startSpeed': 97.7,
#       'endSpeed': 89.0,
#       'strikeZoneTop': 3.25,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 33.13,
#        'aZ': -9.7,
#        'pfxX': -6.78,
#        'pfxZ': 11.02,
#        'pX': -0.5,
#        'pZ': 3.54,
#        'vX0': 6.33,
#        'vY0': -142.05,
#        'vZ0': -4.35,
#        'x': 129.48,
#        'y': 169.3,
#        'x0': -1.88,
#        'y0': 50.0,
#        'z0': 5.71,
#        'aX': -13.83},
#       'breaks': {'breakAngle': 49.2,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2672,
#        'spinDirection': 207},
#       'zone': 11,
#       'typeConfidence': 2.0,
#       'plateTime': 0.39,
#       'extension': 6.57},
#      'index': 3,
#      'playId': '7b18a365-daf0-48a1-b0e5-d63c370061bc',
#      'pitchNumber': 1,
#      'startTime': '2021-04-01T17:10:31.233Z',
#      'endTime': '2021-04-01T17:10:34.765Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 0, 'outs': 0},
#      'pitchData': {'startSpeed': 95.3,
#       'endSpeed': 87.5,
#       'strikeZoneTop': 3.37,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 29.0,
#        'aZ': -10.65,
#        'pfxX': -6.74,
#        'pfxZ': 11.0,
#        'pX': 0.64,
#        'pZ': 2.77,
#        'vX0': 8.37,
#        'vY0': -138.5,
#        'vZ0': -5.9,
#        'x': 125.89,
#        'y': 150.94,
#        'x0': -1.54,
#        'y0': 50.0,
#        'z0': 5.62,
#        'aX': -13.17},
#       'breaks': {'breakAngle': 44.4,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2581,
#        'spinDirection': 209},
#       'zone': 3,
#       'typeConfidence': 2.0,
#       'plateTime': 0.39,
#       'extension': 6.53},
#      'hitData': {'launchSpeed': 99.9,
#       'launchAngle': -1.0,
#       'totalDistance': 40.0,
#       'trajectory': 'ground_ball',
#       'hardness': 'medium',
#       'location': '6',
#       'coordinates': {'coordX': 99.28, 'coordY': 147.19}},
#      'index': 4,
#      'playId': '1cf7d060-1f8b-40d2-92e6-6a16b8252d94',
#      'pitchNumber': 2,
#      'startTime': '2021-04-01T17:10:43.173Z',
#      'endTime': '2021-04-01T17:10:52.200Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'playEndTime': '2021-04-01T17:10:52.200Z',
#    'atBatIndex': 0},
#   {'result': {'type': 'atBat',
#     'event': 'Strikeout',
#     'eventType': 'strikeout',
#     'description': 'Cavan Biggio strikes out swinging.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 1,
#     'halfInning': 'top',
#     'isTopInning': True,
#     'inning': 1,
#     'startTime': '2021-04-01T17:11:26.715Z',
#     'endTime': '2021-04-01T17:12:19.210Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 14},
#    'count': {'balls': 1, 'strikes': 3, 'outs': 2},
#    'matchup': {'batter': {'id': 624415,
#      'fullName': 'Cavan Biggio',
#      'link': '/api/v1/people/624415'},
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitcher': {'id': 543037,
#      'fullName': 'Gerrit Cole',
#      'link': '/api/v1/people/543037'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_LHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'originBase': None,
#       'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 2},
#      'details': {'event': 'Strikeout',
#       'eventType': 'strikeout',
#       'movementReason': None,
#       'runner': {'id': 624415,
#        'fullName': 'Cavan Biggio',
#        'link': '/api/v1/people/624415'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 3},
#      'credits': [{'player': {'id': 596142, 'link': '/api/v1/people/596142'},
#        'position': {'code': '2',
#         'name': 'Catcher',
#         'type': 'Catcher',
#         'abbreviation': 'C'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'C',
#        'description': 'Called Strike'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1, 'outs': 1},
#      'pitchData': {'startSpeed': 96.6,
#       'endSpeed': 86.4,
#       'strikeZoneTop': 3.36,
#       'strikeZoneBottom': 1.59,
#       'coordinates': {'aY': 38.1,
#        'aZ': -7.27,
#        'pfxX': -6.31,
#        'pfxZ': 12.78,
#        'pX': -0.38,
#        'pZ': 2.45,
#        'vX0': 5.77,
#        'vY0': -140.22,
#        'vZ0': -7.33,
#        'x': 131.55,
#        'y': 172.73,
#        'x0': -1.67,
#        'y0': 50.0,
#        'z0': 5.6,
#        'aX': -12.29},
#       'breaks': {'breakAngle': 49.2,
#        'breakLength': 2.4,
#        'breakY': 24.0,
#        'spinRate': 2573,
#        'spinDirection': 209},
#       'zone': 4,
#       'typeConfidence': 2.0,
#       'plateTime': 0.39,
#       'extension': 6.57},
#      'index': 0,
#      'playId': 'a06f87d5-068f-47f8-8567-dc99fe430cd1',
#      'pitchNumber': 1,
#      'startTime': '2021-04-01T17:11:22.056Z',
#      'endTime': '2021-04-01T17:11:26.074Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(153, 171, 0, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'KC', 'description': 'Knuckle Curve'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1, 'outs': 1},
#      'pitchData': {'startSpeed': 82.2,
#       'endSpeed': 74.9,
#       'strikeZoneTop': 3.32,
#       'strikeZoneBottom': 1.59,
#       'coordinates': {'aY': 27.97,
#        'aZ': -44.43,
#        'pfxX': 4.22,
#        'pfxZ': -8.68,
#        'pX': -0.03,
#        'pZ': 0.62,
#        'vX0': 2.86,
#        'vY0': -119.5,
#        'vZ0': -2.5,
#        'x': 118.16,
#        'y': 222.14,
#        'x0': -1.8,
#        'y0': 50.0,
#        'z0': 5.76,
#        'aX': 5.96},
#       'breaks': {'breakAngle': 8.4,
#        'breakLength': 13.2,
#        'breakY': 24.0,
#        'spinRate': 2737,
#        'spinDirection': 28},
#       'zone': 13,
#       'typeConfidence': 2.0,
#       'plateTime': 0.46,
#       'extension': 6.31},
#      'index': 1,
#      'playId': '9c878c08-7ebb-4556-a420-b78c7c650e2b',
#      'pitchNumber': 2,
#      'startTime': '2021-04-01T17:11:34.798Z',
#      'endTime': '2021-04-01T17:11:38.764Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'F', 'description': 'Foul'},
#       'description': 'Foul',
#       'code': 'F',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(0, 85, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'CH', 'description': 'Changeup'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2, 'outs': 1},
#      'pitchData': {'startSpeed': 87.8,
#       'endSpeed': 79.2,
#       'strikeZoneTop': 3.47,
#       'strikeZoneBottom': 1.59,
#       'coordinates': {'aY': 29.88,
#        'aZ': -18.88,
#        'pfxX': -10.4,
#        'pfxZ': 8.19,
#        'pX': -0.52,
#        'pZ': 2.11,
#        'vX0': 6.33,
#        'vY0': -127.52,
#        'vZ0': -4.65,
#        'x': 137.01,
#        'y': 181.91,
#        'x0': -1.71,
#        'y0': 50.0,
#        'z0': 5.47,
#        'aX': -16.87},
#       'breaks': {'breakAngle': 37.2,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 1855,
#        'spinDirection': 241},
#       'zone': 7,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.68},
#      'index': 2,
#      'playId': '780fbde7-6a72-4646-bf85-fb668083267e',
#      'pitchNumber': 3,
#      'startTime': '2021-04-01T17:11:53.466Z',
#      'endTime': '2021-04-01T17:11:57.048Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 3, 'outs': 1},
#      'pitchData': {'startSpeed': 98.3,
#       'endSpeed': 88.6,
#       'strikeZoneTop': 3.47,
#       'strikeZoneBottom': 1.59,
#       'coordinates': {'aY': 36.98,
#        'aZ': -8.85,
#        'pfxX': -8.25,
#        'pfxZ': 11.41,
#        'pX': -0.79,
#        'pZ': 3.92,
#        'vX0': 6.01,
#        'vY0': -142.99,
#        'vZ0': -3.48,
#        'x': 147.02,
#        'y': 132.99,
#        'x0': -1.86,
#        'y0': 50.0,
#        'z0': 5.72,
#        'aX': -16.86},
#       'breaks': {'breakAngle': 57.6,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2648,
#        'spinDirection': 208},
#       'zone': 11,
#       'typeConfidence': 2.0,
#       'plateTime': 0.38,
#       'extension': 6.44},
#      'index': 3,
#      'playId': '7272dfe6-98d2-42bf-920e-dc6099112dde',
#      'pitchNumber': 4,
#      'startTime': '2021-04-01T17:12:13.113Z',
#      'endTime': '2021-04-01T17:12:19.210Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'playEndTime': '2021-04-01T17:12:19.210Z',
#    'atBatIndex': 1},
#   {'result': {'type': 'atBat',
#     'event': 'Groundout',
#     'eventType': 'field_out',
#     'description': 'Bo Bichette grounds out sharply, second baseman DJ LeMahieu to first baseman Jay Bruce.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 2,
#     'halfInning': 'top',
#     'isTopInning': True,
#     'inning': 1,
#     'startTime': '2021-04-01T17:12:36.595Z',
#     'endTime': '2021-04-01T17:14:23.991Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 3, 'strikes': 2, 'outs': 3},
#    'matchup': {'batter': {'id': 666182,
#      'fullName': 'Bo Bichette',
#      'link': '/api/v1/people/666182'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 543037,
#      'fullName': 'Gerrit Cole',
#      'link': '/api/v1/people/543037'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3, 4, 5],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'originBase': None,
#       'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 3},
#      'details': {'event': 'Groundout',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 666182,
#        'fullName': 'Bo Bichette',
#        'link': '/api/v1/people/666182'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 5},
#      'credits': [{'player': {'id': 518934, 'link': '/api/v1/people/518934'},
#        'position': {'code': '4',
#         'name': 'Second Base',
#         'type': 'Infielder',
#         'abbreviation': '2B'},
#        'credit': 'f_assist'},
#       {'player': {'id': 457803, 'link': '/api/v1/people/457803'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'C',
#        'description': 'Called Strike'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1, 'outs': 2},
#      'pitchData': {'startSpeed': 96.5,
#       'endSpeed': 87.4,
#       'strikeZoneTop': 3.62,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 34.22,
#        'aZ': -11.92,
#        'pfxX': -7.6,
#        'pfxZ': 10.26,
#        'pX': -0.02,
#        'pZ': 3.02,
#        'vX0': 7.43,
#        'vY0': -140.23,
#        'vZ0': -4.95,
#        'x': 117.89,
#        'y': 157.11,
#        'x0': -1.73,
#        'y0': 50.0,
#        'z0': 5.6,
#        'aX': -15.01},
#       'breaks': {'breakAngle': 45.6,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2609,
#        'spinDirection': 212},
#       'zone': 2,
#       'typeConfidence': 2.0,
#       'plateTime': 0.39,
#       'extension': 6.61},
#      'index': 0,
#      'playId': '48c69d65-c67c-4b43-8e9b-c39aaa2aea46',
#      'pitchNumber': 1,
#      'startTime': '2021-04-01T17:12:44.209Z',
#      'endTime': '2021-04-01T17:12:47.934Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'C', 'description': 'Called Strike'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(0, 0, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SL', 'description': 'Slider'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 2, 'outs': 2},
#      'pitchData': {'startSpeed': 87.7,
#       'endSpeed': 81.6,
#       'strikeZoneTop': 3.6,
#       'strikeZoneBottom': 1.66,
#       'coordinates': {'aY': 23.14,
#        'aZ': -29.6,
#        'pfxX': 3.48,
#        'pfxZ': 1.54,
#        'pX': 0.91,
#        'pZ': 2.59,
#        'vX0': 5.54,
#        'vY0': -127.7,
#        'vZ0': -2.2,
#        'x': 82.16,
#        'y': 168.89,
#        'x0': -1.72,
#        'y0': 50.0,
#        'z0': 5.76,
#        'aX': 5.81},
#       'breaks': {'breakAngle': 13.2,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2668,
#        'spinDirection': 100},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.44},
#      'index': 1,
#      'playId': 'ec1ce8e6-847e-41f8-8bda-b88d16f9574f',
#      'pitchNumber': 2,
#      'startTime': '2021-04-01T17:12:57.813Z',
#      'endTime': '2021-04-01T17:13:01.621Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 0, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SL', 'description': 'Slider'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2, 'outs': 2},
#      'pitchData': {'startSpeed': 88.1,
#       'endSpeed': 81.3,
#       'strikeZoneTop': 3.39,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 25.83,
#        'aZ': -25.65,
#        'pfxX': 2.18,
#        'pfxZ': 3.93,
#        'pX': 1.87,
#        'pZ': 0.92,
#        'vX0': 7.9,
#        'vY0': -127.97,
#        'vZ0': -6.57,
#        'x': 45.7,
#        'y': 213.96,
#        'x0': -1.54,
#        'y0': 50.01,
#        'z0': 5.52,
#        'aX': 3.63},
#       'breaks': {'breakAngle': 10.8,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2786,
#        'spinDirection': 107},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.53},
#      'index': 2,
#      'playId': '6295d438-10ac-4870-91eb-726a7c85ee61',
#      'pitchNumber': 3,
#      'startTime': '2021-04-01T17:13:14.784Z',
#      'endTime': '2021-04-01T17:13:17.987Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 2, 'outs': 2},
#      'pitchData': {'startSpeed': 96.9,
#       'endSpeed': 88.3,
#       'strikeZoneTop': 3.3,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 32.5,
#        'aZ': -10.34,
#        'pfxX': -7.99,
#        'pfxZ': 10.85,
#        'pX': -1.17,
#        'pZ': 3.96,
#        'vX0': 4.71,
#        'vY0': -141.04,
#        'vZ0': -2.78,
#        'x': 161.65,
#        'y': 131.83,
#        'x0': -1.83,
#        'y0': 50.0,
#        'z0': 5.63,
#        'aX': -16.07},
#       'breaks': {'breakAngle': 54.0,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2588,
#        'spinDirection': 220},
#       'zone': 11,
#       'typeConfidence': 2.0,
#       'plateTime': 0.39,
#       'extension': 6.5},
#      'index': 3,
#      'playId': 'c7d35a29-d816-48d2-974b-df49571f98fc',
#      'pitchNumber': 4,
#      'startTime': '2021-04-01T17:13:36.033Z',
#      'endTime': '2021-04-01T17:13:39.976Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 0, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SL', 'description': 'Slider'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2, 'outs': 2},
#      'pitchData': {'startSpeed': 88.6,
#       'endSpeed': 82.4,
#       'strikeZoneTop': 3.29,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 24.93,
#        'aZ': -28.14,
#        'pfxX': 3.56,
#        'pfxZ': 2.38,
#        'pX': 1.98,
#        'pZ': 0.54,
#        'vX0': 7.92,
#        'vY0': -128.77,
#        'vZ0': -7.32,
#        'x': 41.48,
#        'y': 224.17,
#        'x0': -1.59,
#        'y0': 50.0,
#        'z0': 5.58,
#        'aX': 6.02},
#       'breaks': {'breakAngle': 14.4,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2722,
#        'spinDirection': 115},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.42,
#       'extension': 6.55},
#      'index': 4,
#      'playId': 'a595c9ec-baf1-461f-a950-60d93644b742',
#      'pitchNumber': 5,
#      'startTime': '2021-04-01T17:13:52.709Z',
#      'endTime': '2021-04-01T17:13:56.098Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2, 'outs': 2},
#      'pitchData': {'startSpeed': 96.8,
#       'endSpeed': 86.9,
#       'strikeZoneTop': 3.37,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 37.28,
#        'aZ': -11.46,
#        'pfxX': -8.15,
#        'pfxZ': 10.54,
#        'pX': -0.04,
#        'pZ': 2.55,
#        'vX0': 7.16,
#        'vY0': -140.6,
#        'vZ0': -6.26,
#        'x': 118.53,
#        'y': 170.0,
#        'x0': -1.58,
#        'y0': 50.0,
#        'z0': 5.57,
#        'aX': -16.03},
#       'breaks': {'breakAngle': 46.8,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2592,
#        'spinDirection': 204},
#       'zone': 5,
#       'typeConfidence': 2.0,
#       'plateTime': 0.39,
#       'extension': 6.61},
#      'hitData': {'launchSpeed': 102.2,
#       'launchAngle': -11.0,
#       'totalDistance': 12.0,
#       'trajectory': 'ground_ball',
#       'hardness': 'hard',
#       'location': '4',
#       'coordinates': {'coordX': 139.61, 'coordY': 140.46}},
#      'index': 5,
#      'playId': 'c2e9fb82-02a6-4145-b273-f8243f2d75d4',
#      'pitchNumber': 6,
#      'startTime': '2021-04-01T17:14:16.893Z',
#      'endTime': '2021-04-01T17:14:23.991Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'playEndTime': '2021-04-01T17:14:23.991Z',
#    'atBatIndex': 2},
#   {'result': {'type': 'atBat',
#     'event': 'Groundout',
#     'eventType': 'field_out',
#     'description': 'DJ LeMahieu grounds out to first baseman Vladimir Guerrero Jr.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 3,
#     'halfInning': 'bottom',
#     'isTopInning': False,
#     'inning': 1,
#     'startTime': '2021-04-01T17:16:25.939Z',
#     'endTime': '2021-04-01T17:18:03.094Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 1, 'strikes': 2, 'outs': 1},
#    'matchup': {'batter': {'id': 518934,
#      'fullName': 'DJ LeMahieu',
#      'link': '/api/v1/people/518934'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 547943,
#      'fullName': 'Hyun Jin Ryu',
#      'link': '/api/v1/people/547943'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'originBase': None,
#       'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 1},
#      'details': {'event': 'Groundout',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 518934,
#        'fullName': 'DJ LeMahieu',
#        'link': '/api/v1/people/518934'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 3},
#      'credits': [{'player': {'id': 665489, 'link': '/api/v1/people/665489'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'C',
#        'description': 'Called Strike'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1, 'outs': 0},
#      'pitchData': {'startSpeed': 87.1,
#       'endSpeed': 79.1,
#       'strikeZoneTop': 3.39,
#       'strikeZoneBottom': 1.63,
#       'coordinates': {'aY': 27.72,
#        'aZ': -18.68,
#        'pfxX': 7.6,
#        'pfxZ': 8.4,
#        'pX': -0.42,
#        'pZ': 2.25,
#        'vX0': -8.38,
#        'vY0': -126.45,
#        'vZ0': -5.3,
#        'x': 132.88,
#        'y': 178.06,
#        'x0': 1.97,
#        'y0': 50.0,
#        'z0': 5.89,
#        'aX': 12.2},
#       'breaks': {'breakAngle': 27.6,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 1966,
#        'spinDirection': 140},
#       'zone': 4,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.3},
#      'index': 0,
#      'playId': '14cc85cf-16de-49b5-8933-a23cf8a69c60',
#      'pitchNumber': 1,
#      'startTime': '2021-04-01T17:16:56.677Z',
#      'endTime': '2021-04-01T17:17:00.309Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(152, 0, 101, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FC', 'description': 'Cutter'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1, 'outs': 0},
#      'pitchData': {'startSpeed': 84.2,
#       'endSpeed': 77.8,
#       'strikeZoneTop': 3.25,
#       'strikeZoneBottom': 1.63,
#       'coordinates': {'aY': 22.52,
#        'aZ': -26.34,
#        'pfxX': 1.23,
#        'pfxZ': 3.81,
#        'pX': -1.59,
#        'pZ': 3.33,
#        'vX0': -8.81,
#        'vY0': -122.48,
#        'vZ0': -1.3,
#        'x': 177.73,
#        'y': 148.76,
#        'x0': 1.88,
#        'y0': 50.0,
#        'z0': 6.11,
#        'aX': 1.89},
#       'breaks': {'breakAngle': 1.2,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 1943,
#        'spinDirection': 165},
#       'zone': 11,
#       'typeConfidence': 2.0,
#       'plateTime': 0.45,
#       'extension': 6.28},
#      'index': 1,
#      'playId': 'ec6896b7-78a1-473a-867f-c028a9cbb778',
#      'pitchNumber': 2,
#      'startTime': '2021-04-01T17:17:14.128Z',
#      'endTime': '2021-04-01T17:17:18.216Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2, 'outs': 0},
#      'pitchData': {'startSpeed': 88.4,
#       'endSpeed': 80.5,
#       'strikeZoneTop': 3.55,
#       'strikeZoneBottom': 1.63,
#       'coordinates': {'aY': 28.01,
#        'aZ': -19.43,
#        'pfxX': 6.96,
#        'pfxZ': 7.67,
#        'pX': -0.18,
#        'pZ': 2.69,
#        'vX0': -7.5,
#        'vY0': -128.46,
#        'vZ0': -4.24,
#        'x': 123.74,
#        'y': 166.12,
#        'x0': 1.88,
#        'y0': 50.0,
#        'z0': 5.88,
#        'aX': 11.56},
#       'breaks': {'breakAngle': 26.4,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 1938,
#        'spinDirection': 144},
#       'zone': 5,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.45},
#      'index': 2,
#      'playId': '80ec89ca-9e5c-4f22-a291-71d9298477c6',
#      'pitchNumber': 3,
#      'startTime': '2021-04-01T17:17:32.447Z',
#      'endTime': '2021-04-01T17:17:35.496Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(152, 0, 101, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'FC', 'description': 'Cutter'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2, 'outs': 0},
#      'pitchData': {'startSpeed': 87.6,
#       'endSpeed': 80.8,
#       'strikeZoneTop': 3.55,
#       'strikeZoneBottom': 1.63,
#       'coordinates': {'aY': 24.59,
#        'aZ': -20.98,
#        'pfxX': 1.41,
#        'pfxZ': 6.75,
#        'pX': -0.52,
#        'pZ': 3.15,
#        'vX0': -6.25,
#        'vY0': -127.53,
#        'vZ0': -3.02,
#        'x': 136.7,
#        'y': 153.78,
#        'x0': 1.78,
#        'y0': 50.0,
#        'z0': 5.99,
#        'aX': 2.33},
#       'breaks': {'breakAngle': 3.6,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2038,
#        'spinDirection': 156},
#       'zone': 1,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.45},
#      'hitData': {'launchSpeed': 82.7,
#       'launchAngle': 6.0,
#       'totalDistance': 86.0,
#       'trajectory': 'ground_ball',
#       'hardness': 'medium',
#       'location': '3',
#       'coordinates': {'coordX': 151.65, 'coordY': 158.12}},
#      'index': 3,
#      'playId': '350c41ed-99e2-4262-aed4-880220109eeb',
#      'pitchNumber': 4,
#      'startTime': '2021-04-01T17:17:55.958Z',
#      'endTime': '2021-04-01T17:18:03.094Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'playEndTime': '2021-04-01T17:18:03.094Z',
#    'atBatIndex': 3},
#   {'result': {'type': 'atBat',
#     'event': 'Strikeout',
#     'eventType': 'strikeout',
#     'description': 'Aaron Judge strikes out swinging.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 4,
#     'halfInning': 'bottom',
#     'isTopInning': False,
#     'inning': 1,
#     'startTime': '2021-04-01T17:18:20.009Z',
#     'endTime': '2021-04-01T17:20:43.827Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 14},
#    'count': {'balls': 3, 'strikes': 3, 'outs': 2},
#    'matchup': {'batter': {'id': 592450,
#      'fullName': 'Aaron Judge',
#      'link': '/api/v1/people/592450'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 547943,
#      'fullName': 'Hyun Jin Ryu',
#      'link': '/api/v1/people/547943'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3, 4, 5],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'originBase': None,
#       'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 2},
#      'details': {'event': 'Strikeout',
#       'eventType': 'strikeout',
#       'movementReason': None,
#       'runner': {'id': 592450,
#        'fullName': 'Aaron Judge',
#        'link': '/api/v1/people/592450'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 5},
#      'credits': [{'player': {'id': 643376, 'link': '/api/v1/people/643376'},
#        'position': {'code': '2',
#         'name': 'Catcher',
#         'type': 'Catcher',
#         'abbreviation': 'C'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 0, 'outs': 1},
#      'pitchData': {'startSpeed': 90.4,
#       'endSpeed': 81.7,
#       'strikeZoneTop': 4.01,
#       'strikeZoneBottom': 1.87,
#       'coordinates': {'aY': 31.5,
#        'aZ': -17.24,
#        'pfxX': 8.77,
#        'pfxZ': 8.68,
#        'pX': 0.5,
#        'pZ': 1.79,
#        'vX0': -6.72,
#        'vY0': -131.28,
#        'vZ0': -6.61,
#        'x': 97.95,
#        'y': 190.49,
#        'x0': 1.97,
#        'y0': 50.0,
#        'z0': 5.65,
#        'aX': 15.09},
#       'breaks': {'breakAngle': 36.0,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2165,
#        'spinDirection': 135},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.42,
#       'extension': 6.54},
#      'index': 0,
#      'playId': '54d97e07-31dd-457f-a53e-7e8e3b8a4b09',
#      'pitchNumber': 1,
#      'startTime': '2021-04-01T17:18:35.713Z',
#      'endTime': '2021-04-01T17:18:40.449Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(0, 85, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'CH', 'description': 'Changeup'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1, 'outs': 1},
#      'pitchData': {'startSpeed': 80.0,
#       'endSpeed': 73.0,
#       'strikeZoneTop': 3.76,
#       'strikeZoneBottom': 1.75,
#       'coordinates': {'aY': 23.35,
#        'aZ': -23.61,
#        'pfxX': 8.02,
#        'pfxZ': 6.3,
#        'pX': 0.24,
#        'pZ': 1.57,
#        'vX0': -6.49,
#        'vY0': -116.25,
#        'vZ0': -4.26,
#        'x': 107.82,
#        'y': 196.29,
#        'x0': 2.04,
#        'y0': 50.0,
#        'z0': 5.69,
#        'aX': 10.89},
#       'breaks': {'breakAngle': 21.6,
#        'breakLength': 8.4,
#        'breakY': 24.0,
#        'spinRate': 1547,
#        'spinDirection': 118},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.47,
#       'extension': 6.51},
#      'index': 1,
#      'playId': 'f7377f4a-31c4-4536-9872-6a97a59c22e1',
#      'pitchNumber': 2,
#      'startTime': '2021-04-01T17:18:53.986Z',
#      'endTime': '2021-04-01T17:18:57.506Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 85, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'CH', 'description': 'Changeup'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 1, 'outs': 1},
#      'pitchData': {'startSpeed': 80.6,
#       'endSpeed': 73.5,
#       'strikeZoneTop': 3.81,
#       'strikeZoneBottom': 1.75,
#       'coordinates': {'aY': 23.89,
#        'aZ': -24.04,
#        'pfxX': 7.21,
#        'pfxZ': 5.89,
#        'pX': 1.04,
#        'pZ': 1.81,
#        'vX0': -4.94,
#        'vY0': -117.19,
#        'vZ0': -3.69,
#        'x': 77.23,
#        'y': 189.98,
#        'x0': 2.25,
#        'y0': 50.0,
#        'z0': 5.67,
#        'aX': 9.94},
#       'breaks': {'breakAngle': 20.4,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 1564,
#        'spinDirection': 121},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.47,
#       'extension': 6.62},
#      'index': 2,
#      'playId': '1c40507d-ecf3-4082-b650-c6ece5559090',
#      'pitchNumber': 3,
#      'startTime': '2021-04-01T17:19:14.015Z',
#      'endTime': '2021-04-01T17:19:20.559Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'F', 'description': 'Foul'},
#       'description': 'Foul',
#       'code': 'F',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(152, 0, 101, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FC', 'description': 'Cutter'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 2, 'outs': 1},
#      'pitchData': {'startSpeed': 87.0,
#       'endSpeed': 79.8,
#       'strikeZoneTop': 3.76,
#       'strikeZoneBottom': 1.75,
#       'coordinates': {'aY': 25.87,
#        'aZ': -25.15,
#        'pfxX': -0.6,
#        'pfxZ': 4.33,
#        'pX': -1.02,
#        'pZ': 3.22,
#        'vX0': -6.97,
#        'vY0': -126.58,
#        'vZ0': -1.71,
#        'x': 155.87,
#        'y': 151.76,
#        'x0': 1.85,
#        'y0': 50.0,
#        'z0': 5.92,
#        'aX': -0.97},
#       'breaks': {'breakAngle': 4.8,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2020,
#        'spinDirection': 168},
#       'zone': 11,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.42},
#      'index': 3,
#      'playId': 'b241f1a2-a1ee-4b5b-8729-242e2d7032db',
#      'pitchNumber': 4,
#      'startTime': '2021-04-01T17:19:36.977Z',
#      'endTime': '2021-04-01T17:19:41.378Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(152, 0, 101, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FC', 'description': 'Cutter'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2, 'outs': 1},
#      'pitchData': {'startSpeed': 85.8,
#       'endSpeed': 79.1,
#       'strikeZoneTop': 3.81,
#       'strikeZoneBottom': 1.75,
#       'coordinates': {'aY': 25.05,
#        'aZ': -25.03,
#        'pfxX': -0.64,
#        'pfxZ': 4.54,
#        'pX': -1.47,
#        'pZ': 0.61,
#        'vX0': -7.88,
#        'vY0': -124.61,
#        'vZ0': -7.29,
#        'x': 172.99,
#        'y': 222.3,
#        'x0': 1.82,
#        'y0': 50.0,
#        'z0': 5.64,
#        'aX': -1.0},
#       'breaks': {'breakAngle': 4.8,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2046,
#        'spinDirection': 150},
#       'zone': 13,
#       'typeConfidence': 2.0,
#       'plateTime': 0.44,
#       'extension': 6.55},
#      'index': 4,
#      'playId': '4ee384f7-aacd-4f8f-8841-b7a2dc471c34',
#      'pitchNumber': 5,
#      'startTime': '2021-04-01T17:20:12.109Z',
#      'endTime': '2021-04-01T17:20:15.655Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 3, 'outs': 1},
#      'pitchData': {'startSpeed': 91.1,
#       'endSpeed': 83.4,
#       'strikeZoneTop': 3.76,
#       'strikeZoneBottom': 1.75,
#       'coordinates': {'aY': 27.93,
#        'aZ': -16.08,
#        'pfxX': 6.44,
#        'pfxZ': 9.05,
#        'pX': -0.52,
#        'pZ': 2.92,
#        'vX0': -8.46,
#        'vY0': -132.44,
#        'vZ0': -4.27,
#        'x': 136.96,
#        'y': 159.97,
#        'x0': 1.88,
#        'y0': 50.0,
#        'z0': 5.73,
#        'aX': 11.45},
#       'breaks': {'breakAngle': 30.0,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2006,
#        'spinDirection': 135},
#       'zone': 4,
#       'typeConfidence': 2.0,
#       'plateTime': 0.41,
#       'extension': 6.63},
#      'index': 5,
#      'playId': 'c60c0fb0-275b-49c9-99aa-7f1b54a5a008',
#      'pitchNumber': 6,
#      'startTime': '2021-04-01T17:20:38.367Z',
#      'endTime': '2021-04-01T17:20:43.827Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'playEndTime': '2021-04-01T17:20:43.827Z',
#    'atBatIndex': 4},
#   {'result': {'type': 'atBat',
#     'event': 'Strikeout',
#     'eventType': 'strikeout',
#     'description': 'Aaron Hicks strikes out swinging.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 5,
#     'halfInning': 'bottom',
#     'isTopInning': False,
#     'inning': 1,
#     'startTime': '2021-04-01T17:20:57.398Z',
#     'endTime': '2021-04-01T17:22:54.200Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 14},
#    'count': {'balls': 2, 'strikes': 3, 'outs': 3},
#    'matchup': {'batter': {'id': 543305,
#      'fullName': 'Aaron Hicks',
#      'link': '/api/v1/people/543305'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 547943,
#      'fullName': 'Hyun Jin Ryu',
#      'link': '/api/v1/people/547943'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3, 4],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'originBase': None,
#       'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 3},
#      'details': {'event': 'Strikeout',
#       'eventType': 'strikeout',
#       'movementReason': None,
#       'runner': {'id': 543305,
#        'fullName': 'Aaron Hicks',
#        'link': '/api/v1/people/543305'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 4},
#      'credits': [{'player': {'id': 643376, 'link': '/api/v1/people/643376'},
#        'position': {'code': '2',
#         'name': 'Catcher',
#         'type': 'Catcher',
#         'abbreviation': 'C'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 0, 'outs': 2},
#      'pitchData': {'startSpeed': 89.1,
#       'endSpeed': 80.4,
#       'strikeZoneTop': 3.4,
#       'strikeZoneBottom': 1.56,
#       'coordinates': {'aY': 31.05,
#        'aZ': -20.66,
#        'pfxX': 9.81,
#        'pfxZ': 6.88,
#        'pX': 0.94,
#        'pZ': 2.41,
#        'vX0': -6.05,
#        'vY0': -129.5,
#        'vZ0': -4.05,
#        'x': 81.31,
#        'y': 173.7,
#        'x0': 2.05,
#        'y0': 50.0,
#        'z0': 5.6,
#        'aX': 16.4},
#       'breaks': {'breakAngle': 34.8,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2024,
#        'spinDirection': 133},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.43,
#       'extension': 6.69},
#      'index': 0,
#      'playId': 'eaf74cb4-8047-4ee9-a81b-e289a74d6e3f',
#      'pitchNumber': 1,
#      'startTime': '2021-04-01T17:21:19.475Z',
#      'endTime': '2021-04-01T17:21:23.523Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1, 'outs': 2},
#      'pitchData': {'startSpeed': 89.7,
#       'endSpeed': 81.1,
#       'strikeZoneTop': 3.41,
#       'strikeZoneBottom': 1.56,
#       'coordinates': {'aY': 30.14,
#        'aZ': -16.65,
#        'pfxX': 6.73,
#        'pfxZ': 9.12,
#        'pX': 0.03,
#        'pZ': 3.6,
#        'vX0': -7.1,
#        'vY0': -130.31,
#        'vZ0': -2.14,
#        'x': 115.81,
#        'y': 141.69,
#        'x0': 1.93,
#        'y0': 50.0,
#        'z0': 5.7,
#        'aX': 11.45},
#       'breaks': {'breakAngle': 30.0,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 1982,
#        'spinDirection': 135},
#       'zone': 12,
#       'typeConfidence': 2.0,
#       'plateTime': 0.42,
#       'extension': 6.56},
#      'index': 1,
#      'playId': '31d9b804-e26f-4c14-a92d-2433e782dc4c',
#      'pitchNumber': 2,
#      'startTime': '2021-04-01T17:21:39.183Z',
#      'endTime': '2021-04-01T17:21:42.221Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 34, 255, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'CU', 'description': 'Curveball'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 1, 'outs': 2},
#      'pitchData': {'startSpeed': 74.6,
#       'endSpeed': 68.5,
#       'strikeZoneTop': 3.4,
#       'strikeZoneBottom': 1.56,
#       'coordinates': {'aY': 22.1,
#        'aZ': -41.82,
#        'pfxX': -5.27,
#        'pfxZ': -8.25,
#        'pX': 0.21,
#        'pZ': 0.66,
#        'vX0': -2.1,
#        'vY0': -108.5,
#        'vZ0': -1.43,
#        'x': 108.95,
#        'y': 220.99,
#        'x0': 1.88,
#        'y0': 50.0,
#        'z0': 5.96,
#        'aX': -6.17},
#       'breaks': {'breakAngle': 8.4,
#        'breakLength': 14.4,
#        'breakY': 24.0,
#        'spinRate': 2536,
#        'spinDirection': 317},
#       'zone': 14,
#       'typeConfidence': 2.0,
#       'plateTime': 0.51,
#       'extension': 6.28},
#      'index': 2,
#      'playId': 'f9ad6fc6-54a1-4e5d-b84d-e43eef3d97d9',
#      'pitchNumber': 3,
#      'startTime': '2021-04-01T17:21:59.332Z',
#      'endTime': '2021-04-01T17:22:04.243Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'C', 'description': 'Called Strike'},
# ...
#       'batter': {'id': 543760,
#        'fullName': 'Marcus Semien',
#        'link': '/api/v1/people/543760'},
#       'coordinates': {'x': 70.43, 'y': 65.09},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 543037,
#        'fullName': 'Gerrit Cole',
#        'link': '/api/v1/people/543037'},
#       'batter': {'id': 624415,
#        'fullName': 'Cavan Biggio',
#        'link': '/api/v1/people/624415'},
#       'coordinates': {'x': 80.91, 'y': 74.54},
#       'type': 'O',
#       'description': 'Flyout'}],
#     'home': [{'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 547943,
#        'fullName': 'Hyun Jin Ryu',
#        'link': '/api/v1/people/547943'},
#       'batter': {'id': 570482,
#        'fullName': 'Gio Urshela',
#        'link': '/api/v1/people/570482'},
#       'coordinates': {'x': 176.51, 'y': 144.9},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 547943,
#        'fullName': 'Hyun Jin Ryu',
#        'link': '/api/v1/people/547943'},
#       'batter': {'id': 596142,
#        'fullName': 'Gary Sanchez',
#        'link': '/api/v1/people/596142'},
#       'coordinates': {'x': 67.19, 'y': 73.91},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 547943,
#        'fullName': 'Hyun Jin Ryu',
#        'link': '/api/v1/people/547943'},
#       'batter': {'id': 640449,
#        'fullName': 'Clint Frazier',
#        'link': '/api/v1/people/640449'},
#       'coordinates': {'x': 91.46, 'y': 169.68},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 547943,
#        'fullName': 'Hyun Jin Ryu',
#        'link': '/api/v1/people/547943'},
#       'batter': {'id': 518934,
#        'fullName': 'DJ LeMahieu',
#        'link': '/api/v1/people/518934'},
#       'coordinates': {'x': 150.1, 'y': 140.03},
#       'type': 'O',
#       'description': 'Groundout'}]}},
#   {'startIndex': 39,
#    'endIndex': 47,
#    'top': [39, 40, 41, 42],
#    'bottom': [43, 44, 45, 46, 47],
#    'hits': {'away': [{'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 543037,
#        'fullName': 'Gerrit Cole',
#        'link': '/api/v1/people/543037'},
#       'batter': {'id': 606192,
#        'fullName': 'Teoscar Hernandez',
#        'link': '/api/v1/people/606192'},
#       'coordinates': {'x': 32.63, 'y': 47.89},
#       'type': 'H',
#       'description': 'Home Run'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 643338,
#        'fullName': 'Chad Green',
#        'link': '/api/v1/people/643338'},
#       'batter': {'id': 666971,
#        'fullName': 'Lourdes Gurriel Jr.',
#        'link': '/api/v1/people/666971'},
#       'coordinates': {'x': 100.93, 'y': 171.31},
#       'type': 'O',
#       'description': 'Grounded Into DP'}],
#     'home': [{'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 547943,
#        'fullName': 'Hyun Jin Ryu',
#        'link': '/api/v1/people/547943'},
#       'batter': {'id': 592450,
#        'fullName': 'Aaron Judge',
#        'link': '/api/v1/people/592450'},
#       'coordinates': {'x': 104.68, 'y': 96.07},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 547943,
#        'fullName': 'Hyun Jin Ryu',
#        'link': '/api/v1/people/547943'},
#       'batter': {'id': 543305,
#        'fullName': 'Aaron Hicks',
#        'link': '/api/v1/people/543305'},
#       'coordinates': {'x': 100.88, 'y': 173.13},
#       'type': 'O',
#       'description': 'Forceout'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 543022,
#        'fullName': 'Tyler Chatwood',
#        'link': '/api/v1/people/543022'},
#       'batter': {'id': 570482,
#        'fullName': 'Gio Urshela',
#        'link': '/api/v1/people/570482'},
#       'coordinates': {'x': 103.12, 'y': 172.53},
#       'type': 'O',
#       'description': 'Groundout'}]}},
#   {'startIndex': 48,
#    'endIndex': 56,
#    'top': [48, 49, 50, 51],
#    'bottom': [52, 53, 54, 55, 56],
#    'hits': {'away': [{'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 643338,
#        'fullName': 'Chad Green',
#        'link': '/api/v1/people/643338'},
#       'batter': {'id': 642133,
#        'fullName': 'Rowdy Tellez',
#        'link': '/api/v1/people/642133'},
#       'coordinates': {'x': 93.17, 'y': 159.74},
#       'type': 'O',
#       'description': 'Pop Out'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 643338,
#        'fullName': 'Chad Green',
#        'link': '/api/v1/people/643338'},
#       'batter': {'id': 545341,
#        'fullName': 'Randal Grichuk',
#        'link': '/api/v1/people/545341'},
#       'coordinates': {'x': 130.9, 'y': 102.19},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 643338,
#        'fullName': 'Chad Green',
#        'link': '/api/v1/people/643338'},
#       'batter': {'id': 643376,
#        'fullName': 'Danny Jansen',
#        'link': '/api/v1/people/643376'},
#       'coordinates': {'x': 156.21, 'y': 125.38},
#       'type': 'O',
#       'description': 'Pop Out'}],
#     'home': [{'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 475479,
#        'fullName': 'David Phelps',
#        'link': '/api/v1/people/475479'},
#       'batter': {'id': 596142,
#        'fullName': 'Gary Sanchez',
#        'link': '/api/v1/people/596142'},
#       'coordinates': {'x': 103.6, 'y': 166.49},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 475479,
#        'fullName': 'David Phelps',
#        'link': '/api/v1/people/475479'},
#       'batter': {'id': 457803,
#        'fullName': 'Jay Bruce',
#        'link': '/api/v1/people/457803'},
#       'coordinates': {'x': 168.14, 'y': 58.94},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 475479,
#        'fullName': 'David Phelps',
#        'link': '/api/v1/people/475479'},
#       'batter': {'id': 640449,
#        'fullName': 'Clint Frazier',
#        'link': '/api/v1/people/640449'},
#       'coordinates': {'x': 76.07, 'y': 128.1},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 475479,
#        'fullName': 'David Phelps',
#        'link': '/api/v1/people/475479'},
#       'batter': {'id': 592450,
#        'fullName': 'Aaron Judge',
#        'link': '/api/v1/people/592450'},
#       'coordinates': {'x': 102.35, 'y': 166.21},
#       'type': 'O',
#       'description': 'Grounded Into DP'}]}},
#   {'startIndex': 57,
#    'endIndex': 63,
#    'top': [57, 58, 59],
#    'bottom': [60, 61, 62, 63],
#    'hits': {'away': [{'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 642528,
#        'fullName': 'Jonathan Loaisiga',
#        'link': '/api/v1/people/642528'},
#       'batter': {'id': 624415,
#        'fullName': 'Cavan Biggio',
#        'link': '/api/v1/people/624415'},
#       'coordinates': {'x': 129.5, 'y': 87.7},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 642528,
#        'fullName': 'Jonathan Loaisiga',
#        'link': '/api/v1/people/642528'},
#       'batter': {'id': 666182,
#        'fullName': 'Bo Bichette',
#        'link': '/api/v1/people/666182'},
#       'coordinates': {'x': 146.9, 'y': 148.49},
#       'type': 'O',
#       'description': 'Groundout'}],
#     'home': [{'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 503569,
#        'fullName': 'Rafael Dolis',
#        'link': '/api/v1/people/503569'},
#       'batter': {'id': 650402,
#        'fullName': 'Gleyber Torres',
#        'link': '/api/v1/people/650402'},
#       'coordinates': {'x': 144.41, 'y': 170.45},
#       'type': 'O',
#       'description': 'Pop Out'}]}},
#   {'startIndex': 64,
#    'endIndex': 72,
#    'top': [64, 65, 66, 67],
#    'bottom': [68, 69, 70, 71, 72],
#    'hits': {'away': [{'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 9,
#       'pitcher': {'id': 503285,
#        'fullName': "Darren O'Day",
#        'link': '/api/v1/people/503285'},
#       'batter': {'id': 606192,
#        'fullName': 'Teoscar Hernandez',
#        'link': '/api/v1/people/606192'},
#       'coordinates': {'x': 109.6, 'y': 136.44},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 9,
#       'pitcher': {'id': 503285,
#        'fullName': "Darren O'Day",
#        'link': '/api/v1/people/503285'},
#       'batter': {'id': 665489,
#        'fullName': 'Vladimir Guerrero Jr.',
#        'link': '/api/v1/people/665489'},
#       'coordinates': {'x': 144.71, 'y': 141.73},
#       'type': 'O',
#       'description': 'Pop Out'},
#      {'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 9,
#       'pitcher': {'id': 503285,
#        'fullName': "Darren O'Day",
#        'link': '/api/v1/people/503285'},
#       'batter': {'id': 642133,
#        'fullName': 'Rowdy Tellez',
#        'link': '/api/v1/people/642133'},
#       'coordinates': {'x': 201.21, 'y': 131.25},
#       'type': 'O',
#       'description': 'Flyout'}],
#     'home': [{'team': {'id': 147,
#        'name': 'New York Yankees',
#        'link': '/api/v1/teams/147',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 9,
#       'pitcher': {'id': 605447,
#        'fullName': 'Jordan Romano',
#        'link': '/api/v1/people/605447'},
#       'batter': {'id': 518934,
#        'fullName': 'DJ LeMahieu',
#        'link': '/api/v1/people/518934'},
#       'coordinates': {'x': 104.69, 'y': 167.68},
#       'type': 'O',
#       'description': 'Fielders Choice Out'}]}},
#   {'startIndex': 73,
#    'endIndex': 79,
#    'top': [73, 74, 75, 76],
#    'bottom': [77, 78, 79],
#    'hits': {'away': [{'team': {'id': 141,
#        'name': 'Toronto Blue Jays',
#        'link': '/api/v1/teams/141',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 10,
#       'pitcher': {'id': 656793,
#        'fullName': 'Nick Nelson',
#        'link': '/api/v1/people/656793'},
#       'batter': {'id': 545341,
#        'fullName': 'Randal Grichuk',
#        'link': '/api/v1/people/545341'},
#       'coordinates': {'x': 191.73, 'y': 82.14},
#       'type': 'H',
#       'description': 'Double'}],
#     'home': []}}]}

# %% [markdown]
# A quick skim of the content implies that the most of the contents are under the key `allPlays`.

# %%
allPlays_content = playbyplay_json_content['allPlays']
allPlays_content
# Out:
# [{'result': {'type': 'atBat',
#    'event': 'Groundout',
#    'eventType': 'field_out',
#    'description': 'Marcus Semien grounds out, shortstop Gleyber Torres to first baseman Jay Bruce.',
#    'rbi': 0,
#    'awayScore': 0,
#    'homeScore': 0},
#   'about': {'atBatIndex': 0,
#    'halfInning': 'top',
#    'isTopInning': True,
#    'inning': 1,
#    'startTime': '2021-04-01T16:38:06.807Z',
#    'endTime': '2021-04-01T17:10:52.200Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 0},
#   'count': {'balls': 1, 'strikes': 0, 'outs': 1},
#   'matchup': {'batter': {'id': 543760,
#     'fullName': 'Marcus Semien',
#     'link': '/api/v1/people/543760'},
#    'batSide': {'code': 'R', 'description': 'Right'},
#    'pitcher': {'id': 543037,
#     'fullName': 'Gerrit Cole',
#     'link': '/api/v1/people/543037'},
#    'pitchHand': {'code': 'R', 'description': 'Right'},
#    'batterHotColdZones': [],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [3, 4],
#   'actionIndex': [0, 1, 2],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 1},
#     'details': {'event': 'Groundout',
#      'eventType': 'field_out',
#      'movementReason': None,
#      'runner': {'id': 543760,
#       'fullName': 'Marcus Semien',
#       'link': '/api/v1/people/543760'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 4},
#     'credits': [{'player': {'id': 650402, 'link': '/api/v1/people/650402'},
#       'position': {'code': '6',
#        'name': 'Shortstop',
#        'type': 'Infielder',
#        'abbreviation': 'SS'},
#       'credit': 'f_assist'},
#      {'player': {'id': 457803, 'link': '/api/v1/people/457803'},
#       'position': {'code': '3',
#        'name': 'First Base',
#        'type': 'Infielder',
#        'abbreviation': '1B'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'description': 'Status Change - Pre-Game',
#      'event': 'Game Advisory',
#      'eventType': 'game_advisory',
#      'awayScore': 0,
#      'homeScore': 0,
#      'isScoringPlay': False,
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#     'index': 0,
#     'startTime': '2021-04-01T16:38:06.807Z',
#     'endTime': '2021-04-01T16:56:47.520Z',
#     'isPitch': False,
#     'type': 'action',
#     'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#    {'details': {'description': 'Status Change - Warmup',
#      'event': 'Game Advisory',
#      'eventType': 'game_advisory',
#      'awayScore': 0,
#      'homeScore': 0,
#      'isScoringPlay': False,
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#     'index': 1,
#     'startTime': '2021-04-01T16:56:47.520Z',
#     'endTime': '2021-04-01T17:10:02.256Z',
#     'isPitch': False,
#     'type': 'action',
#     'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#    {'details': {'description': 'Status Change - In Progress',
#      'event': 'Game Advisory',
#      'eventType': 'game_advisory',
#      'awayScore': 0,
#      'homeScore': 0,
#      'isScoringPlay': False,
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#     'index': 2,
#     'startTime': '2021-04-01T17:10:02.256Z',
#     'isPitch': False,
#     'type': 'action',
#     'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 0, 'outs': 0},
#     'pitchData': {'startSpeed': 97.7,
#      'endSpeed': 89.0,
#      'strikeZoneTop': 3.25,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 33.13,
#       'aZ': -9.7,
#       'pfxX': -6.78,
#       'pfxZ': 11.02,
#       'pX': -0.5,
#       'pZ': 3.54,
#       'vX0': 6.33,
#       'vY0': -142.05,
#       'vZ0': -4.35,
#       'x': 129.48,
#       'y': 169.3,
#       'x0': -1.88,
#       'y0': 50.0,
#       'z0': 5.71,
#       'aX': -13.83},
#      'breaks': {'breakAngle': 49.2,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2672,
#       'spinDirection': 207},
#      'zone': 11,
#      'typeConfidence': 2.0,
#      'plateTime': 0.39,
#      'extension': 6.57},
#     'index': 3,
#     'playId': '7b18a365-daf0-48a1-b0e5-d63c370061bc',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T17:10:31.233Z',
#     'endTime': '2021-04-01T17:10:34.765Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#      'description': 'In play, out(s)',
#      'code': 'X',
#      'ballColor': 'rgba(26, 86, 190, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': True,
#      'isStrike': False,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 0, 'outs': 0},
#     'pitchData': {'startSpeed': 95.3,
#      'endSpeed': 87.5,
#      'strikeZoneTop': 3.37,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 29.0,
#       'aZ': -10.65,
#       'pfxX': -6.74,
#       'pfxZ': 11.0,
#       'pX': 0.64,
#       'pZ': 2.77,
#       'vX0': 8.37,
#       'vY0': -138.5,
#       'vZ0': -5.9,
#       'x': 125.89,
#       'y': 150.94,
#       'x0': -1.54,
#       'y0': 50.0,
#       'z0': 5.62,
#       'aX': -13.17},
#      'breaks': {'breakAngle': 44.4,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2581,
#       'spinDirection': 209},
#      'zone': 3,
#      'typeConfidence': 2.0,
#      'plateTime': 0.39,
#      'extension': 6.53},
#     'hitData': {'launchSpeed': 99.9,
#      'launchAngle': -1.0,
#      'totalDistance': 40.0,
#      'trajectory': 'ground_ball',
#      'hardness': 'medium',
#      'location': '6',
#      'coordinates': {'coordX': 99.28, 'coordY': 147.19}},
#     'index': 4,
#     'playId': '1cf7d060-1f8b-40d2-92e6-6a16b8252d94',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T17:10:43.173Z',
#     'endTime': '2021-04-01T17:10:52.200Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T17:10:52.200Z',
#   'atBatIndex': 0},
#  {'result': {'type': 'atBat',
#    'event': 'Strikeout',
#    'eventType': 'strikeout',
#    'description': 'Cavan Biggio strikes out swinging.',
#    'rbi': 0,
#    'awayScore': 0,
#    'homeScore': 0},
#   'about': {'atBatIndex': 1,
#    'halfInning': 'top',
#    'isTopInning': True,
#    'inning': 1,
#    'startTime': '2021-04-01T17:11:26.715Z',
#    'endTime': '2021-04-01T17:12:19.210Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 14},
#   'count': {'balls': 1, 'strikes': 3, 'outs': 2},
#   'matchup': {'batter': {'id': 624415,
#     'fullName': 'Cavan Biggio',
#     'link': '/api/v1/people/624415'},
#    'batSide': {'code': 'L', 'description': 'Left'},
#    'pitcher': {'id': 543037,
#     'fullName': 'Gerrit Cole',
#     'link': '/api/v1/people/543037'},
#    'pitchHand': {'code': 'R', 'description': 'Right'},
#    'batterHotColdZones': [],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_LHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [0, 1, 2, 3],
#   'actionIndex': [],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 2},
#     'details': {'event': 'Strikeout',
#      'eventType': 'strikeout',
#      'movementReason': None,
#      'runner': {'id': 624415,
#       'fullName': 'Cavan Biggio',
#       'link': '/api/v1/people/624415'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 3},
#     'credits': [{'player': {'id': 596142, 'link': '/api/v1/people/596142'},
#       'position': {'code': '2',
#        'name': 'Catcher',
#        'type': 'Catcher',
#        'abbreviation': 'C'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'call': {'code': 'C',
#       'description': 'Called Strike'},
#      'description': 'Called Strike',
#      'code': 'C',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 1, 'outs': 1},
#     'pitchData': {'startSpeed': 96.6,
#      'endSpeed': 86.4,
#      'strikeZoneTop': 3.36,
#      'strikeZoneBottom': 1.59,
#      'coordinates': {'aY': 38.1,
#       'aZ': -7.27,
#       'pfxX': -6.31,
#       'pfxZ': 12.78,
#       'pX': -0.38,
#       'pZ': 2.45,
#       'vX0': 5.77,
#       'vY0': -140.22,
#       'vZ0': -7.33,
#       'x': 131.55,
#       'y': 172.73,
#       'x0': -1.67,
#       'y0': 50.0,
#       'z0': 5.6,
#       'aX': -12.29},
#      'breaks': {'breakAngle': 49.2,
#       'breakLength': 2.4,
#       'breakY': 24.0,
#       'spinRate': 2573,
#       'spinDirection': 209},
#      'zone': 4,
#      'typeConfidence': 2.0,
#      'plateTime': 0.39,
#      'extension': 6.57},
#     'index': 0,
#     'playId': 'a06f87d5-068f-47f8-8567-dc99fe430cd1',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T17:11:22.056Z',
#     'endTime': '2021-04-01T17:11:26.074Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(153, 171, 0, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'KC', 'description': 'Knuckle Curve'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 1, 'outs': 1},
#     'pitchData': {'startSpeed': 82.2,
#      'endSpeed': 74.9,
#      'strikeZoneTop': 3.32,
#      'strikeZoneBottom': 1.59,
#      'coordinates': {'aY': 27.97,
#       'aZ': -44.43,
#       'pfxX': 4.22,
#       'pfxZ': -8.68,
#       'pX': -0.03,
#       'pZ': 0.62,
#       'vX0': 2.86,
#       'vY0': -119.5,
#       'vZ0': -2.5,
#       'x': 118.16,
#       'y': 222.14,
#       'x0': -1.8,
#       'y0': 50.0,
#       'z0': 5.76,
#       'aX': 5.96},
#      'breaks': {'breakAngle': 8.4,
#       'breakLength': 13.2,
#       'breakY': 24.0,
#       'spinRate': 2737,
#       'spinDirection': 28},
#      'zone': 13,
#      'typeConfidence': 2.0,
#      'plateTime': 0.46,
#      'extension': 6.31},
#     'index': 1,
#     'playId': '9c878c08-7ebb-4556-a420-b78c7c650e2b',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T17:11:34.798Z',
#     'endTime': '2021-04-01T17:11:38.764Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'F', 'description': 'Foul'},
#      'description': 'Foul',
#      'code': 'F',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(0, 85, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'CH', 'description': 'Changeup'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 2, 'outs': 1},
#     'pitchData': {'startSpeed': 87.8,
#      'endSpeed': 79.2,
#      'strikeZoneTop': 3.47,
#      'strikeZoneBottom': 1.59,
#      'coordinates': {'aY': 29.88,
#       'aZ': -18.88,
#       'pfxX': -10.4,
#       'pfxZ': 8.19,
#       'pX': -0.52,
#       'pZ': 2.11,
#       'vX0': 6.33,
#       'vY0': -127.52,
#       'vZ0': -4.65,
#       'x': 137.01,
#       'y': 181.91,
#       'x0': -1.71,
#       'y0': 50.0,
#       'z0': 5.47,
#       'aX': -16.87},
#      'breaks': {'breakAngle': 37.2,
#       'breakLength': 6.0,
#       'breakY': 24.0,
#       'spinRate': 1855,
#       'spinDirection': 241},
#      'zone': 7,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.68},
#     'index': 2,
#     'playId': '780fbde7-6a72-4646-bf85-fb668083267e',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T17:11:53.466Z',
#     'endTime': '2021-04-01T17:11:57.048Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 3, 'outs': 1},
#     'pitchData': {'startSpeed': 98.3,
#      'endSpeed': 88.6,
#      'strikeZoneTop': 3.47,
#      'strikeZoneBottom': 1.59,
#      'coordinates': {'aY': 36.98,
#       'aZ': -8.85,
#       'pfxX': -8.25,
#       'pfxZ': 11.41,
#       'pX': -0.79,
#       'pZ': 3.92,
#       'vX0': 6.01,
#       'vY0': -142.99,
#       'vZ0': -3.48,
#       'x': 147.02,
#       'y': 132.99,
#       'x0': -1.86,
#       'y0': 50.0,
#       'z0': 5.72,
#       'aX': -16.86},
#      'breaks': {'breakAngle': 57.6,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2648,
#       'spinDirection': 208},
#      'zone': 11,
#      'typeConfidence': 2.0,
#      'plateTime': 0.38,
#      'extension': 6.44},
#     'index': 3,
#     'playId': '7272dfe6-98d2-42bf-920e-dc6099112dde',
#     'pitchNumber': 4,
#     'startTime': '2021-04-01T17:12:13.113Z',
#     'endTime': '2021-04-01T17:12:19.210Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T17:12:19.210Z',
#   'atBatIndex': 1},
#  {'result': {'type': 'atBat',
#    'event': 'Groundout',
#    'eventType': 'field_out',
#    'description': 'Bo Bichette grounds out sharply, second baseman DJ LeMahieu to first baseman Jay Bruce.',
#    'rbi': 0,
#    'awayScore': 0,
#    'homeScore': 0},
#   'about': {'atBatIndex': 2,
#    'halfInning': 'top',
#    'isTopInning': True,
#    'inning': 1,
#    'startTime': '2021-04-01T17:12:36.595Z',
#    'endTime': '2021-04-01T17:14:23.991Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 0},
#   'count': {'balls': 3, 'strikes': 2, 'outs': 3},
#   'matchup': {'batter': {'id': 666182,
#     'fullName': 'Bo Bichette',
#     'link': '/api/v1/people/666182'},
#    'batSide': {'code': 'R', 'description': 'Right'},
#    'pitcher': {'id': 543037,
#     'fullName': 'Gerrit Cole',
#     'link': '/api/v1/people/543037'},
#    'pitchHand': {'code': 'R', 'description': 'Right'},
#    'batterHotColdZones': [],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [0, 1, 2, 3, 4, 5],
#   'actionIndex': [],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 3},
#     'details': {'event': 'Groundout',
#      'eventType': 'field_out',
#      'movementReason': None,
#      'runner': {'id': 666182,
#       'fullName': 'Bo Bichette',
#       'link': '/api/v1/people/666182'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 5},
#     'credits': [{'player': {'id': 518934, 'link': '/api/v1/people/518934'},
#       'position': {'code': '4',
#        'name': 'Second Base',
#        'type': 'Infielder',
#        'abbreviation': '2B'},
#       'credit': 'f_assist'},
#      {'player': {'id': 457803, 'link': '/api/v1/people/457803'},
#       'position': {'code': '3',
#        'name': 'First Base',
#        'type': 'Infielder',
#        'abbreviation': '1B'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'call': {'code': 'C',
#       'description': 'Called Strike'},
#      'description': 'Called Strike',
#      'code': 'C',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 1, 'outs': 2},
#     'pitchData': {'startSpeed': 96.5,
#      'endSpeed': 87.4,
#      'strikeZoneTop': 3.62,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 34.22,
#       'aZ': -11.92,
#       'pfxX': -7.6,
#       'pfxZ': 10.26,
#       'pX': -0.02,
#       'pZ': 3.02,
#       'vX0': 7.43,
#       'vY0': -140.23,
#       'vZ0': -4.95,
#       'x': 117.89,
#       'y': 157.11,
#       'x0': -1.73,
#       'y0': 50.0,
#       'z0': 5.6,
#       'aX': -15.01},
#      'breaks': {'breakAngle': 45.6,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2609,
#       'spinDirection': 212},
#      'zone': 2,
#      'typeConfidence': 2.0,
#      'plateTime': 0.39,
#      'extension': 6.61},
#     'index': 0,
#     'playId': '48c69d65-c67c-4b43-8e9b-c39aaa2aea46',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T17:12:44.209Z',
#     'endTime': '2021-04-01T17:12:47.934Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'C', 'description': 'Called Strike'},
#      'description': 'Called Strike',
#      'code': 'C',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(0, 0, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'SL', 'description': 'Slider'},
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 87.7,
#      'endSpeed': 81.6,
#      'strikeZoneTop': 3.6,
#      'strikeZoneBottom': 1.66,
#      'coordinates': {'aY': 23.14,
#       'aZ': -29.6,
#       'pfxX': 3.48,
#       'pfxZ': 1.54,
#       'pX': 0.91,
#       'pZ': 2.59,
#       'vX0': 5.54,
#       'vY0': -127.7,
#       'vZ0': -2.2,
#       'x': 82.16,
#       'y': 168.89,
#       'x0': -1.72,
#       'y0': 50.0,
#       'z0': 5.76,
#       'aX': 5.81},
#      'breaks': {'breakAngle': 13.2,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 2668,
#       'spinDirection': 100},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.44},
#     'index': 1,
#     'playId': 'ec1ce8e6-847e-41f8-8bda-b88d16f9574f',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T17:12:57.813Z',
#     'endTime': '2021-04-01T17:13:01.621Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(0, 0, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'SL', 'description': 'Slider'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 88.1,
#      'endSpeed': 81.3,
#      'strikeZoneTop': 3.39,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 25.83,
#       'aZ': -25.65,
#       'pfxX': 2.18,
#       'pfxZ': 3.93,
#       'pX': 1.87,
#       'pZ': 0.92,
#       'vX0': 7.9,
#       'vY0': -127.97,
#       'vZ0': -6.57,
#       'x': 45.7,
#       'y': 213.96,
#       'x0': -1.54,
#       'y0': 50.01,
#       'z0': 5.52,
#       'aX': 3.63},
#      'breaks': {'breakAngle': 10.8,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 2786,
#       'spinDirection': 107},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.53},
#     'index': 2,
#     'playId': '6295d438-10ac-4870-91eb-726a7c85ee61',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T17:13:14.784Z',
#     'endTime': '2021-04-01T17:13:17.987Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 2, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 96.9,
#      'endSpeed': 88.3,
#      'strikeZoneTop': 3.3,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 32.5,
#       'aZ': -10.34,
#       'pfxX': -7.99,
#       'pfxZ': 10.85,
#       'pX': -1.17,
#       'pZ': 3.96,
#       'vX0': 4.71,
#       'vY0': -141.04,
#       'vZ0': -2.78,
#       'x': 161.65,
#       'y': 131.83,
#       'x0': -1.83,
#       'y0': 50.0,
#       'z0': 5.63,
#       'aX': -16.07},
#      'breaks': {'breakAngle': 54.0,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2588,
#       'spinDirection': 220},
#      'zone': 11,
#      'typeConfidence': 2.0,
#      'plateTime': 0.39,
#      'extension': 6.5},
#     'index': 3,
#     'playId': 'c7d35a29-d816-48d2-974b-df49571f98fc',
#     'pitchNumber': 4,
#     'startTime': '2021-04-01T17:13:36.033Z',
#     'endTime': '2021-04-01T17:13:39.976Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(0, 0, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'SL', 'description': 'Slider'},
#      'hasReview': False},
#     'count': {'balls': 3, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 88.6,
#      'endSpeed': 82.4,
#      'strikeZoneTop': 3.29,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 24.93,
#       'aZ': -28.14,
#       'pfxX': 3.56,
#       'pfxZ': 2.38,
#       'pX': 1.98,
#       'pZ': 0.54,
#       'vX0': 7.92,
#       'vY0': -128.77,
#       'vZ0': -7.32,
#       'x': 41.48,
#       'y': 224.17,
#       'x0': -1.59,
#       'y0': 50.0,
#       'z0': 5.58,
#       'aX': 6.02},
#      'breaks': {'breakAngle': 14.4,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 2722,
#       'spinDirection': 115},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.42,
#      'extension': 6.55},
#     'index': 4,
#     'playId': 'a595c9ec-baf1-461f-a950-60d93644b742',
#     'pitchNumber': 5,
#     'startTime': '2021-04-01T17:13:52.709Z',
#     'endTime': '2021-04-01T17:13:56.098Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#      'description': 'In play, out(s)',
#      'code': 'X',
#      'ballColor': 'rgba(26, 86, 190, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': True,
#      'isStrike': False,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 3, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 96.8,
#      'endSpeed': 86.9,
#      'strikeZoneTop': 3.37,
#      'strikeZoneBottom': 1.53,
#      'coordinates': {'aY': 37.28,
#       'aZ': -11.46,
#       'pfxX': -8.15,
#       'pfxZ': 10.54,
#       'pX': -0.04,
#       'pZ': 2.55,
#       'vX0': 7.16,
#       'vY0': -140.6,
#       'vZ0': -6.26,
#       'x': 118.53,
#       'y': 170.0,
#       'x0': -1.58,
#       'y0': 50.0,
#       'z0': 5.57,
#       'aX': -16.03},
#      'breaks': {'breakAngle': 46.8,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2592,
#       'spinDirection': 204},
#      'zone': 5,
#      'typeConfidence': 2.0,
#      'plateTime': 0.39,
#      'extension': 6.61},
#     'hitData': {'launchSpeed': 102.2,
#      'launchAngle': -11.0,
#      'totalDistance': 12.0,
#      'trajectory': 'ground_ball',
#      'hardness': 'hard',
#      'location': '4',
#      'coordinates': {'coordX': 139.61, 'coordY': 140.46}},
#     'index': 5,
#     'playId': 'c2e9fb82-02a6-4145-b273-f8243f2d75d4',
#     'pitchNumber': 6,
#     'startTime': '2021-04-01T17:14:16.893Z',
#     'endTime': '2021-04-01T17:14:23.991Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T17:14:23.991Z',
#   'atBatIndex': 2},
#  {'result': {'type': 'atBat',
#    'event': 'Groundout',
#    'eventType': 'field_out',
#    'description': 'DJ LeMahieu grounds out to first baseman Vladimir Guerrero Jr.',
#    'rbi': 0,
#    'awayScore': 0,
#    'homeScore': 0},
#   'about': {'atBatIndex': 3,
#    'halfInning': 'bottom',
#    'isTopInning': False,
#    'inning': 1,
#    'startTime': '2021-04-01T17:16:25.939Z',
#    'endTime': '2021-04-01T17:18:03.094Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 0},
#   'count': {'balls': 1, 'strikes': 2, 'outs': 1},
#   'matchup': {'batter': {'id': 518934,
#     'fullName': 'DJ LeMahieu',
#     'link': '/api/v1/people/518934'},
#    'batSide': {'code': 'R', 'description': 'Right'},
#    'pitcher': {'id': 547943,
#     'fullName': 'Hyun Jin Ryu',
#     'link': '/api/v1/people/547943'},
#    'pitchHand': {'code': 'L', 'description': 'Left'},
#    'batterHotColdZones': [],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [0, 1, 2, 3],
#   'actionIndex': [],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 1},
#     'details': {'event': 'Groundout',
#      'eventType': 'field_out',
#      'movementReason': None,
#      'runner': {'id': 518934,
#       'fullName': 'DJ LeMahieu',
#       'link': '/api/v1/people/518934'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 3},
#     'credits': [{'player': {'id': 665489, 'link': '/api/v1/people/665489'},
#       'position': {'code': '3',
#        'name': 'First Base',
#        'type': 'Infielder',
#        'abbreviation': '1B'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'call': {'code': 'C',
#       'description': 'Called Strike'},
#      'description': 'Called Strike',
#      'code': 'C',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 1, 'outs': 0},
#     'pitchData': {'startSpeed': 87.1,
#      'endSpeed': 79.1,
#      'strikeZoneTop': 3.39,
#      'strikeZoneBottom': 1.63,
#      'coordinates': {'aY': 27.72,
#       'aZ': -18.68,
#       'pfxX': 7.6,
#       'pfxZ': 8.4,
#       'pX': -0.42,
#       'pZ': 2.25,
#       'vX0': -8.38,
#       'vY0': -126.45,
#       'vZ0': -5.3,
#       'x': 132.88,
#       'y': 178.06,
#       'x0': 1.97,
#       'y0': 50.0,
#       'z0': 5.89,
#       'aX': 12.2},
#      'breaks': {'breakAngle': 27.6,
#       'breakLength': 6.0,
#       'breakY': 24.0,
#       'spinRate': 1966,
#       'spinDirection': 140},
#      'zone': 4,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.3},
#     'index': 0,
#     'playId': '14cc85cf-16de-49b5-8933-a23cf8a69c60',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T17:16:56.677Z',
#     'endTime': '2021-04-01T17:17:00.309Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(152, 0, 101, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'FC', 'description': 'Cutter'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 1, 'outs': 0},
#     'pitchData': {'startSpeed': 84.2,
#      'endSpeed': 77.8,
#      'strikeZoneTop': 3.25,
#      'strikeZoneBottom': 1.63,
#      'coordinates': {'aY': 22.52,
#       'aZ': -26.34,
#       'pfxX': 1.23,
#       'pfxZ': 3.81,
#       'pX': -1.59,
#       'pZ': 3.33,
#       'vX0': -8.81,
#       'vY0': -122.48,
#       'vZ0': -1.3,
#       'x': 177.73,
#       'y': 148.76,
#       'x0': 1.88,
#       'y0': 50.0,
#       'z0': 6.11,
#       'aX': 1.89},
#      'breaks': {'breakAngle': 1.2,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 1943,
#       'spinDirection': 165},
#      'zone': 11,
#      'typeConfidence': 2.0,
#      'plateTime': 0.45,
#      'extension': 6.28},
#     'index': 1,
#     'playId': 'ec6896b7-78a1-473a-867f-c028a9cbb778',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T17:17:14.128Z',
#     'endTime': '2021-04-01T17:17:18.216Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 2, 'outs': 0},
#     'pitchData': {'startSpeed': 88.4,
#      'endSpeed': 80.5,
#      'strikeZoneTop': 3.55,
#      'strikeZoneBottom': 1.63,
#      'coordinates': {'aY': 28.01,
#       'aZ': -19.43,
#       'pfxX': 6.96,
#       'pfxZ': 7.67,
#       'pX': -0.18,
#       'pZ': 2.69,
#       'vX0': -7.5,
#       'vY0': -128.46,
#       'vZ0': -4.24,
#       'x': 123.74,
#       'y': 166.12,
#       'x0': 1.88,
#       'y0': 50.0,
#       'z0': 5.88,
#       'aX': 11.56},
#      'breaks': {'breakAngle': 26.4,
#       'breakLength': 6.0,
#       'breakY': 24.0,
#       'spinRate': 1938,
#       'spinDirection': 144},
#      'zone': 5,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.45},
#     'index': 2,
#     'playId': '80ec89ca-9e5c-4f22-a291-71d9298477c6',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T17:17:32.447Z',
#     'endTime': '2021-04-01T17:17:35.496Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#      'description': 'In play, out(s)',
#      'code': 'X',
#      'ballColor': 'rgba(26, 86, 190, 1.0)',
#      'trailColor': 'rgba(152, 0, 101, 1.0)',
#      'isInPlay': True,
#      'isStrike': False,
#      'isBall': False,
#      'type': {'code': 'FC', 'description': 'Cutter'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 2, 'outs': 0},
#     'pitchData': {'startSpeed': 87.6,
#      'endSpeed': 80.8,
#      'strikeZoneTop': 3.55,
#      'strikeZoneBottom': 1.63,
#      'coordinates': {'aY': 24.59,
#       'aZ': -20.98,
#       'pfxX': 1.41,
#       'pfxZ': 6.75,
#       'pX': -0.52,
#       'pZ': 3.15,
#       'vX0': -6.25,
#       'vY0': -127.53,
#       'vZ0': -3.02,
#       'x': 136.7,
#       'y': 153.78,
#       'x0': 1.78,
#       'y0': 50.0,
#       'z0': 5.99,
#       'aX': 2.33},
#      'breaks': {'breakAngle': 3.6,
#       'breakLength': 4.8,
#       'breakY': 24.0,
#       'spinRate': 2038,
#       'spinDirection': 156},
#      'zone': 1,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.45},
#     'hitData': {'launchSpeed': 82.7,
#      'launchAngle': 6.0,
#      'totalDistance': 86.0,
#      'trajectory': 'ground_ball',
#      'hardness': 'medium',
#      'location': '3',
#      'coordinates': {'coordX': 151.65, 'coordY': 158.12}},
#     'index': 3,
#     'playId': '350c41ed-99e2-4262-aed4-880220109eeb',
#     'pitchNumber': 4,
#     'startTime': '2021-04-01T17:17:55.958Z',
#     'endTime': '2021-04-01T17:18:03.094Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T17:18:03.094Z',
#   'atBatIndex': 3},
#  {'result': {'type': 'atBat',
#    'event': 'Strikeout',
#    'eventType': 'strikeout',
#    'description': 'Aaron Judge strikes out swinging.',
#    'rbi': 0,
#    'awayScore': 0,
#    'homeScore': 0},
#   'about': {'atBatIndex': 4,
#    'halfInning': 'bottom',
#    'isTopInning': False,
#    'inning': 1,
#    'startTime': '2021-04-01T17:18:20.009Z',
#    'endTime': '2021-04-01T17:20:43.827Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 14},
#   'count': {'balls': 3, 'strikes': 3, 'outs': 2},
#   'matchup': {'batter': {'id': 592450,
#     'fullName': 'Aaron Judge',
#     'link': '/api/v1/people/592450'},
#    'batSide': {'code': 'R', 'description': 'Right'},
#    'pitcher': {'id': 547943,
#     'fullName': 'Hyun Jin Ryu',
#     'link': '/api/v1/people/547943'},
#    'pitchHand': {'code': 'L', 'description': 'Left'},
#    'batterHotColdZones': [],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [0, 1, 2, 3, 4, 5],
#   'actionIndex': [],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 2},
#     'details': {'event': 'Strikeout',
#      'eventType': 'strikeout',
#      'movementReason': None,
#      'runner': {'id': 592450,
#       'fullName': 'Aaron Judge',
#       'link': '/api/v1/people/592450'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 5},
#     'credits': [{'player': {'id': 643376, 'link': '/api/v1/people/643376'},
#       'position': {'code': '2',
#        'name': 'Catcher',
#        'type': 'Catcher',
#        'abbreviation': 'C'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 0, 'outs': 1},
#     'pitchData': {'startSpeed': 90.4,
#      'endSpeed': 81.7,
#      'strikeZoneTop': 4.01,
#      'strikeZoneBottom': 1.87,
#      'coordinates': {'aY': 31.5,
#       'aZ': -17.24,
#       'pfxX': 8.77,
#       'pfxZ': 8.68,
#       'pX': 0.5,
#       'pZ': 1.79,
#       'vX0': -6.72,
#       'vY0': -131.28,
#       'vZ0': -6.61,
#       'x': 97.95,
#       'y': 190.49,
#       'x0': 1.97,
#       'y0': 50.0,
#       'z0': 5.65,
#       'aX': 15.09},
#      'breaks': {'breakAngle': 36.0,
#       'breakLength': 6.0,
#       'breakY': 24.0,
#       'spinRate': 2165,
#       'spinDirection': 135},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.42,
#      'extension': 6.54},
#     'index': 0,
#     'playId': '54d97e07-31dd-457f-a53e-7e8e3b8a4b09',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T17:18:35.713Z',
#     'endTime': '2021-04-01T17:18:40.449Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(0, 85, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'CH', 'description': 'Changeup'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 1, 'outs': 1},
#     'pitchData': {'startSpeed': 80.0,
#      'endSpeed': 73.0,
#      'strikeZoneTop': 3.76,
#      'strikeZoneBottom': 1.75,
#      'coordinates': {'aY': 23.35,
#       'aZ': -23.61,
#       'pfxX': 8.02,
#       'pfxZ': 6.3,
#       'pX': 0.24,
#       'pZ': 1.57,
#       'vX0': -6.49,
#       'vY0': -116.25,
#       'vZ0': -4.26,
#       'x': 107.82,
#       'y': 196.29,
#       'x0': 2.04,
#       'y0': 50.0,
#       'z0': 5.69,
#       'aX': 10.89},
#      'breaks': {'breakAngle': 21.6,
#       'breakLength': 8.4,
#       'breakY': 24.0,
#       'spinRate': 1547,
#       'spinDirection': 118},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.47,
#      'extension': 6.51},
#     'index': 1,
#     'playId': 'f7377f4a-31c4-4536-9872-6a97a59c22e1',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T17:18:53.986Z',
#     'endTime': '2021-04-01T17:18:57.506Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(0, 85, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'CH', 'description': 'Changeup'},
#      'hasReview': False},
#     'count': {'balls': 2, 'strikes': 1, 'outs': 1},
#     'pitchData': {'startSpeed': 80.6,
#      'endSpeed': 73.5,
#      'strikeZoneTop': 3.81,
#      'strikeZoneBottom': 1.75,
#      'coordinates': {'aY': 23.89,
#       'aZ': -24.04,
#       'pfxX': 7.21,
#       'pfxZ': 5.89,
#       'pX': 1.04,
#       'pZ': 1.81,
#       'vX0': -4.94,
#       'vY0': -117.19,
#       'vZ0': -3.69,
#       'x': 77.23,
#       'y': 189.98,
#       'x0': 2.25,
#       'y0': 50.0,
#       'z0': 5.67,
#       'aX': 9.94},
#      'breaks': {'breakAngle': 20.4,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 1564,
#       'spinDirection': 121},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.47,
#      'extension': 6.62},
#     'index': 2,
#     'playId': '1c40507d-ecf3-4082-b650-c6ece5559090',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T17:19:14.015Z',
#     'endTime': '2021-04-01T17:19:20.559Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'F', 'description': 'Foul'},
#      'description': 'Foul',
#      'code': 'F',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(152, 0, 101, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FC', 'description': 'Cutter'},
#      'hasReview': False},
#     'count': {'balls': 2, 'strikes': 2, 'outs': 1},
#     'pitchData': {'startSpeed': 87.0,
#      'endSpeed': 79.8,
#      'strikeZoneTop': 3.76,
#      'strikeZoneBottom': 1.75,
#      'coordinates': {'aY': 25.87,
#       'aZ': -25.15,
#       'pfxX': -0.6,
#       'pfxZ': 4.33,
#       'pX': -1.02,
#       'pZ': 3.22,
#       'vX0': -6.97,
#       'vY0': -126.58,
#       'vZ0': -1.71,
#       'x': 155.87,
#       'y': 151.76,
#       'x0': 1.85,
#       'y0': 50.0,
#       'z0': 5.92,
#       'aX': -0.97},
#      'breaks': {'breakAngle': 4.8,
#       'breakLength': 6.0,
#       'breakY': 24.0,
#       'spinRate': 2020,
#       'spinDirection': 168},
#      'zone': 11,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.42},
#     'index': 3,
#     'playId': 'b241f1a2-a1ee-4b5b-8729-242e2d7032db',
#     'pitchNumber': 4,
#     'startTime': '2021-04-01T17:19:36.977Z',
#     'endTime': '2021-04-01T17:19:41.378Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(152, 0, 101, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'FC', 'description': 'Cutter'},
#      'hasReview': False},
#     'count': {'balls': 3, 'strikes': 2, 'outs': 1},
#     'pitchData': {'startSpeed': 85.8,
#      'endSpeed': 79.1,
#      'strikeZoneTop': 3.81,
#      'strikeZoneBottom': 1.75,
#      'coordinates': {'aY': 25.05,
#       'aZ': -25.03,
#       'pfxX': -0.64,
#       'pfxZ': 4.54,
#       'pX': -1.47,
#       'pZ': 0.61,
#       'vX0': -7.88,
#       'vY0': -124.61,
#       'vZ0': -7.29,
#       'x': 172.99,
#       'y': 222.3,
#       'x0': 1.82,
#       'y0': 50.0,
#       'z0': 5.64,
#       'aX': -1.0},
#      'breaks': {'breakAngle': 4.8,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 2046,
#       'spinDirection': 150},
#      'zone': 13,
#      'typeConfidence': 2.0,
#      'plateTime': 0.44,
#      'extension': 6.55},
#     'index': 4,
#     'playId': '4ee384f7-aacd-4f8f-8841-b7a2dc471c34',
#     'pitchNumber': 5,
#     'startTime': '2021-04-01T17:20:12.109Z',
#     'endTime': '2021-04-01T17:20:15.655Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 3, 'strikes': 3, 'outs': 1},
#     'pitchData': {'startSpeed': 91.1,
#      'endSpeed': 83.4,
#      'strikeZoneTop': 3.76,
#      'strikeZoneBottom': 1.75,
#      'coordinates': {'aY': 27.93,
#       'aZ': -16.08,
#       'pfxX': 6.44,
#       'pfxZ': 9.05,
#       'pX': -0.52,
#       'pZ': 2.92,
#       'vX0': -8.46,
#       'vY0': -132.44,
#       'vZ0': -4.27,
#       'x': 136.96,
#       'y': 159.97,
#       'x0': 1.88,
#       'y0': 50.0,
#       'z0': 5.73,
#       'aX': 11.45},
#      'breaks': {'breakAngle': 30.0,
#       'breakLength': 4.8,
#       'breakY': 24.0,
#       'spinRate': 2006,
#       'spinDirection': 135},
#      'zone': 4,
#      'typeConfidence': 2.0,
#      'plateTime': 0.41,
#      'extension': 6.63},
#     'index': 5,
#     'playId': 'c60c0fb0-275b-49c9-99aa-7f1b54a5a008',
#     'pitchNumber': 6,
#     'startTime': '2021-04-01T17:20:38.367Z',
#     'endTime': '2021-04-01T17:20:43.827Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T17:20:43.827Z',
#   'atBatIndex': 4},
#  {'result': {'type': 'atBat',
#    'event': 'Strikeout',
#    'eventType': 'strikeout',
#    'description': 'Aaron Hicks strikes out swinging.',
#    'rbi': 0,
#    'awayScore': 0,
#    'homeScore': 0},
#   'about': {'atBatIndex': 5,
#    'halfInning': 'bottom',
#    'isTopInning': False,
#    'inning': 1,
#    'startTime': '2021-04-01T17:20:57.398Z',
#    'endTime': '2021-04-01T17:22:54.200Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 14},
#   'count': {'balls': 2, 'strikes': 3, 'outs': 3},
#   'matchup': {'batter': {'id': 543305,
#     'fullName': 'Aaron Hicks',
#     'link': '/api/v1/people/543305'},
#    'batSide': {'code': 'R', 'description': 'Right'},
#    'pitcher': {'id': 547943,
#     'fullName': 'Hyun Jin Ryu',
#     'link': '/api/v1/people/547943'},
#    'pitchHand': {'code': 'L', 'description': 'Left'},
#    'batterHotColdZones': [],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [0, 1, 2, 3, 4],
#   'actionIndex': [],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 3},
#     'details': {'event': 'Strikeout',
#      'eventType': 'strikeout',
#      'movementReason': None,
#      'runner': {'id': 543305,
#       'fullName': 'Aaron Hicks',
#       'link': '/api/v1/people/543305'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 4},
#     'credits': [{'player': {'id': 643376, 'link': '/api/v1/people/643376'},
#       'position': {'code': '2',
#        'name': 'Catcher',
#        'type': 'Catcher',
#        'abbreviation': 'C'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(50, 0, 221, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'SI', 'description': 'Sinker'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 0, 'outs': 2},
#     'pitchData': {'startSpeed': 89.1,
#      'endSpeed': 80.4,
#      'strikeZoneTop': 3.4,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 31.05,
#       'aZ': -20.66,
#       'pfxX': 9.81,
#       'pfxZ': 6.88,
#       'pX': 0.94,
#       'pZ': 2.41,
#       'vX0': -6.05,
#       'vY0': -129.5,
#       'vZ0': -4.05,
#       'x': 81.31,
#       'y': 173.7,
#       'x0': 2.05,
#       'y0': 50.0,
#       'z0': 5.6,
#       'aX': 16.4},
#      'breaks': {'breakAngle': 34.8,
#       'breakLength': 6.0,
#       'breakY': 24.0,
#       'spinRate': 2024,
#       'spinDirection': 133},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.69},
#     'index': 0,
#     'playId': 'eaf74cb4-8047-4ee9-a81b-e289a74d6e3f',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T17:21:19.475Z',
#     'endTime': '2021-04-01T17:21:23.523Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 1, 'outs': 2},
#     'pitchData': {'startSpeed': 89.7,
#      'endSpeed': 81.1,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 30.14,
#       'aZ': -16.65,
#       'pfxX': 6.73,
#       'pfxZ': 9.12,
#       'pX': 0.03,
#       'pZ': 3.6,
#       'vX0': -7.1,
#       'vY0': -130.31,
#       'vZ0': -2.14,
#       'x': 115.81,
#       'y': 141.69,
#       'x0': 1.93,
#       'y0': 50.0,
#       'z0': 5.7,
#       'aX': 11.45},
#      'breaks': {'breakAngle': 30.0,
#       'breakLength': 4.8,
#       'breakY': 24.0,
#       'spinRate': 1982,
#       'spinDirection': 135},
#      'zone': 12,
#      'typeConfidence': 2.0,
#      'plateTime': 0.42,
#      'extension': 6.56},
#     'index': 1,
#     'playId': '31d9b804-e26f-4c14-a92d-2433e782dc4c',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T17:21:39.183Z',
#     'endTime': '2021-04-01T17:21:42.221Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'B', 'description': 'Ball'},
#      'description': 'Ball',
#      'code': 'B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(0, 34, 255, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'CU', 'description': 'Curveball'},
#      'hasReview': False},
#     'count': {'balls': 2, 'strikes': 1, 'outs': 2},
#     'pitchData': {'startSpeed': 74.6,
#      'endSpeed': 68.5,
#      'strikeZoneTop': 3.4,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 22.1,
#       'aZ': -41.82,
#       'pfxX': -5.27,
#       'pfxZ': -8.25,
#       'pX': 0.21,
#       'pZ': 0.66,
#       'vX0': -2.1,
#       'vY0': -108.5,
#       'vZ0': -1.43,
#       'x': 108.95,
#       'y': 220.99,
#       'x0': 1.88,
#       'y0': 50.0,
#       'z0': 5.96,
#       'aX': -6.17},
#      'breaks': {'breakAngle': 8.4,
#       'breakLength': 14.4,
#       'breakY': 24.0,
#       'spinRate': 2536,
#       'spinDirection': 317},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.51,
#      'extension': 6.28},
#     'index': 2,
#     'playId': 'f9ad6fc6-54a1-4e5d-b84d-e43eef3d97d9',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T17:21:59.332Z',
#     'endTime': '2021-04-01T17:22:04.243Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'C', 'description': 'Called Strike'},
#      'description': 'Called Strike',
#      'code': 'C',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(0, 85, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'CH', 'description': 'Changeup'},
#      'hasReview': False},
#     'count': {'balls': 2, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 81.2,
#      'endSpeed': 74.4,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 22.84,
#       'aZ': -24.49,
#       'pfxX': 6.28,
#       'pfxZ': 5.45,
#       'pX': 0.35,
#       'pZ': 1.79,
#       'vX0': -5.83,
#       'vY0': -118.04,
#       'vZ0': -3.75,
#       'x': 103.66,
#       'y': 190.58,
#       'x0': 2.04,
#       'y0': 50.0,
#       'z0': 5.65,
#       'aX': 8.84},
#      'breaks': {'breakAngle': 16.8,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 1517,
#       'spinDirection': 118},
#      'zone': 9,
#      'typeConfidence': 2.0,
#      'plateTime': 0.46,
#      'extension': 6.67},
#     'index': 3,
#     'playId': 'fadae11b-1496-442e-ba10-6e1fa0245445',
#     'pitchNumber': 4,
#     'startTime': '2021-04-01T17:22:23.803Z',
#     'endTime': '2021-04-01T17:22:28.993Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 2, 'strikes': 3, 'outs': 2},
#     'pitchData': {'startSpeed': 90.9,
#      'endSpeed': 83.2,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
# ...
#      'strikeZoneBottom': 1.68,
#      'coordinates': {'aY': 36.47,
#       'aZ': -8.55,
#       'pfxX': -7.59,
#       'pfxZ': 11.38,
#       'pX': -1.29,
#       'pZ': 3.51,
#       'vX0': 2.08,
#       'vY0': -143.89,
#       'vZ0': -4.66,
#       'x': 166.1,
#       'y': 144.06,
#       'x0': -1.04,
#       'y0': 50.0,
#       'z0': 5.69,
#       'aX': -15.76},
#      'breaks': {'breakAngle': 57.6,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2647,
#       'spinDirection': 209},
#      'zone': 11,
#      'typeConfidence': 2.0,
#      'plateTime': 0.38,
#      'extension': 6.71},
#     'index': 2,
#     'playId': 'c95fba4f-0aa4-48d2-a34b-a5c414500f10',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T20:51:24.523Z',
#     'endTime': '2021-04-01T20:51:31.711Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T20:51:31.711Z',
#   'atBatIndex': 78},
#  {'result': {'type': 'atBat',
#    'event': 'Strikeout',
#    'eventType': 'strikeout',
#    'description': 'Gleyber Torres strikes out swinging.',
#    'rbi': 0,
#    'awayScore': 3,
#    'homeScore': 2},
#   'about': {'atBatIndex': 79,
#    'halfInning': 'bottom',
#    'isTopInning': False,
#    'inning': 10,
#    'startTime': '2021-04-01T20:51:54.290Z',
#    'endTime': '2021-04-01T20:54:48.716Z',
#    'isComplete': True,
#    'isScoringPlay': False,
#    'hasReview': False,
#    'hasOut': True,
#    'captivatingIndex': 14},
#   'count': {'balls': 1, 'strikes': 3, 'outs': 3},
#   'matchup': {'batter': {'id': 650402,
#     'fullName': 'Gleyber Torres',
#     'link': '/api/v1/people/650402'},
#    'batSide': {'code': 'R', 'description': 'Right'},
#    'pitcher': {'id': 657240,
#     'fullName': 'Julian Merryweather',
#     'link': '/api/v1/people/657240'},
#    'pitchHand': {'code': 'R', 'description': 'Right'},
#    'batterHotColdZoneStats': {'stats': [{'type': {'displayName': 'hotColdZones'},
#       'group': {'displayName': 'hitting'},
#       'exemptions': [],
#       'splits': [{'stat': {'name': 'exitVelocity',
#          'zones': [{'zone': '01',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '91.90'},
#           {'zone': '02',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '96.11'},
#           {'zone': '03',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '85.32'},
#           {'zone': '04',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '95.77'},
#           {'zone': '05',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '91.50'},
#           {'zone': '06',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '87.64'},
#           {'zone': '07',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '87.28'},
#           {'zone': '08',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '88.56'},
#           {'zone': '09',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '75.85'},
#           {'zone': '11',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '82.90'},
#           {'zone': '12',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '88.92'},
#           {'zone': '13',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '77.49'},
#           {'zone': '14',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '68.05'}]}},
#        {'stat': {'name': 'battingAverage',
#          'zones': [{'zone': '01',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.111'},
#           {'zone': '02',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '.250'},
#           {'zone': '03',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.143'},
#           {'zone': '04',
#            'color': 'rgba(214, 41, 52, .55)',
#            'temp': 'hot',
#            'value': '.400'},
#           {'zone': '05',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '.250'},
#           {'zone': '06',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '.267'},
#           {'zone': '07',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '.250'},
#           {'zone': '08',
#            'color': 'rgba(214, 41, 52, .55)',
#            'temp': 'hot',
#            'value': '.438'},
#           {'zone': '09',
#            'color': 'rgba(214, 41, 52, .55)',
#            'temp': 'hot',
#            'value': '.353'},
#           {'zone': '11',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.111'},
#           {'zone': '12',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.100'},
#           {'zone': '13',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '.250'},
#           {'zone': '14',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.200'}]}},
#        {'stat': {'name': 'onBasePlusSlugging',
#          'zones': [{'zone': '01',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.300'},
#           {'zone': '02',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '.583'},
#           {'zone': '03',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.286'},
#           {'zone': '04',
#            'color': 'rgba(234, 147, 153, .55)',
#            'temp': 'warm',
#            'value': '1.133'},
#           {'zone': '05',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '.750'},
#           {'zone': '06',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.533'},
#           {'zone': '07',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.500'},
#           {'zone': '08',
#            'color': 'rgba(234, 147, 153, .55)',
#            'temp': 'warm',
#            'value': '1.000'},
#           {'zone': '09',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '.706'},
#           {'zone': '11',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.500'},
#           {'zone': '12',
#            'color': 'rgba(6, 90, 238, .55)',
#            'temp': 'cold',
#            'value': '.429'},
#           {'zone': '13',
#            'color': 'rgba(255, 255, 255, 0.55)',
#            'temp': 'lukewarm',
#            'value': '.727'},
#           {'zone': '14',
#            'color': 'rgba(150, 188, 255, .55)',
#            'temp': 'cool',
#            'value': '.571'}]}}]}]},
#    'batterHotColdZones': [{'zone': '01',
#      'color': 'rgba(6, 90, 238, .55)',
#      'temp': 'cold',
#      'value': '.300'},
#     {'zone': '02',
#      'color': 'rgba(150, 188, 255, .55)',
#      'temp': 'cool',
#      'value': '.583'},
#     {'zone': '03',
#      'color': 'rgba(6, 90, 238, .55)',
#      'temp': 'cold',
#      'value': '.286'},
#     {'zone': '04',
#      'color': 'rgba(234, 147, 153, .55)',
#      'temp': 'warm',
#      'value': '1.133'},
#     {'zone': '05',
#      'color': 'rgba(255, 255, 255, 0.55)',
#      'temp': 'lukewarm',
#      'value': '.750'},
#     {'zone': '06',
#      'color': 'rgba(6, 90, 238, .55)',
#      'temp': 'cold',
#      'value': '.533'},
#     {'zone': '07',
#      'color': 'rgba(6, 90, 238, .55)',
#      'temp': 'cold',
#      'value': '.500'},
#     {'zone': '08',
#      'color': 'rgba(234, 147, 153, .55)',
#      'temp': 'warm',
#      'value': '1.000'},
#     {'zone': '09',
#      'color': 'rgba(255, 255, 255, 0.55)',
#      'temp': 'lukewarm',
#      'value': '.706'},
#     {'zone': '11',
#      'color': 'rgba(6, 90, 238, .55)',
#      'temp': 'cold',
#      'value': '.500'},
#     {'zone': '12',
#      'color': 'rgba(6, 90, 238, .55)',
#      'temp': 'cold',
#      'value': '.429'},
#     {'zone': '13',
#      'color': 'rgba(255, 255, 255, 0.55)',
#      'temp': 'lukewarm',
#      'value': '.727'},
#     {'zone': '14',
#      'color': 'rgba(150, 188, 255, .55)',
#      'temp': 'cool',
#      'value': '.571'}],
#    'pitcherHotColdZones': [],
#    'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#   'pitchIndex': [0, 1, 2, 3, 4],
#   'actionIndex': [],
#   'runnerIndex': [0],
#   'runners': [{'movement': {'originBase': None,
#      'start': None,
#      'end': None,
#      'outBase': '1B',
#      'isOut': True,
#      'outNumber': 3},
#     'details': {'event': 'Strikeout',
#      'eventType': 'strikeout',
#      'movementReason': None,
#      'runner': {'id': 650402,
#       'fullName': 'Gleyber Torres',
#       'link': '/api/v1/people/650402'},
#      'responsiblePitcher': None,
#      'isScoringEvent': False,
#      'rbi': False,
#      'earned': False,
#      'teamUnearned': False,
#      'playIndex': 4},
#     'credits': [{'player': {'id': 643376, 'link': '/api/v1/people/643376'},
#       'position': {'code': '2',
#        'name': 'Catcher',
#        'type': 'Catcher',
#        'abbreviation': 'C'},
#       'credit': 'f_putout'}]}],
#   'playEvents': [{'details': {'call': {'code': 'W',
#       'description': 'Swinging Strike (Blocked)'},
#      'description': 'Swinging Strike (Blocked)',
#      'code': 'W',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(0, 0, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'SL', 'description': 'Slider'},
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 1, 'outs': 2},
#     'pitchData': {'startSpeed': 88.0,
#      'endSpeed': 81.2,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 26.12,
#       'aZ': -28.51,
#       'pfxX': 1.07,
#       'pfxZ': 2.2,
#       'pX': -0.39,
#       'pZ': 1.04,
#       'vX0': 0.8,
#       'vY0': -128.1,
#       'vZ0': -6.33,
#       'x': 131.84,
#       'y': 210.7,
#       'x0': -0.85,
#       'y0': 50.0,
#       'z0': 5.77,
#       'aX': 1.78},
#      'breaks': {'breakAngle': 3.6,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 2460,
#       'spinDirection': 121},
#      'zone': 13,
#      'typeConfidence': 2.0,
#      'plateTime': 0.43,
#      'extension': 6.46},
#     'index': 0,
#     'playId': 'd63c59ce-040e-44dd-88e7-caed23313b5a',
#     'pitchNumber': 1,
#     'startTime': '2021-04-01T20:52:04.692Z',
#     'endTime': '2021-04-01T20:52:09.761Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'F', 'description': 'Foul'},
#      'description': 'Foul',
#      'code': 'F',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 0, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 98.9,
#      'endSpeed': 90.4,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 33.36,
#       'aZ': -11.21,
#       'pfxX': -7.16,
#       'pfxZ': 10.01,
#       'pX': -0.08,
#       'pZ': 2.0,
#       'vX0': 5.07,
#       'vY0': -143.79,
#       'vZ0': -8.21,
#       'x': 120.23,
#       'y': 184.82,
#       'x0': -0.94,
#       'y0': 50.0,
#       'z0': 5.59,
#       'aX': -14.98},
#      'breaks': {'breakAngle': 46.8,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2513,
#       'spinDirection': 209},
#      'zone': 8,
#      'typeConfidence': 2.0,
#      'plateTime': 0.38,
#      'extension': 6.67},
#     'index': 1,
#     'playId': 'd942f3d0-7cf9-452d-a508-09e9fcbf4f2e',
#     'pitchNumber': 2,
#     'startTime': '2021-04-01T20:52:56.800Z',
#     'endTime': '2021-04-01T20:53:02.234Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': '*B', 'description': 'Ball In Dirt'},
#      'description': 'Ball In Dirt',
#      'code': '*B',
#      'ballColor': 'rgba(39, 161, 39, 1.0)',
#      'trailColor': 'rgba(0, 0, 254, 1.0)',
#      'isInPlay': False,
#      'isStrike': False,
#      'isBall': True,
#      'type': {'code': 'SL', 'description': 'Slider'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 89.3,
#      'endSpeed': 82.8,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 26.52,
#       'aZ': -27.33,
#       'pfxX': -1.31,
#       'pfxZ': 2.84,
#       'pX': 1.89,
#       'pZ': -1.13,
#       'vX0': 6.77,
#       'vY0': -129.53,
#       'vZ0': -11.63,
#       'x': 99.37,
#       'y': 207.47,
#       'x0': -0.58,
#       'y0': 50.0,
#       'z0': 5.5,
#       'aX': -2.24},
#      'breaks': {'breakAngle': 2.4,
#       'breakLength': 7.2,
#       'breakY': 24.0,
#       'spinRate': 2588,
#       'spinDirection': 123},
#      'zone': 14,
#      'typeConfidence': 2.0,
#      'plateTime': 0.42,
#      'extension': 6.58},
#     'index': 2,
#     'playId': '03d9f1f6-f42c-44b4-8b08-ca3a1121c8f7',
#     'pitchNumber': 3,
#     'startTime': '2021-04-01T20:53:34.686Z',
#     'endTime': '2021-04-01T20:53:45.329Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'F', 'description': 'Foul'},
#      'description': 'Foul',
#      'code': 'F',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 2, 'outs': 2},
#     'pitchData': {'startSpeed': 98.6,
#      'endSpeed': 89.7,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 34.38,
#       'aZ': -8.29,
#       'pfxX': -7.13,
#       'pfxZ': 11.52,
#       'pX': -0.28,
#       'pZ': 2.84,
#       'vX0': 4.04,
#       'vY0': -143.38,
#       'vZ0': -6.56,
#       'x': 44.79,
#       'y': 269.17,
#       'x0': -0.79,
#       'y0': 50.0,
#       'z0': 5.68,
#       'aX': -14.78},
#      'breaks': {'breakAngle': 54.0,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2524,
#       'spinDirection': 210},
#      'zone': 1,
#      'typeConfidence': 0.85,
#      'plateTime': 0.38,
#      'extension': 6.56},
#     'index': 3,
#     'playId': 'ddaf8e59-0321-48d8-af20-dfccaa548740',
#     'pitchNumber': 4,
#     'startTime': '2021-04-01T20:54:07.983Z',
#     'endTime': '2021-04-01T20:54:12.000Z',
#     'isPitch': True,
#     'type': 'pitch'},
#    {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#      'description': 'Swinging Strike',
#      'code': 'S',
#      'ballColor': 'rgba(170, 21, 11, 1.0)',
#      'trailColor': 'rgba(188, 0, 33, 1.0)',
#      'isInPlay': False,
#      'isStrike': True,
#      'isBall': False,
#      'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#      'hasReview': False},
#     'count': {'balls': 1, 'strikes': 3, 'outs': 2},
#     'pitchData': {'startSpeed': 99.1,
#      'endSpeed': 89.6,
#      'strikeZoneTop': 3.41,
#      'strikeZoneBottom': 1.56,
#      'coordinates': {'aY': 36.85,
#       'aZ': -9.84,
#       'pfxX': -5.66,
#       'pfxZ': 10.73,
#       'pX': 0.01,
#       'pZ': 2.88,
#       'vX0': 4.44,
#       'vY0': -144.11,
#       'vZ0': -6.28,
#       'x': 116.76,
#       'y': 160.92,
#       'x0': -0.83,
#       'y0': 50.01,
#       'z0': 5.72,
#       'aX': -11.78},
#      'breaks': {'breakAngle': 43.2,
#       'breakLength': 3.6,
#       'breakY': 24.0,
#       'spinRate': 2447,
#       'spinDirection': 211},
#      'zone': 2,
#      'typeConfidence': 2.0,
#      'plateTime': 0.38,
#      'extension': 6.77},
#     'index': 4,
#     'playId': '2c66947b-2734-4704-a972-dab8edb060a0',
#     'pitchNumber': 5,
#     'startTime': '2021-04-01T20:54:43.899Z',
#     'endTime': '2021-04-01T20:54:48.716Z',
#     'isPitch': True,
#     'type': 'pitch'}],
#   'playEndTime': '2021-04-01T20:54:48.716Z',
#   'atBatIndex': 79}]

# %% [markdown]
# Again, this `allPlays` object is a list of `plays`. So we only dig into one for the exploratory work.

# %%
Play1 = allPlays_content[0]
Play1
# Out:
# {'result': {'type': 'atBat',
#   'event': 'Groundout',
#   'eventType': 'field_out',
#   'description': 'Marcus Semien grounds out, shortstop Gleyber Torres to first baseman Jay Bruce.',
#   'rbi': 0,
#   'awayScore': 0,
#   'homeScore': 0},
#  'about': {'atBatIndex': 0,
#   'halfInning': 'top',
#   'isTopInning': True,
#   'inning': 1,
#   'startTime': '2021-04-01T16:38:06.807Z',
#   'endTime': '2021-04-01T17:10:52.200Z',
#   'isComplete': True,
#   'isScoringPlay': False,
#   'hasReview': False,
#   'hasOut': True,
#   'captivatingIndex': 0},
#  'count': {'balls': 1, 'strikes': 0, 'outs': 1},
#  'matchup': {'batter': {'id': 543760,
#    'fullName': 'Marcus Semien',
#    'link': '/api/v1/people/543760'},
#   'batSide': {'code': 'R', 'description': 'Right'},
#   'pitcher': {'id': 543037,
#    'fullName': 'Gerrit Cole',
#    'link': '/api/v1/people/543037'},
#   'pitchHand': {'code': 'R', 'description': 'Right'},
#   'batterHotColdZones': [],
#   'pitcherHotColdZones': [],
#   'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#  'pitchIndex': [3, 4],
#  'actionIndex': [0, 1, 2],
#  'runnerIndex': [0],
#  'runners': [{'movement': {'originBase': None,
#     'start': None,
#     'end': None,
#     'outBase': '1B',
#     'isOut': True,
#     'outNumber': 1},
#    'details': {'event': 'Groundout',
#     'eventType': 'field_out',
#     'movementReason': None,
#     'runner': {'id': 543760,
#      'fullName': 'Marcus Semien',
#      'link': '/api/v1/people/543760'},
#     'responsiblePitcher': None,
#     'isScoringEvent': False,
#     'rbi': False,
#     'earned': False,
#     'teamUnearned': False,
#     'playIndex': 4},
#    'credits': [{'player': {'id': 650402, 'link': '/api/v1/people/650402'},
#      'position': {'code': '6',
#       'name': 'Shortstop',
#       'type': 'Infielder',
#       'abbreviation': 'SS'},
#      'credit': 'f_assist'},
#     {'player': {'id': 457803, 'link': '/api/v1/people/457803'},
#      'position': {'code': '3',
#       'name': 'First Base',
#       'type': 'Infielder',
#       'abbreviation': '1B'},
#      'credit': 'f_putout'}]}],
#  'playEvents': [{'details': {'description': 'Status Change - Pre-Game',
#     'event': 'Game Advisory',
#     'eventType': 'game_advisory',
#     'awayScore': 0,
#     'homeScore': 0,
#     'isScoringPlay': False,
#     'hasReview': False},
#    'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#    'index': 0,
#    'startTime': '2021-04-01T16:38:06.807Z',
#    'endTime': '2021-04-01T16:56:47.520Z',
#    'isPitch': False,
#    'type': 'action',
#    'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#   {'details': {'description': 'Status Change - Warmup',
#     'event': 'Game Advisory',
#     'eventType': 'game_advisory',
#     'awayScore': 0,
#     'homeScore': 0,
#     'isScoringPlay': False,
#     'hasReview': False},
#    'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#    'index': 1,
#    'startTime': '2021-04-01T16:56:47.520Z',
#    'endTime': '2021-04-01T17:10:02.256Z',
#    'isPitch': False,
#    'type': 'action',
#    'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#   {'details': {'description': 'Status Change - In Progress',
#     'event': 'Game Advisory',
#     'eventType': 'game_advisory',
#     'awayScore': 0,
#     'homeScore': 0,
#     'isScoringPlay': False,
#     'hasReview': False},
#    'count': {'balls': 0, 'strikes': 0, 'outs': 0},
#    'index': 2,
#    'startTime': '2021-04-01T17:10:02.256Z',
#    'isPitch': False,
#    'type': 'action',
#    'player': {'id': 543760, 'link': '/api/v1/people/543760'}},
#   {'details': {'call': {'code': 'B', 'description': 'Ball'},
#     'description': 'Ball',
#     'code': 'B',
#     'ballColor': 'rgba(39, 161, 39, 1.0)',
#     'trailColor': 'rgba(188, 0, 33, 1.0)',
#     'isInPlay': False,
#     'isStrike': False,
#     'isBall': True,
#     'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#     'hasReview': False},
#    'count': {'balls': 1, 'strikes': 0, 'outs': 0},
#    'pitchData': {'startSpeed': 97.7,
#     'endSpeed': 89.0,
#     'strikeZoneTop': 3.25,
#     'strikeZoneBottom': 1.53,
#     'coordinates': {'aY': 33.13,
#      'aZ': -9.7,
#      'pfxX': -6.78,
#      'pfxZ': 11.02,
#      'pX': -0.5,
#      'pZ': 3.54,
#      'vX0': 6.33,
#      'vY0': -142.05,
#      'vZ0': -4.35,
#      'x': 129.48,
#      'y': 169.3,
#      'x0': -1.88,
#      'y0': 50.0,
#      'z0': 5.71,
#      'aX': -13.83},
#     'breaks': {'breakAngle': 49.2,
#      'breakLength': 3.6,
#      'breakY': 24.0,
#      'spinRate': 2672,
#      'spinDirection': 207},
#     'zone': 11,
#     'typeConfidence': 2.0,
#     'plateTime': 0.39,
#     'extension': 6.57},
#    'index': 3,
#    'playId': '7b18a365-daf0-48a1-b0e5-d63c370061bc',
#    'pitchNumber': 1,
#    'startTime': '2021-04-01T17:10:31.233Z',
#    'endTime': '2021-04-01T17:10:34.765Z',
#    'isPitch': True,
#    'type': 'pitch'},
#   {'details': {'call': {'code': 'X', 'description': 'In play, out(s)'},
#     'description': 'In play, out(s)',
#     'code': 'X',
#     'ballColor': 'rgba(26, 86, 190, 1.0)',
#     'trailColor': 'rgba(188, 0, 33, 1.0)',
#     'isInPlay': True,
#     'isStrike': False,
#     'isBall': False,
#     'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#     'hasReview': False},
#    'count': {'balls': 1, 'strikes': 0, 'outs': 0},
#    'pitchData': {'startSpeed': 95.3,
#     'endSpeed': 87.5,
#     'strikeZoneTop': 3.37,
#     'strikeZoneBottom': 1.53,
#     'coordinates': {'aY': 29.0,
#      'aZ': -10.65,
#      'pfxX': -6.74,
#      'pfxZ': 11.0,
#      'pX': 0.64,
#      'pZ': 2.77,
#      'vX0': 8.37,
#      'vY0': -138.5,
#      'vZ0': -5.9,
#      'x': 125.89,
#      'y': 150.94,
#      'x0': -1.54,
#      'y0': 50.0,
#      'z0': 5.62,
#      'aX': -13.17},
#     'breaks': {'breakAngle': 44.4,
#      'breakLength': 3.6,
#      'breakY': 24.0,
#      'spinRate': 2581,
#      'spinDirection': 209},
#     'zone': 3,
#     'typeConfidence': 2.0,
#     'plateTime': 0.39,
#     'extension': 6.53},
#    'hitData': {'launchSpeed': 99.9,
#     'launchAngle': -1.0,
#     'totalDistance': 40.0,
#     'trajectory': 'ground_ball',
#     'hardness': 'medium',
#     'location': '6',
#     'coordinates': {'coordX': 99.28, 'coordY': 147.19}},
#    'index': 4,
#    'playId': '1cf7d060-1f8b-40d2-92e6-6a16b8252d94',
#    'pitchNumber': 2,
#    'startTime': '2021-04-01T17:10:43.173Z',
#    'endTime': '2021-04-01T17:10:52.200Z',
#    'isPitch': True,
#    'type': 'pitch'}],
#  'playEndTime': '2021-04-01T17:10:52.200Z',
#  'atBatIndex': 0}

# %%
Play1.keys()
# Out:
# dict_keys(['result', 'about', 'count', 'matchup', 'pitchIndex', 'actionIndex', 'runnerIndex', 'runners', 'playEvents', 'playEndTime', 'atBatIndex'])

# %% [markdown]
# Looking at the available keys of this endpoint, `result` key obviously contains the information we want: the outcome of each at bat.

# %%
Play1['result']
# Out:
# {'type': 'atBat',
#  'event': 'Groundout',
#  'eventType': 'field_out',
#  'description': 'Marcus Semien grounds out, shortstop Gleyber Torres to first baseman Jay Bruce.',
#  'rbi': 0,
#  'awayScore': 0,
#  'homeScore': 0}

# %% [markdown]
# Here we are. We need to cautious here. `type` attributes implies that there could be play type that is not `atBat`.
#
# So we loop through each play and filter out ones whose type is not `atBat`.

# %%
play_dict = {}
play_count = 0

for play in allPlays_content:
    if play['result']['type'] != 'atBat':
        pass
    
    play_count += 1
    play_outcome = play['result']['eventType']
    
    play_dict.update({play_count: play_outcome})

# %%
play_dict
# Out:
# {1: 'field_out',
#  2: 'strikeout',
#  3: 'field_out',
#  4: 'field_out',
#  5: 'strikeout',
#  6: 'strikeout',
#  7: 'single',
#  8: 'single',
#  9: 'single',
#  10: 'field_out',
#  11: 'strikeout',
#  12: 'strikeout',
#  13: 'field_out',
#  14: 'single',
#  15: 'strikeout',
#  16: 'home_run',
#  17: 'field_out',
#  18: 'field_out',
#  19: 'strikeout',
#  20: 'strikeout',
#  21: 'field_out',
#  22: 'field_out',
#  23: 'field_out',
#  24: 'strikeout',
#  25: 'walk',
#  26: 'strikeout',
#  27: 'field_out',
#  28: 'strikeout',
#  29: 'field_out',
#  30: 'strikeout',
#  31: 'field_out',
#  32: 'single',
#  33: 'field_out',
#  34: 'field_out',
#  35: 'field_out',
#  36: 'field_out',
#  37: 'walk',
#  38: 'single',
#  39: 'field_out',
#  40: 'strikeout',
#  41: 'home_run',
#  42: 'walk',
#  43: 'grounded_into_double_play',
#  44: 'single',
#  45: 'force_out',
#  46: 'strikeout',
#  47: 'walk',
#  48: 'field_out',
#  49: 'field_out',
#  50: 'single',
#  51: 'field_out',
#  52: 'caught_stealing_2b',
#  53: 'single',
#  54: 'field_out',
#  55: 'single',
#  56: 'walk',
#  57: 'grounded_into_double_play',
#  58: 'strikeout',
#  59: 'field_out',
#  60: 'field_out',
#  61: 'walk',
#  62: 'strikeout',
#  63: 'field_out',
#  64: 'strikeout',
#  65: 'single',
#  66: 'field_out',
#  67: 'strikeout',
#  68: 'field_out',
#  69: 'walk',
#  70: 'strikeout',
#  71: 'walk',
#  72: 'fielders_choice_out',
#  73: 'strikeout',
#  74: 'double',
#  75: 'strikeout',
#  76: 'strikeout',
#  77: 'strikeout',
#  78: 'strikeout',
#  79: 'strikeout',
#  80: 'strikeout'}

# %% [markdown]
# Finally, we achieved what we wanted. The outcome of each at-bat.

# %% [markdown]
# ### 3. Putting it altogether

# %% [markdown]
# First we build a helper function that can be used generally.

# %%
import time

def get_json(url):
    ## get_json: str -> json
    ## get_json() function takes 'url' and returns the response in json format from the MLB Stats API.
    
    response = requests.get(url)
    if (response.status_code != 200):
        print('status code: %s' % response.status_code)
        time.sleep(1.0)
        get_json(url)
    else:
        content = response.content
        json_content = json.loads(content)
        return(json_content)

# %%
def extract_game_id(schedule_json):
    ## extract_game_id: json -> listof int
    ## extract_game_id() function takes a schedule response object and returns a list of game IDs.
    
    if schedule_json == {}:
        return []

    gameID_list = []
    
    dates = schedule_json['dates']
    
    for day in dates:
        games = day['games']
        
        for game in games:
            gameID = game['gamePk']
            gameID_list.append(gameID)
   
    
    return(gameID_list)

# %%
def get_game_ids(date, endDate = None, teamId = None):
    ## get_game_ids: str int str str -> listof int
    ## get_game_ids() function returns the list of game IDs.
    ## date must be of format "YYYY-MM-DD". 
    ## If date is used without end_date, then it returns the list of game IDs on the input date.
    ## If end_date is inputted, then it returns the list of game IDs in the period of date and end_date.
    ## If teamID is inputted, then it will return game ID's that the corresponding team played; otherwise, all.
    
    
    base_schedule_url = "http://statsapi.mlb.com/api/v1/schedule?sportId=1"
    alt_base_url = "https://beta-statsapi.mlb.com:443/api/v1/schedule?sportId=1"
    suffix = ""

    if endDate is not None:
        suffix = "&startDate=" + date + "&endDate=" + endDate
    
    else:
        suffix = "&date=" + date
        
    if teamId is not None:
        suffix = suffix + "&teamId=" + str(teamId)
        
    
    try:
        url = base_schedule_url + suffix
        #print(url)
        schedule_content = get_json(url)
        #print('status code: %s' % response.status_code)

    except:
        #print('Trying alternate route...')
        url = alt_base_url + suffix
        #print(url)
        schedule_content = get_json(url)
   
    gameIDs = extract_game_id(schedule_content)

    return(gameIDs)

# %%
def get_atbat_outcome(listofgameIDs):
    
    gameID_dict = {}
    
    for gameID in listofgameIDs:
        
        try:
            url =  "http://statsapi.mlb.com/api/v1/game/" + str(gameID) + "/playByPlay"
            playbyplay_content = get_json(url)
            
        except:
            #print('Trying alternate route...')
            url = "https://beta-statsapi.mlb.com:443/api/v1/game" + str(gameID) + "/playByPlay"
            playbyplay_content = get_json(url)

    
        allPlays_content = playbyplay_content['allPlays']
    
        play_dict = {}
        play_count = 0

        for play in allPlays_content:
            if play['result']['type'] != 'atBat':
                pass

            play_count += 1
            play_outcome = play['result']['eventType']

            play_dict.update({play_count: play_outcome})
            
        gameID_dict.update({gameID:play_dict})
        
    return(gameID_dict)
